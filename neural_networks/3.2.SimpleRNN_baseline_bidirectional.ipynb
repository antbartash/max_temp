# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
import os
import random
import datetime

np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# # Data

# %%
data_path = 'https://raw.githubusercontent.com/antbartash/max_temp/master/data/data2.csv'
data = pd.read_csv(data_path, index_col=0)
data['DATE'] = data['DATE'].astype('datetime64[ns]')

print(data.shape)
data.head()
# Out:
# (40898, 4)
#        STATION                        NAME       DATE  TMAX
# 0  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-01  12.2
# 1  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-02  10.6
# 2  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-03   8.3
# 3  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-04   6.1
# 4  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-05   6.1

# %%
data = data[['STATION', 'DATE', 'TMAX']]

# add sine and cosine transforms to add periodicality
doy = data['DATE'].dt.dayofyear / 365.25
data['Year_sin'] = np.sin(doy * 2 * np.pi)
data['Year_cos'] = np.cos(doy * 2 * np.pi)

print(data.shape)
data.head()
# Out:
# (40898, 5)
#        STATION       DATE  TMAX  Year_sin  Year_cos
# 0  USW00012916 2010-01-01  12.2  0.017202  0.999852
# 1  USW00012916 2010-01-02  10.6  0.034398  0.999408
# 2  USW00012916 2010-01-03   8.3  0.051584  0.998669
# 3  USW00012916 2010-01-04   6.1  0.068755  0.997634
# 4  USW00012916 2010-01-05   6.1  0.085906  0.996303

# %% [markdown]
# ## Data preprocessing

# %%
# TRAIN/VALID/TEST SPLIT

train_df = data.loc[data['DATE'].dt.year <= 2021].reset_index(drop=True).copy()
valid_df = data.loc[data['DATE'].dt.year == 2022].reset_index(drop=True).copy()
test_df = data.loc[data['DATE'].dt.year == 2023].reset_index(drop=True).copy()

print(f'Train: {train_df.shape}')
print(f'Valid: {valid_df.shape}')
print(f'Test: {test_df.shape}')
# Out:
# Train: (35058, 5)
# Valid: (2920, 5)
# Test: (2920, 5)

# %%
# SCALING

train_df.drop(columns=['DATE'], inplace=True)
valid_df.drop(columns=['DATE'], inplace=True)
test_df.drop(columns=['DATE'], inplace=True)

# keep station to drop mixed windows later (encode to avoid errors from scaler)
encoder = OrdinalEncoder()
encoder.fit(train_df[['STATION']])
train_df['STATION'] = encoder.transform(train_df[['STATION']])[:, 0]
valid_df['STATION'] = encoder.transform(valid_df[['STATION']])[:, 0]
test_df['STATION'] = encoder.transform(test_df[['STATION']])[:, 0]

# scaling
scaler = StandardScaler()
scaler.fit(train_df)
train_df = pd.DataFrame(scaler.transform(train_df),
                        columns=scaler.feature_names_in_, index=train_df.index)
valid_df = pd.DataFrame(scaler.transform(valid_df),
                        columns=scaler.feature_names_in_, index=valid_df.index)
test_df = pd.DataFrame(scaler.transform(test_df),
                       columns=scaler.feature_names_in_, index=test_df.index)

train_df.head()
# Out:
#     STATION      TMAX  Year_sin  Year_cos
# 0 -1.091014 -0.747812  0.024401  1.414059
# 1 -1.091014 -0.896450  0.048721  1.413431
# 2 -1.091014 -1.110117  0.073027  1.412386
# 3 -1.091014 -1.314495  0.097312  1.410922
# 4 -1.091014 -1.314495  0.121567  1.409041

# %%
def tmax_inverse_transform(arr, scale=scaler.scale_[1], mean=scaler.mean_[1]):
    return arr * scale + mean

# %%
# TF DATASET

def create_dataset(data, target_col, source_col, seq_length):
  input_data = data[:-seq_length]
  # adding source_col to target allows to drop samples with features and target
  # from diff sources (source_col will be dropped from the target later)
  targets = data[[source_col, target_col]][seq_length:]
  dataset = tf.keras.preprocessing.timeseries_dataset_from_array(
      input_data, targets,
      sequence_length=seq_length,
      sequence_stride=1,
      batch_size=32,
      shuffle=False,
      seed=42
    )
  for batch in dataset:
    inputs, targets = batch
    assert np.array_equal(inputs[0], data[:seq_length])  # First sequence: steps [0-13]
    # Corresponding target: step 14
    assert np.array_equal(targets[0, 1], data.loc[seq_length, target_col])
    break
  return dataset

train_ds = create_dataset(train_df, 'TMAX', 'STATION', 14)
valid_ds = create_dataset(valid_df, 'TMAX', 'STATION', 14)
test_ds = create_dataset(test_df, 'TMAX', 'STATION', 14)

# %%
# DATASET CLEANING

def filter_mixed_windows(dataset):
    def is_valid_window(inputs, targets):
        # Extract the first feature (station) from inputs and targets
        input_station_ids = inputs[:, :, 0]  # Shape: (batch_size, sequence_length)
        target_station_ids = targets[:, 0]  # Shape: (batch_size)

        # Check if all station IDs in the inputs are the same
        input_same_station = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == tf.reduce_min(input_station_ids, axis=1))

        # Check if the target's station ID matches the input station ID
        target_matches_input = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == target_station_ids)

        # Only keep windows where both conditions are true
        return tf.logical_and(input_same_station, target_matches_input)

    # Filter the dataset
    filtered_dataset = dataset.filter(is_valid_window)
    return filtered_dataset

train_ds = filter_mixed_windows(train_ds)
valid_ds = filter_mixed_windows(valid_ds)
test_ds = filter_mixed_windows(test_ds)

# %%
def drop_first_column(feature, label):
    feature = feature[:, :, 1:]  # Keep all rows, drop the first column
    label = label[:, 1:]    # Keep all rows, drop the first column
    return feature, label

train_ds = train_ds.map(drop_first_column)
valid_ds = valid_ds.map(drop_first_column)
test_ds = test_ds.map(drop_first_column)

# %%
def load_data(batch_size, prefetch=tf.data.AUTOTUNE,
              train_ds=train_ds, valid_ds=valid_ds, test_ds=test_ds):
    train_ds = train_ds.rebatch(batch_size).prefetch(prefetch)
    valid_ds = valid_ds.rebatch(batch_size).prefetch(prefetch)
    test_ds = test_ds.rebatch(batch_size).prefetch(prefetch)
    train_num_batches = len(list(train_ds))
    valid_num_batches = len(list(valid_ds))
    test_num_batches = len(list(test_ds))
    # print(f'load_data - num_batches (train, valid, test): {train_num_batches}, {valid_num_batches}, {test_num_batches}')
    train_ds_repeat = train_ds.repeat()
    valid_ds_repeat = valid_ds.repeat()
    test_ds_repeat = test_ds.repeat()
    return train_ds_repeat, valid_ds_repeat, test_ds_repeat, train_num_batches, valid_num_batches, test_num_batches

train_ds_repeat, valid_ds_repeat, test_ds_repeat, train_num_batches, valid_num_batches, test_num_batches = load_data(batch_size=32)

# %% [markdown]
# # Model

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=75, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=25
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.SimpleRNN(4, activation='tanh', return_sequences=False)
    ),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='gelu'),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds_repeat, epochs=750, validation_data=valid_ds_repeat,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=2
)
# Out:
# Epoch 1/750
# 1088/1088 - 12s - 11ms/step - loss: 0.3203 - mean_squared_error: 0.1841 - val_loss: 0.3212 - val_mean_squared_error: 0.1811 - learning_rate: 0.0010
# Epoch 2/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2802 - mean_squared_error: 0.1437 - val_loss: 0.3115 - val_mean_squared_error: 0.1724 - learning_rate: 0.0010
# Epoch 3/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2764 - mean_squared_error: 0.1409 - val_loss: 0.3083 - val_mean_squared_error: 0.1679 - learning_rate: 0.0010
# Epoch 4/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2754 - mean_squared_error: 0.1402 - val_loss: 0.3074 - val_mean_squared_error: 0.1670 - learning_rate: 0.0010
# Epoch 5/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2744 - mean_squared_error: 0.1396 - val_loss: 0.3081 - val_mean_squared_error: 0.1666 - learning_rate: 0.0010
# Epoch 6/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2741 - mean_squared_error: 0.1392 - val_loss: 0.3075 - val_mean_squared_error: 0.1665 - learning_rate: 0.0010
# Epoch 7/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2733 - mean_squared_error: 0.1388 - val_loss: 0.3062 - val_mean_squared_error: 0.1657 - learning_rate: 0.0010
# Epoch 8/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2729 - mean_squared_error: 0.1384 - val_loss: 0.3071 - val_mean_squared_error: 0.1659 - learning_rate: 0.0010
# Epoch 9/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2728 - mean_squared_error: 0.1384 - val_loss: 0.3061 - val_mean_squared_error: 0.1649 - learning_rate: 0.0010
# Epoch 10/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2723 - mean_squared_error: 0.1381 - val_loss: 0.3033 - val_mean_squared_error: 0.1637 - learning_rate: 0.0010
# Epoch 11/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2720 - mean_squared_error: 0.1378 - val_loss: 0.3043 - val_mean_squared_error: 0.1636 - learning_rate: 0.0010
# Epoch 12/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2717 - mean_squared_error: 0.1375 - val_loss: 0.3038 - val_mean_squared_error: 0.1629 - learning_rate: 0.0010
# Epoch 13/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2717 - mean_squared_error: 0.1376 - val_loss: 0.3048 - val_mean_squared_error: 0.1641 - learning_rate: 0.0010
# Epoch 14/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2713 - mean_squared_error: 0.1373 - val_loss: 0.3042 - val_mean_squared_error: 0.1635 - learning_rate: 0.0010
# Epoch 15/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2710 - mean_squared_error: 0.1371 - val_loss: 0.3047 - val_mean_squared_error: 0.1640 - learning_rate: 0.0010
# Epoch 16/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2713 - mean_squared_error: 0.1372 - val_loss: 0.3012 - val_mean_squared_error: 0.1615 - learning_rate: 0.0010
# Epoch 17/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2710 - mean_squared_error: 0.1370 - val_loss: 0.3031 - val_mean_squared_error: 0.1628 - learning_rate: 0.0010
# Epoch 18/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2710 - mean_squared_error: 0.1370 - val_loss: 0.3012 - val_mean_squared_error: 0.1620 - learning_rate: 0.0010
# Epoch 19/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2708 - mean_squared_error: 0.1367 - val_loss: 0.3039 - val_mean_squared_error: 0.1629 - learning_rate: 0.0010
# Epoch 20/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2709 - mean_squared_error: 0.1369 - val_loss: 0.3024 - val_mean_squared_error: 0.1621 - learning_rate: 0.0010
# Epoch 21/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2706 - mean_squared_error: 0.1367 - val_loss: 0.3029 - val_mean_squared_error: 0.1626 - learning_rate: 0.0010
# Epoch 22/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2706 - mean_squared_error: 0.1367 - val_loss: 0.3038 - val_mean_squared_error: 0.1625 - learning_rate: 0.0010
# Epoch 23/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2706 - mean_squared_error: 0.1367 - val_loss: 0.3022 - val_mean_squared_error: 0.1622 - learning_rate: 0.0010
# Epoch 24/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2705 - mean_squared_error: 0.1365 - val_loss: 0.3009 - val_mean_squared_error: 0.1606 - learning_rate: 0.0010
# Epoch 25/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2704 - mean_squared_error: 0.1366 - val_loss: 0.3027 - val_mean_squared_error: 0.1617 - learning_rate: 0.0010
# Epoch 26/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2705 - mean_squared_error: 0.1366 - val_loss: 0.3015 - val_mean_squared_error: 0.1609 - learning_rate: 0.0010
# Epoch 27/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2703 - mean_squared_error: 0.1365 - val_loss: 0.3017 - val_mean_squared_error: 0.1612 - learning_rate: 0.0010
# Epoch 28/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2703 - mean_squared_error: 0.1363 - val_loss: 0.3023 - val_mean_squared_error: 0.1612 - learning_rate: 0.0010
# Epoch 29/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2702 - mean_squared_error: 0.1362 - val_loss: 0.3030 - val_mean_squared_error: 0.1618 - learning_rate: 0.0010
# Epoch 30/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2701 - mean_squared_error: 0.1363 - val_loss: 0.3027 - val_mean_squared_error: 0.1615 - learning_rate: 0.0010
# Epoch 31/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2702 - mean_squared_error: 0.1363 - val_loss: 0.3016 - val_mean_squared_error: 0.1608 - learning_rate: 0.0010
# Epoch 32/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2700 - mean_squared_error: 0.1361 - val_loss: 0.3030 - val_mean_squared_error: 0.1620 - learning_rate: 0.0010
# Epoch 33/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2700 - mean_squared_error: 0.1362 - val_loss: 0.3009 - val_mean_squared_error: 0.1601 - learning_rate: 0.0010
# Epoch 34/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2698 - mean_squared_error: 0.1361 - val_loss: 0.3019 - val_mean_squared_error: 0.1606 - learning_rate: 0.0010
# Epoch 35/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2698 - mean_squared_error: 0.1360 - val_loss: 0.3005 - val_mean_squared_error: 0.1599 - learning_rate: 0.0010
# Epoch 36/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2699 - mean_squared_error: 0.1360 - val_loss: 0.2999 - val_mean_squared_error: 0.1592 - learning_rate: 0.0010
# Epoch 37/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2698 - mean_squared_error: 0.1358 - val_loss: 0.3018 - val_mean_squared_error: 0.1605 - learning_rate: 0.0010
# Epoch 38/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2697 - mean_squared_error: 0.1360 - val_loss: 0.3013 - val_mean_squared_error: 0.1603 - learning_rate: 0.0010
# Epoch 39/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2697 - mean_squared_error: 0.1357 - val_loss: 0.3021 - val_mean_squared_error: 0.1605 - learning_rate: 0.0010
# Epoch 40/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2695 - mean_squared_error: 0.1357 - val_loss: 0.2986 - val_mean_squared_error: 0.1586 - learning_rate: 0.0010
# Epoch 41/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2696 - mean_squared_error: 0.1357 - val_loss: 0.3005 - val_mean_squared_error: 0.1593 - learning_rate: 0.0010
# Epoch 42/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2694 - mean_squared_error: 0.1355 - val_loss: 0.3013 - val_mean_squared_error: 0.1607 - learning_rate: 0.0010
# Epoch 43/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2694 - mean_squared_error: 0.1355 - val_loss: 0.2997 - val_mean_squared_error: 0.1589 - learning_rate: 0.0010
# Epoch 44/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2693 - mean_squared_error: 0.1355 - val_loss: 0.3014 - val_mean_squared_error: 0.1603 - learning_rate: 0.0010
# Epoch 45/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2693 - mean_squared_error: 0.1355 - val_loss: 0.2981 - val_mean_squared_error: 0.1581 - learning_rate: 0.0010
# Epoch 46/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2692 - mean_squared_error: 0.1354 - val_loss: 0.3007 - val_mean_squared_error: 0.1596 - learning_rate: 0.0010
# Epoch 47/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2693 - mean_squared_error: 0.1353 - val_loss: 0.2994 - val_mean_squared_error: 0.1587 - learning_rate: 0.0010
# Epoch 48/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2693 - mean_squared_error: 0.1354 - val_loss: 0.2992 - val_mean_squared_error: 0.1584 - learning_rate: 0.0010
# Epoch 49/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2692 - mean_squared_error: 0.1353 - val_loss: 0.2987 - val_mean_squared_error: 0.1584 - learning_rate: 0.0010
# Epoch 50/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2692 - mean_squared_error: 0.1353 - val_loss: 0.2999 - val_mean_squared_error: 0.1582 - learning_rate: 0.0010
# Epoch 51/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2691 - mean_squared_error: 0.1352 - val_loss: 0.2997 - val_mean_squared_error: 0.1580 - learning_rate: 0.0010
# Epoch 52/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2691 - mean_squared_error: 0.1352 - val_loss: 0.2985 - val_mean_squared_error: 0.1581 - learning_rate: 0.0010
# Epoch 53/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2690 - mean_squared_error: 0.1351 - val_loss: 0.2982 - val_mean_squared_error: 0.1575 - learning_rate: 0.0010
# Epoch 54/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2691 - mean_squared_error: 0.1352 - val_loss: 0.2982 - val_mean_squared_error: 0.1573 - learning_rate: 0.0010
# Epoch 55/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2690 - mean_squared_error: 0.1351 - val_loss: 0.2983 - val_mean_squared_error: 0.1576 - learning_rate: 0.0010
# Epoch 56/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2689 - mean_squared_error: 0.1350 - val_loss: 0.2991 - val_mean_squared_error: 0.1578 - learning_rate: 0.0010
# Epoch 57/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2690 - mean_squared_error: 0.1351 - val_loss: 0.2986 - val_mean_squared_error: 0.1572 - learning_rate: 0.0010
# Epoch 58/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1351 - val_loss: 0.2984 - val_mean_squared_error: 0.1572 - learning_rate: 0.0010
# Epoch 59/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2690 - mean_squared_error: 0.1351 - val_loss: 0.2984 - val_mean_squared_error: 0.1572 - learning_rate: 0.0010
# Epoch 60/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2689 - mean_squared_error: 0.1351 - val_loss: 0.2984 - val_mean_squared_error: 0.1572 - learning_rate: 0.0010
# Epoch 61/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2985 - val_mean_squared_error: 0.1570 - learning_rate: 0.0010
# Epoch 62/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1351 - val_loss: 0.2990 - val_mean_squared_error: 0.1571 - learning_rate: 0.0010
# Epoch 63/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1349 - val_loss: 0.2980 - val_mean_squared_error: 0.1569 - learning_rate: 0.0010
# Epoch 64/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2988 - val_mean_squared_error: 0.1569 - learning_rate: 0.0010
# Epoch 65/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2996 - val_mean_squared_error: 0.1574 - learning_rate: 0.0010
# Epoch 66/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1349 - val_loss: 0.2993 - val_mean_squared_error: 0.1573 - learning_rate: 0.0010
# Epoch 67/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1349 - val_loss: 0.2994 - val_mean_squared_error: 0.1572 - learning_rate: 0.0010
# Epoch 68/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1348 - val_loss: 0.2999 - val_mean_squared_error: 0.1577 - learning_rate: 0.0010
# Epoch 69/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1348 - val_loss: 0.2987 - val_mean_squared_error: 0.1569 - learning_rate: 0.0010
# Epoch 70/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1348 - val_loss: 0.2994 - val_mean_squared_error: 0.1574 - learning_rate: 0.0010
# Epoch 71/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1348 - val_loss: 0.3016 - val_mean_squared_error: 0.1570 - learning_rate: 5.0000e-04
# Epoch 72/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1349 - val_loss: 0.3030 - val_mean_squared_error: 0.1583 - learning_rate: 5.0000e-04
# Epoch 73/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2685 - mean_squared_error: 0.1346 - val_loss: 0.3035 - val_mean_squared_error: 0.1583 - learning_rate: 5.0000e-04
# Epoch 74/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1347 - val_loss: 0.3024 - val_mean_squared_error: 0.1576 - learning_rate: 5.0000e-04
# Epoch 75/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1347 - val_loss: 0.3021 - val_mean_squared_error: 0.1573 - learning_rate: 5.0000e-04
# Epoch 76/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2684 - mean_squared_error: 0.1347 - val_loss: 0.3013 - val_mean_squared_error: 0.1570 - learning_rate: 5.0000e-04
# Epoch 77/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.3010 - val_mean_squared_error: 0.1568 - learning_rate: 5.0000e-04
# Epoch 78/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2684 - mean_squared_error: 0.1346 - val_loss: 0.3011 - val_mean_squared_error: 0.1570 - learning_rate: 5.0000e-04
# Epoch 79/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2683 - mean_squared_error: 0.1346 - val_loss: 0.3008 - val_mean_squared_error: 0.1567 - learning_rate: 5.0000e-04
# Epoch 80/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.3007 - val_mean_squared_error: 0.1567 - learning_rate: 5.0000e-04
# Epoch 81/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.3002 - val_mean_squared_error: 0.1563 - learning_rate: 5.0000e-04
# Epoch 82/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.3000 - val_mean_squared_error: 0.1563 - learning_rate: 5.0000e-04
# Epoch 83/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.3007 - val_mean_squared_error: 0.1565 - learning_rate: 5.0000e-04
# Epoch 84/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.3006 - val_mean_squared_error: 0.1567 - learning_rate: 5.0000e-04
# Epoch 85/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.3004 - val_mean_squared_error: 0.1563 - learning_rate: 5.0000e-04
# Epoch 86/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2996 - val_mean_squared_error: 0.1559 - learning_rate: 5.0000e-04
# Epoch 87/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.3004 - val_mean_squared_error: 0.1563 - learning_rate: 5.0000e-04
# Epoch 88/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2996 - val_mean_squared_error: 0.1560 - learning_rate: 5.0000e-04
# Epoch 89/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.3001 - val_mean_squared_error: 0.1562 - learning_rate: 5.0000e-04
# Epoch 90/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.3003 - val_mean_squared_error: 0.1563 - learning_rate: 5.0000e-04
# Epoch 91/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.3010 - val_mean_squared_error: 0.1566 - learning_rate: 5.0000e-04
# Epoch 92/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.3001 - val_mean_squared_error: 0.1563 - learning_rate: 5.0000e-04
# Epoch 93/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2681 - mean_squared_error: 0.1344 - val_loss: 0.3002 - val_mean_squared_error: 0.1563 - learning_rate: 5.0000e-04
# Epoch 94/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.2998 - val_mean_squared_error: 0.1561 - learning_rate: 5.0000e-04
# Epoch 95/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2680 - mean_squared_error: 0.1345 - val_loss: 0.3002 - val_mean_squared_error: 0.1562 - learning_rate: 5.0000e-04
# Epoch 96/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2692 - mean_squared_error: 0.1353 - val_loss: 0.2899 - val_mean_squared_error: 0.1524 - learning_rate: 2.5000e-04
# Epoch 97/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1350 - val_loss: 0.2900 - val_mean_squared_error: 0.1523 - learning_rate: 2.5000e-04
# Epoch 98/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1350 - val_loss: 0.2900 - val_mean_squared_error: 0.1522 - learning_rate: 2.5000e-04
# Epoch 99/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1349 - val_loss: 0.2901 - val_mean_squared_error: 0.1520 - learning_rate: 2.5000e-04
# Epoch 100/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1349 - val_loss: 0.2904 - val_mean_squared_error: 0.1522 - learning_rate: 2.5000e-04
# Epoch 101/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1349 - val_loss: 0.2903 - val_mean_squared_error: 0.1521 - learning_rate: 2.5000e-04
# Epoch 102/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1349 - val_loss: 0.2904 - val_mean_squared_error: 0.1521 - learning_rate: 2.5000e-04
# Epoch 103/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1349 - val_loss: 0.2901 - val_mean_squared_error: 0.1521 - learning_rate: 2.5000e-04
# Epoch 104/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1349 - val_loss: 0.2901 - val_mean_squared_error: 0.1520 - learning_rate: 2.5000e-04
# Epoch 105/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2685 - mean_squared_error: 0.1349 - val_loss: 0.2899 - val_mean_squared_error: 0.1520 - learning_rate: 2.5000e-04
# Epoch 106/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2684 - mean_squared_error: 0.1348 - val_loss: 0.2899 - val_mean_squared_error: 0.1520 - learning_rate: 2.5000e-04
# Epoch 107/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2684 - mean_squared_error: 0.1349 - val_loss: 0.2897 - val_mean_squared_error: 0.1519 - learning_rate: 2.5000e-04
# Epoch 108/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2684 - mean_squared_error: 0.1348 - val_loss: 0.2898 - val_mean_squared_error: 0.1519 - learning_rate: 2.5000e-04
# Epoch 109/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2684 - mean_squared_error: 0.1348 - val_loss: 0.2895 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 110/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2684 - mean_squared_error: 0.1348 - val_loss: 0.2896 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 111/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2896 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 112/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2684 - mean_squared_error: 0.1347 - val_loss: 0.2895 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 113/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2897 - val_mean_squared_error: 0.1519 - learning_rate: 2.5000e-04
# Epoch 114/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2897 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 115/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2896 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 116/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2895 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 117/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2896 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 118/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2896 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 119/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2895 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 120/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2892 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 121/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1346 - val_loss: 0.2894 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 122/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2894 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 123/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2683 - mean_squared_error: 0.1347 - val_loss: 0.2894 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 124/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2894 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 125/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2893 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 126/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2895 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 127/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2894 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 128/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2894 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 129/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2900 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 130/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2896 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 131/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2894 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 132/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2894 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 133/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2895 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 134/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2896 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 135/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2896 - val_mean_squared_error: 0.1515 - learning_rate: 2.5000e-04
# Epoch 136/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2895 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 137/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1346 - val_loss: 0.2897 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 138/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2681 - mean_squared_error: 0.1346 - val_loss: 0.2895 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 139/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1345 - val_loss: 0.2898 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 140/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2681 - mean_squared_error: 0.1346 - val_loss: 0.2897 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 141/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2896 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 142/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2897 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 143/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2897 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 144/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2895 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 145/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2682 - mean_squared_error: 0.1346 - val_loss: 0.2894 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 146/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2693 - mean_squared_error: 0.1356 - val_loss: 0.2830 - val_mean_squared_error: 0.1511 - learning_rate: 1.2500e-04
# Epoch 147/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1354 - val_loss: 0.2841 - val_mean_squared_error: 0.1503 - learning_rate: 1.2500e-04
# Epoch 148/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1352 - val_loss: 0.2854 - val_mean_squared_error: 0.1502 - learning_rate: 1.2500e-04
# Epoch 149/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2859 - val_mean_squared_error: 0.1502 - learning_rate: 1.2500e-04
# Epoch 150/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2860 - val_mean_squared_error: 0.1502 - learning_rate: 1.2500e-04
# Epoch 151/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2856 - val_mean_squared_error: 0.1501 - learning_rate: 1.2500e-04
# Epoch 152/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2850 - val_mean_squared_error: 0.1500 - learning_rate: 1.2500e-04
# Epoch 153/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2845 - val_mean_squared_error: 0.1500 - learning_rate: 1.2500e-04
# Epoch 154/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2841 - val_mean_squared_error: 0.1501 - learning_rate: 1.2500e-04
# Epoch 155/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1354 - val_loss: 0.2837 - val_mean_squared_error: 0.1501 - learning_rate: 1.2500e-04
# Epoch 156/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1354 - val_loss: 0.2835 - val_mean_squared_error: 0.1502 - learning_rate: 1.2500e-04
# Epoch 157/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1354 - val_loss: 0.2833 - val_mean_squared_error: 0.1502 - learning_rate: 1.2500e-04
# Epoch 158/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1352 - val_loss: 0.2836 - val_mean_squared_error: 0.1501 - learning_rate: 1.2500e-04
# Epoch 159/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1351 - val_loss: 0.2841 - val_mean_squared_error: 0.1499 - learning_rate: 1.2500e-04
# Epoch 160/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1350 - val_loss: 0.2845 - val_mean_squared_error: 0.1498 - learning_rate: 1.2500e-04
# Epoch 161/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1350 - val_loss: 0.2845 - val_mean_squared_error: 0.1498 - learning_rate: 1.2500e-04
# Epoch 162/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2845 - val_mean_squared_error: 0.1498 - learning_rate: 1.2500e-04
# Epoch 163/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2844 - val_mean_squared_error: 0.1498 - learning_rate: 1.2500e-04
# Epoch 164/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2840 - val_mean_squared_error: 0.1497 - learning_rate: 1.2500e-04
# Epoch 165/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2837 - val_mean_squared_error: 0.1498 - learning_rate: 1.2500e-04
# Epoch 166/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2834 - val_mean_squared_error: 0.1498 - learning_rate: 1.2500e-04
# Epoch 167/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2837 - val_mean_squared_error: 0.1498 - learning_rate: 1.2500e-04
# Epoch 168/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1351 - val_loss: 0.2840 - val_mean_squared_error: 0.1499 - learning_rate: 1.2500e-04
# Epoch 169/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1350 - val_loss: 0.2842 - val_mean_squared_error: 0.1498 - learning_rate: 1.2500e-04
# Epoch 170/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1350 - val_loss: 0.2844 - val_mean_squared_error: 0.1497 - learning_rate: 1.2500e-04
# Epoch 171/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2685 - mean_squared_error: 0.1350 - val_loss: 0.2844 - val_mean_squared_error: 0.1497 - learning_rate: 1.2500e-04
# Epoch 172/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2694 - mean_squared_error: 0.1355 - val_loss: 0.2806 - val_mean_squared_error: 0.1502 - learning_rate: 6.2500e-05
# Epoch 173/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2690 - mean_squared_error: 0.1354 - val_loss: 0.2806 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 174/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2690 - mean_squared_error: 0.1354 - val_loss: 0.2806 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 175/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2690 - mean_squared_error: 0.1354 - val_loss: 0.2805 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 176/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2690 - mean_squared_error: 0.1354 - val_loss: 0.2805 - val_mean_squared_error: 0.1501 - learning_rate: 6.2500e-05
# Epoch 177/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2805 - val_mean_squared_error: 0.1501 - learning_rate: 6.2500e-05
# Epoch 178/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1355 - val_loss: 0.2805 - val_mean_squared_error: 0.1501 - learning_rate: 6.2500e-05
# Epoch 179/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2689 - mean_squared_error: 0.1355 - val_loss: 0.2805 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 180/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1355 - val_loss: 0.2805 - val_mean_squared_error: 0.1501 - learning_rate: 6.2500e-05
# Epoch 181/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1355 - val_loss: 0.2804 - val_mean_squared_error: 0.1501 - learning_rate: 6.2500e-05
# Epoch 182/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1355 - val_loss: 0.2804 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 183/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2689 - mean_squared_error: 0.1355 - val_loss: 0.2804 - val_mean_squared_error: 0.1501 - learning_rate: 6.2500e-05
# Epoch 184/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2804 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 185/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2803 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 186/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2803 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 187/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2803 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 188/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2803 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 189/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2802 - val_mean_squared_error: 0.1500 - learning_rate: 6.2500e-05
# Epoch 190/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2802 - val_mean_squared_error: 0.1499 - learning_rate: 6.2500e-05
# Epoch 191/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2802 - val_mean_squared_error: 0.1499 - learning_rate: 6.2500e-05
# Epoch 192/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2802 - val_mean_squared_error: 0.1499 - learning_rate: 6.2500e-05
# Epoch 193/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2802 - val_mean_squared_error: 0.1499 - learning_rate: 6.2500e-05
# Epoch 194/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2802 - val_mean_squared_error: 0.1499 - learning_rate: 6.2500e-05
# Epoch 195/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2803 - val_mean_squared_error: 0.1499 - learning_rate: 6.2500e-05
# Epoch 196/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2689 - mean_squared_error: 0.1353 - val_loss: 0.2803 - val_mean_squared_error: 0.1498 - learning_rate: 6.2500e-05
# Epoch 197/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1354 - val_loss: 0.2803 - val_mean_squared_error: 0.1498 - learning_rate: 6.2500e-05
# Epoch 198/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2803 - val_mean_squared_error: 0.1498 - learning_rate: 6.2500e-05
# Epoch 199/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1353 - val_loss: 0.2802 - val_mean_squared_error: 0.1498 - learning_rate: 6.2500e-05
# Epoch 200/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2802 - val_mean_squared_error: 0.1498 - learning_rate: 6.2500e-05
# Epoch 201/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2802 - val_mean_squared_error: 0.1498 - learning_rate: 6.2500e-05
# Epoch 202/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2803 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 203/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2802 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 204/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2801 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 205/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2801 - val_mean_squared_error: 0.1498 - learning_rate: 6.2500e-05
# Epoch 206/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2801 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 207/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2802 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 208/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2801 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 209/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2801 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 210/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1353 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 211/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2801 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 212/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2801 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 213/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2801 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 214/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 215/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 216/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 217/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 218/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 219/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 220/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 221/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 222/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 223/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 224/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 225/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 226/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 227/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 228/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1497 - learning_rate: 6.2500e-05
# Epoch 229/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 230/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 231/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 232/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2800 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 233/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 234/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 235/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 236/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 237/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 238/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1496 - learning_rate: 6.2500e-05
# Epoch 239/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 240/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 241/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 242/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2799 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 243/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 244/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 245/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1495 - learning_rate: 6.2500e-05
# Epoch 246/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 247/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 248/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 249/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 250/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 251/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 252/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 253/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 254/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 255/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1352 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 256/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 257/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 258/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2798 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 259/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 260/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1494 - learning_rate: 6.2500e-05
# Epoch 261/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 262/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 263/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 264/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 265/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 266/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 267/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 268/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 269/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 270/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 271/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 272/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 273/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 274/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 275/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 276/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 277/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 278/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 279/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 280/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 281/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 282/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 283/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2687 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 284/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1492 - learning_rate: 6.2500e-05
# Epoch 285/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1493 - learning_rate: 6.2500e-05
# Epoch 286/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1492 - learning_rate: 6.2500e-05
# Epoch 287/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2686 - mean_squared_error: 0.1351 - val_loss: 0.2797 - val_mean_squared_error: 0.1492 - learning_rate: 6.2500e-05
# Epoch 288/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2690 - mean_squared_error: 0.1351 - val_loss: 0.2789 - val_mean_squared_error: 0.1497 - learning_rate: 3.1250e-05
# Epoch 289/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2689 - mean_squared_error: 0.1352 - val_loss: 0.2789 - val_mean_squared_error: 0.1497 - learning_rate: 3.1250e-05
# Epoch 290/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2689 - mean_squared_error: 0.1352 - val_loss: 0.2789 - val_mean_squared_error: 0.1497 - learning_rate: 3.1250e-05
# Epoch 291/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1351 - val_loss: 0.2789 - val_mean_squared_error: 0.1496 - learning_rate: 3.1250e-05
# Epoch 292/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1351 - val_loss: 0.2789 - val_mean_squared_error: 0.1496 - learning_rate: 3.1250e-05
# Epoch 293/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1351 - val_loss: 0.2788 - val_mean_squared_error: 0.1496 - learning_rate: 3.1250e-05
# Epoch 294/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1351 - val_loss: 0.2788 - val_mean_squared_error: 0.1496 - learning_rate: 3.1250e-05
# Epoch 295/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1351 - val_loss: 0.2788 - val_mean_squared_error: 0.1496 - learning_rate: 3.1250e-05
# ...
# Epoch 458/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 459/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 460/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 461/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 462/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 463/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 464/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 465/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 466/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 467/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 468/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 469/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 470/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 471/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 472/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 473/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 474/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 475/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 476/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 477/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 478/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 479/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 9.7656e-07
# Epoch 480/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 481/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 482/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 483/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 484/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 485/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 486/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 487/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 488/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 489/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 490/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 491/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 492/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 493/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 494/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 495/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 496/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 497/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 498/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 499/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 500/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 501/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 502/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 503/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 504/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 4.8828e-07
# Epoch 505/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1350 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 506/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 507/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 508/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 509/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 510/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 511/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 512/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 513/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 514/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 515/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 516/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 517/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 518/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 519/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 520/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 521/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 522/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 523/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 524/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 525/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 526/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 527/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 528/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 529/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 2.4414e-07
# Epoch 530/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 531/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 532/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 533/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 534/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 535/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 536/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 537/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 538/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 539/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 540/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 541/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 542/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 543/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 544/750
# 1088/1088 - 9s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 545/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 546/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 547/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 548/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 549/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 550/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 551/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 552/750
# 1088/1088 - 8s - 8ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 553/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07
# Epoch 554/750
# 1088/1088 - 8s - 7ms/step - loss: 0.2688 - mean_squared_error: 0.1349 - val_loss: 0.2782 - val_mean_squared_error: 0.1491 - learning_rate: 1.2207e-07

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds_repeat.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds_repeat.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Train MAE (standardized): 0.26882596401081876
# Valid MAE (standardized): 0.27818934925094296
# Train MAE: 2.893746357570724
# Valid MAE: 2.994537462337537
