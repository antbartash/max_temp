# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
import os
import random
import datetime

np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# # Data

# %%
data_path = 'https://raw.githubusercontent.com/antbartash/max_temp/master/data/data2.csv'
data = pd.read_csv(data_path, index_col=0)
data['DATE'] = data['DATE'].astype('datetime64[ns]')

print(data.shape)
data.head()
# Out:
# (40898, 4)
#        STATION                        NAME       DATE  TMAX
# 0  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-01  12.2
# 1  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-02  10.6
# 2  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-03   8.3
# 3  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-04   6.1
# 4  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-05   6.1

# %%
# only 1 station
# data = data[data['STATION'] == 'USW00012916'].reset_index(drop=True)
# data = data[['DATE', 'TMAX']]

data = data[['STATION', 'DATE', 'TMAX']]

# add sine and cosine transforms to add periodicality
doy = data['DATE'].dt.dayofyear / 365.25
data['Year_sin'] = np.sin(doy * 2 * np.pi)
data['Year_cos'] = np.cos(doy * 2 * np.pi)

print(data.shape)
data.head()
# Out:
# (40898, 5)
#        STATION       DATE  TMAX  Year_sin  Year_cos
# 0  USW00012916 2010-01-01  12.2  0.017202  0.999852
# 1  USW00012916 2010-01-02  10.6  0.034398  0.999408
# 2  USW00012916 2010-01-03   8.3  0.051584  0.998669
# 3  USW00012916 2010-01-04   6.1  0.068755  0.997634
# 4  USW00012916 2010-01-05   6.1  0.085906  0.996303

# %%
# Station TMAX plot
STATION_IDX = 2
data_plot = data[data['STATION'] == data['STATION'].unique()[STATION_IDX]].copy()

fix, ax = plt.subplots(figsize=(12, 2))
ax.plot(data_plot['DATE'], data_plot['TMAX'], label='TMAX')

ax2 = ax.twinx()
ax2.plot(np.nan, np.nan, label='TMAX')
ax2.plot(data_plot['DATE'], data_plot['Year_sin'], label='Year_sin')
ax2.plot(data_plot['DATE'], data_plot['Year_cos'], label='Year_cos')

ax.set_ylabel('TMAX')
ax2.set_ylabel('sin, cos')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Station TMAX plot
PLOT_YEAR = 2010

fix, ax = plt.subplots(figsize=(12, 2))
ax.plot(data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'DATE'],
        data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'TMAX'],
        label='TMAX')

ax2 = ax.twinx()
ax2.plot(np.nan, np.nan, label='TMAX')
ax2.plot(data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'DATE'],
        data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'Year_sin'],
        label='Year_sin')
ax2.plot(data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'DATE'],
        data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'Year_cos'],
        label='Year_cos')

ax.set_ylabel('TMAX')
ax2.set_ylabel('sin, cos')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Train/valid/test split

# %%
train_df = data.loc[data['DATE'].dt.year <= 2021].reset_index(drop=True).copy()
valid_df = data.loc[data['DATE'].dt.year == 2022].reset_index(drop=True).copy()
test_df = data.loc[data['DATE'].dt.year == 2023].reset_index(drop=True).copy()

print(f'Train: {train_df.shape}')
print(f'Valid: {valid_df.shape}')
print(f'Test: {test_df.shape}')
# Out:
# Train: (35058, 5)
# Valid: (2920, 5)
# Test: (2920, 5)

# %% [markdown]
# ## Scaling

# %%
# train_df.set_index('DATE', inplace=True)
# valid_df.set_index('DATE', inplace=True)
# test_df.set_index('DATE', inplace=True)
train_df.drop(columns=['DATE'], inplace=True)
valid_df.drop(columns=['DATE'], inplace=True)
test_df.drop(columns=['DATE'], inplace=True)

# keep station to drop mixed windows later (encode to avoid errors from scaler)
encoder = OrdinalEncoder()
encoder.fit(train_df[['STATION']])
train_df['STATION'] = encoder.transform(train_df[['STATION']])[:, 0]
valid_df['STATION'] = encoder.transform(valid_df[['STATION']])[:, 0]
test_df['STATION'] = encoder.transform(test_df[['STATION']])[:, 0]

# scaling
scaler = StandardScaler()
scaler.fit(train_df)
train_df = pd.DataFrame(scaler.transform(train_df),
                        columns=scaler.feature_names_in_, index=train_df.index)
valid_df = pd.DataFrame(scaler.transform(valid_df),
                        columns=scaler.feature_names_in_, index=valid_df.index)
test_df = pd.DataFrame(scaler.transform(test_df),
                       columns=scaler.feature_names_in_, index=test_df.index)

train_df.head()
# Out:
#     STATION      TMAX  Year_sin  Year_cos
# 0 -1.091014 -0.747812  0.024401  1.414059
# 1 -1.091014 -0.896450  0.048721  1.413431
# 2 -1.091014 -1.110117  0.073027  1.412386
# 3 -1.091014 -1.314495  0.097312  1.410922
# 4 -1.091014 -1.314495  0.121567  1.409041

# %%
def tmax_inverse_transform(arr, scale=scaler.scale_[1], mean=scaler.mean_[1]):
    return arr * scale + mean

# %% [markdown]
# ## TF Dataset

# %%
def create_dataset(data, target_col, source_col, seq_length):
  input_data = data[:-seq_length]
  # adding source_col to target allows to drop samples with features and target
  # from diff sources (source_col will be dropped from the target later)
  targets = data[[source_col, target_col]][seq_length:]
  dataset = tf.keras.preprocessing.timeseries_dataset_from_array(
      input_data, targets,
      sequence_length=seq_length,
      sequence_stride=1,
      batch_size=32,
      shuffle=False,
      seed=42
    )
  for batch in dataset:
    inputs, targets = batch
    assert np.array_equal(inputs[0], data[:seq_length])  # First sequence: steps [0-13]
    # Corresponding target: step 14
    assert np.array_equal(targets[0, 1], data.loc[seq_length, target_col])
    break
  return dataset

train_ds = create_dataset(train_df, 'TMAX', 'STATION', 14)
valid_ds = create_dataset(valid_df, 'TMAX', 'STATION', 14)
test_ds = create_dataset(test_df, 'TMAX', 'STATION', 14)

# %% [markdown]
# ### Check

# %%
train_df.head(15)
# Out:
#      STATION      TMAX  Year_sin  Year_cos
# 0  -1.091014 -0.747812  0.024401  1.414059
# 1  -1.091014 -0.896450  0.048721  1.413431
# 2  -1.091014 -1.110117  0.073027  1.412386
# 3  -1.091014 -1.314495  0.097312  1.410922
# 4  -1.091014 -1.314495  0.121567  1.409041
# 5  -1.091014 -1.110117  0.145787  1.406742
# 6  -1.091014 -0.329766  0.169963  1.404028
# 7  -1.091014 -1.723250  0.194089  1.400898
# 8  -1.091014 -1.621062  0.218158  1.397354
# 9  -1.091014 -1.472423  0.242163  1.393396
# 10 -1.091014 -1.007929  0.266095  1.389025
# 11 -1.091014 -0.543434  0.289949  1.384244
# 12 -1.091014 -0.952189  0.313717  1.379054
# 13 -1.091014 -0.385506  0.337393  1.373455
# 14 -1.091014 -0.487695  0.360968  1.367449

# %%
list(train_ds.unbatch().as_numpy_iterator())[0]
# Out:
# (array([[-1.09101358, -0.74781154,  0.02440109,  1.41405912],
#         [-1.09101358, -0.89644984,  0.0487214 ,  1.41343147],
#         [-1.09101358, -1.1101174 ,  0.07302732,  1.41238559],
#         [-1.09101358, -1.31449507,  0.09731164,  1.4109218 ],
#         [-1.09101358, -1.31449507,  0.1215672 ,  1.40904052],
#         [-1.09101358, -1.1101174 ,  0.1457868 ,  1.40674231],
#         [-1.09101358, -0.32976632,  0.16996328,  1.40402786],
#         [-1.09101358, -1.72325039,  0.19408949,  1.40089796],
#         [-1.09101358, -1.62106156,  0.21815828,  1.39735354],
#         [-1.09101358, -1.47242326,  0.24216255,  1.39339566],
#         [-1.09101358, -1.00792857,  0.26609517,  1.38902547],
#         [-1.09101358, -0.54343388,  0.28994907,  1.38424428],
#         [-1.09101358, -0.95218921,  0.3137172 ,  1.3790535 ],
#         [-1.09101358, -0.38550568,  0.33739251,  1.37345467]]),
#  array([-1.09101358, -0.48769452]))

# %% [markdown]
# ## Different sources

# %% [markdown]
# ### Problem

# %%
# some samples has info from different sources in features (the first column)
list(train_ds.unbatch().as_numpy_iterator())[4382]
# Out:
# (array([[-1.09101358,  0.74786136, -0.00600858,  1.41425528],
#         [ 1.52765803, -1.47242326,  0.02440109,  1.41405912],
#         [ 1.52765803, -1.77898976,  0.0487214 ,  1.41343147],
#         [ 1.52765803, -2.40141264,  0.07302732,  1.41238559],
#         [ 1.52765803, -1.98336742,  0.09731164,  1.4109218 ],
#         [ 1.52765803, -1.98336742,  0.1215672 ,  1.40904052],
#         [ 1.52765803, -1.77898976,  0.1457868 ,  1.40674231],
#         [ 1.52765803, -1.62106156,  0.16996328,  1.40402786],
#         [ 1.52765803, -1.82543923,  0.19408949,  1.40089796],
#         [ 1.52765803, -1.98336742,  0.21815828,  1.39735354],
#         [ 1.52765803, -2.08555625,  0.24216255,  1.39339566],
#         [ 1.52765803, -1.93691795,  0.26609517,  1.38902547],
#         [ 1.52765803, -1.72325039,  0.28994907,  1.38424428],
#         [ 1.52765803, -1.72325039,  0.3137172 ,  1.3790535 ]]),
#  array([ 1.52765803, -1.36094454]))

# %%
# some samples has info from different sources in target (the first column)
list(train_ds.unbatch().as_numpy_iterator())[4369]
# Out:
# (array([[-1.09101358,  0.5434837 , -0.31949784,  1.37769199],
#         [-1.09101358, -0.12538866, -0.29575226,  1.38298493],
#         [-1.09101358, -0.89644984, -0.27191914,  1.38786865],
#         [-1.09101358, -0.85000038, -0.24800554,  1.39234171],
#         [-1.09101358, -0.32976632, -0.22401852,  1.39640279],
#         [-1.09101358, -0.12538866, -0.19996519,  1.40005068],
#         [-1.09101358,  0.44129487, -0.17585266,  1.4032843 ],
#         [-1.09101358,  0.49703423, -0.15168808,  1.40610269],
#         [-1.09101358,  0.44129487, -0.12747859,  1.40850503],
#         [-1.09101358,  0.5434837 , -0.10323135,  1.4104906 ],
#         [-1.09101358,  0.5434837 , -0.07895354,  1.41205881],
#         [-1.09101358,  0.64567253, -0.05465235,  1.4132092 ],
#         [-1.09101358,  0.80360072, -0.03033496,  1.41394143],
#         [-1.09101358,  0.74786136, -0.00600858,  1.41425528]]),
#  array([ 1.52765803, -1.47242326]))

# %%
def filter_mixed_windows(dataset):
    def is_valid_window(inputs, targets):
        # Extract the first feature (station) from inputs and targets
        input_station_ids = inputs[:, :, 0]  # Shape: (batch_size, sequence_length)
        target_station_ids = targets[:, 0]  # Shape: (batch_size)

        # Check if all station IDs in the inputs are the same
        input_same_station = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == tf.reduce_min(input_station_ids, axis=1))

        # Check if the target's station ID matches the input station ID
        target_matches_input = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == target_station_ids)

        # Only keep windows where both conditions are true
        return tf.logical_and(input_same_station, target_matches_input)

    # Filter the dataset
    filtered_dataset = dataset.filter(is_valid_window)
    return filtered_dataset

train_ds = filter_mixed_windows(train_ds)
valid_ds = filter_mixed_windows(valid_ds)
test_ds = filter_mixed_windows(test_ds)

# %% [markdown]
# ### Check

# %%
# different sources problem (features) fixed
list(filter_mixed_windows(train_ds).unbatch().as_numpy_iterator())[4382]
# Out:
# (array([[ 1.52765803, -1.72325039,  0.73986523,  1.20536033],
#         [ 1.52765803, -1.82543923,  0.76048949,  1.19245726],
#         [ 1.52765803, -1.51887273,  0.78088874,  1.17920136],
#         [ 1.52765803, -1.62106156,  0.80105693,  1.16559655],
#         [ 1.52765803, -1.67680093,  0.8209881 ,  1.15164684],
#         [ 1.52765803, -1.82543923,  0.84067634,  1.13735638],
#         [ 1.52765803, -1.77898976,  0.86011584,  1.12272938],
#         [ 1.52765803, -1.62106156,  0.87930084,  1.10777018],
#         [ 1.52765803, -1.36094454,  0.89822566,  1.0924832 ],
#         [ 1.52765803, -1.77898976,  0.9168847 ,  1.07687297],
#         [ 1.52765803, -1.62106156,  0.93527244,  1.06094411],
#         [ 1.52765803, -1.62106156,  0.95338344,  1.04470133],
#         [ 1.52765803, -1.88117859,  0.97121234,  1.02814943],
#         [ 1.52765803, -1.51887273,  0.98875387,  1.01129331]]),
#  array([ 1.52765803, -1.47242326]))

# %%
list(train_ds.unbatch().as_numpy_iterator())[4369]
# Out:
# (array([[ 1.52765803, -1.05437804,  0.45413276,  1.33940188],
#         [ 1.52765803, -1.4166839 ,  0.47710518,  1.33139371],
#         [ 1.52765803, -1.4166839 ,  0.49993644,  1.32299158],
#         [ 1.52765803, -1.2587557 ,  0.52261978,  1.31419799],
#         [ 1.52765803, -1.47242326,  0.5451485 ,  1.30501554],
#         [ 1.52765803, -0.95218921,  0.56751591,  1.29544695],
#         [ 1.52765803, -0.58988335,  0.58971541,  1.28549504],
#         [ 1.52765803, -1.00792857,  0.61174043,  1.27516276],
#         [ 1.52765803, -1.51887273,  0.63358445,  1.26445317],
#         [ 1.52765803, -1.36094454,  0.65524099,  1.25336944],
#         [ 1.52765803, -2.34567328,  0.67670367,  1.24191484],
#         [ 1.52765803, -2.50360148,  0.69796612,  1.23009278],
#         [ 1.52765803, -1.98336742,  0.71902205,  1.21790674],
#         [ 1.52765803, -1.72325039,  0.73986523,  1.20536033]]),
#  array([ 1.52765803, -1.82543923]))

# %% [markdown]
# ## Drop source column

# %%
def drop_first_column(feature, label):
    feature = feature[:, :, 1:]  # Keep all rows, drop the first column
    label = label[:, 1:]    # Keep all rows, drop the first column
    return feature, label

train_ds = train_ds.map(drop_first_column)
valid_ds = valid_ds.map(drop_first_column)
test_ds = test_ds.map(drop_first_column)

# %% [markdown]
# # Final dataset

# %%
for element in train_ds.take(1):
    print(f'Features batch shape: {element[0].shape}')
    print(f'Target batch shape: {element[1].shape}')
# Out:
# Features batch shape: (32, 14, 3)
# Target batch shape: (32, 1)

# %%
# 1st row features
element[0][0]
# Out:
# <tf.Tensor: shape=(14, 3), dtype=float64, numpy=
# array([[-0.74781154,  0.02440109,  1.41405912],
#        [-0.89644984,  0.0487214 ,  1.41343147],
#        [-1.1101174 ,  0.07302732,  1.41238559],
#        [-1.31449507,  0.09731164,  1.4109218 ],
#        [-1.31449507,  0.1215672 ,  1.40904052],
#        [-1.1101174 ,  0.1457868 ,  1.40674231],
#        [-0.32976632,  0.16996328,  1.40402786],
#        [-1.72325039,  0.19408949,  1.40089796],
#        [-1.62106156,  0.21815828,  1.39735354],
#        [-1.47242326,  0.24216255,  1.39339566],
#        [-1.00792857,  0.26609517,  1.38902547],
#        [-0.54343388,  0.28994907,  1.38424428],
#        [-0.95218921,  0.3137172 ,  1.3790535 ],
#        [-0.38550568,  0.33739251,  1.37345467]])>

# %%
# 1st row target
element[1][0]
# Out:
# <tf.Tensor: shape=(1,), dtype=float64, numpy=array([-0.48769452])>

# %% [markdown]
# # Baseline/test models

# %%
BATCH_SIZE = 128
train_ds = train_ds.unbatch().batch(BATCH_SIZE)
valid_ds = valid_ds.unbatch().batch(BATCH_SIZE)
test_ds = test_ds.unbatch().batch(BATCH_SIZE)

train_num_batches = len(list(train_ds))
valid_num_batches = len(list(valid_ds))
test_num_batches = len(list(test_ds))
print(train_num_batches, valid_num_batches, test_num_batches)

train_ds = train_ds.repeat()
valid_ds = valid_ds.repeat()
test_ds = test_ds.repeat()
# Out:
# 272 21 21

# %% [markdown]
# ## Model 1

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    patience=100, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=25
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.01)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds, epochs=1000, validation_data=valid_ds,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=1
)
# Out:
# Epoch 1/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.4558 - mean_squared_error: 0.4022 - val_loss: 0.3242 - val_mean_squared_error: 0.1821 - learning_rate: 0.0100
# Epoch 2/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2766 - mean_squared_error: 0.1365 - val_loss: 0.3194 - val_mean_squared_error: 0.1775 - learning_rate: 0.0100
# Epoch 3/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2763 - mean_squared_error: 0.1349 - val_loss: 0.3095 - val_mean_squared_error: 0.1682 - learning_rate: 0.0100
# Epoch 4/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2737 - mean_squared_error: 0.1331 - val_loss: 0.3066 - val_mean_squared_error: 0.1669 - learning_rate: 0.0100
# Epoch 5/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2662 - mean_squared_error: 0.1300 - val_loss: 0.3037 - val_mean_squared_error: 0.1634 - learning_rate: 0.0100
# Epoch 6/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2664 - mean_squared_error: 0.1291 - val_loss: 0.2976 - val_mean_squared_error: 0.1590 - learning_rate: 0.0100
# Epoch 7/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2721 - mean_squared_error: 0.1347 - val_loss: 0.3045 - val_mean_squared_error: 0.1601 - learning_rate: 0.0100
# Epoch 8/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2630 - mean_squared_error: 0.1269 - val_loss: 0.2939 - val_mean_squared_error: 0.1567 - learning_rate: 0.0100
# Epoch 9/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2691 - mean_squared_error: 0.1341 - val_loss: 0.2947 - val_mean_squared_error: 0.1553 - learning_rate: 0.0100
# Epoch 10/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2611 - mean_squared_error: 0.1258 - val_loss: 0.2934 - val_mean_squared_error: 0.1553 - learning_rate: 0.0100
# Epoch 11/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2636 - mean_squared_error: 0.1280 - val_loss: 0.3005 - val_mean_squared_error: 0.1593 - learning_rate: 0.0100
# Epoch 12/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2635 - mean_squared_error: 0.1265 - val_loss: 0.3025 - val_mean_squared_error: 0.1585 - learning_rate: 0.0100
# Epoch 13/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2645 - mean_squared_error: 0.1286 - val_loss: 0.2940 - val_mean_squared_error: 0.1547 - learning_rate: 0.0100
# Epoch 14/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2689 - mean_squared_error: 0.1341 - val_loss: 0.2974 - val_mean_squared_error: 0.1578 - learning_rate: 0.0100
# Epoch 15/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2662 - mean_squared_error: 0.1295 - val_loss: 0.3005 - val_mean_squared_error: 0.1622 - learning_rate: 0.0100
# Epoch 16/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2723 - mean_squared_error: 0.1341 - val_loss: 0.2930 - val_mean_squared_error: 0.1546 - learning_rate: 0.0100
# Epoch 17/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2585 - mean_squared_error: 0.1252 - val_loss: 0.2886 - val_mean_squared_error: 0.1547 - learning_rate: 0.0100
# Epoch 18/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2571 - mean_squared_error: 0.1245 - val_loss: 0.2965 - val_mean_squared_error: 0.1565 - learning_rate: 0.0100
# Epoch 19/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2655 - mean_squared_error: 0.1301 - val_loss: 0.2958 - val_mean_squared_error: 0.1592 - learning_rate: 0.0100
# Epoch 20/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2563 - mean_squared_error: 0.1237 - val_loss: 0.2940 - val_mean_squared_error: 0.1581 - learning_rate: 0.0100
# Epoch 21/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2698 - mean_squared_error: 0.1330 - val_loss: 0.2989 - val_mean_squared_error: 0.1598 - learning_rate: 0.0100
# Epoch 22/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2600 - mean_squared_error: 0.1257 - val_loss: 0.2936 - val_mean_squared_error: 0.1546 - learning_rate: 0.0100
# Epoch 23/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2561 - mean_squared_error: 0.1229 - val_loss: 0.2920 - val_mean_squared_error: 0.1544 - learning_rate: 0.0100
# Epoch 24/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2619 - mean_squared_error: 0.1267 - val_loss: 0.3035 - val_mean_squared_error: 0.1636 - learning_rate: 0.0100
# Epoch 25/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2684 - mean_squared_error: 0.1306 - val_loss: 0.2949 - val_mean_squared_error: 0.1562 - learning_rate: 0.0100
# Epoch 26/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2585 - mean_squared_error: 0.1246 - val_loss: 0.2908 - val_mean_squared_error: 0.1537 - learning_rate: 0.0100
# Epoch 27/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2588 - mean_squared_error: 0.1243 - val_loss: 0.2904 - val_mean_squared_error: 0.1529 - learning_rate: 0.0100
# Epoch 28/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2564 - mean_squared_error: 0.1228 - val_loss: 0.2978 - val_mean_squared_error: 0.1570 - learning_rate: 0.0100
# Epoch 29/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2584 - mean_squared_error: 0.1248 - val_loss: 0.2895 - val_mean_squared_error: 0.1530 - learning_rate: 0.0100
# Epoch 30/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2567 - mean_squared_error: 0.1240 - val_loss: 0.2934 - val_mean_squared_error: 0.1555 - learning_rate: 0.0100
# Epoch 31/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2567 - mean_squared_error: 0.1234 - val_loss: 0.2893 - val_mean_squared_error: 0.1539 - learning_rate: 0.0100
# Epoch 32/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2552 - mean_squared_error: 0.1226 - val_loss: 0.2918 - val_mean_squared_error: 0.1562 - learning_rate: 0.0100
# Epoch 33/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2623 - mean_squared_error: 0.1281 - val_loss: 0.2844 - val_mean_squared_error: 0.1511 - learning_rate: 0.0100
# Epoch 34/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2634 - mean_squared_error: 0.1271 - val_loss: 0.2882 - val_mean_squared_error: 0.1514 - learning_rate: 0.0100
# Epoch 35/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2568 - mean_squared_error: 0.1239 - val_loss: 0.2920 - val_mean_squared_error: 0.1537 - learning_rate: 0.0100
# Epoch 36/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2550 - mean_squared_error: 0.1236 - val_loss: 0.2891 - val_mean_squared_error: 0.1522 - learning_rate: 0.0100
# Epoch 37/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2580 - mean_squared_error: 0.1248 - val_loss: 0.2852 - val_mean_squared_error: 0.1518 - learning_rate: 0.0100
# Epoch 38/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2544 - mean_squared_error: 0.1224 - val_loss: 0.2842 - val_mean_squared_error: 0.1511 - learning_rate: 0.0100
# Epoch 39/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2547 - mean_squared_error: 0.1223 - val_loss: 0.2915 - val_mean_squared_error: 0.1526 - learning_rate: 0.0100
# Epoch 40/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2615 - mean_squared_error: 0.1265 - val_loss: 0.2944 - val_mean_squared_error: 0.1567 - learning_rate: 0.0100
# Epoch 41/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2574 - mean_squared_error: 0.1244 - val_loss: 0.2908 - val_mean_squared_error: 0.1528 - learning_rate: 0.0100
# Epoch 42/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2558 - mean_squared_error: 0.1230 - val_loss: 0.2855 - val_mean_squared_error: 0.1544 - learning_rate: 0.0100
# Epoch 43/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2573 - mean_squared_error: 0.1242 - val_loss: 0.2853 - val_mean_squared_error: 0.1515 - learning_rate: 0.0100
# Epoch 44/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2543 - mean_squared_error: 0.1222 - val_loss: 0.2870 - val_mean_squared_error: 0.1529 - learning_rate: 0.0100
# Epoch 45/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2559 - mean_squared_error: 0.1232 - val_loss: 0.2891 - val_mean_squared_error: 0.1527 - learning_rate: 0.0100
# Epoch 46/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2582 - mean_squared_error: 0.1236 - val_loss: 0.2937 - val_mean_squared_error: 0.1548 - learning_rate: 0.0100
# Epoch 47/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2555 - mean_squared_error: 0.1224 - val_loss: 0.2896 - val_mean_squared_error: 0.1536 - learning_rate: 0.0100
# Epoch 48/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2548 - mean_squared_error: 0.1227 - val_loss: 0.2926 - val_mean_squared_error: 0.1552 - learning_rate: 0.0100
# Epoch 49/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2564 - mean_squared_error: 0.1239 - val_loss: 0.2892 - val_mean_squared_error: 0.1520 - learning_rate: 0.0100
# Epoch 50/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2555 - mean_squared_error: 0.1226 - val_loss: 0.2839 - val_mean_squared_error: 0.1511 - learning_rate: 0.0100
# Epoch 51/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2538 - mean_squared_error: 0.1219 - val_loss: 0.2888 - val_mean_squared_error: 0.1519 - learning_rate: 0.0100
# Epoch 52/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2550 - mean_squared_error: 0.1221 - val_loss: 0.3067 - val_mean_squared_error: 0.1665 - learning_rate: 0.0100
# Epoch 53/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2571 - mean_squared_error: 0.1256 - val_loss: 0.2885 - val_mean_squared_error: 0.1526 - learning_rate: 0.0100
# Epoch 54/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2551 - mean_squared_error: 0.1229 - val_loss: 0.2908 - val_mean_squared_error: 0.1530 - learning_rate: 0.0100
# Epoch 55/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2547 - mean_squared_error: 0.1227 - val_loss: 0.2865 - val_mean_squared_error: 0.1511 - learning_rate: 0.0100
# Epoch 56/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2551 - mean_squared_error: 0.1223 - val_loss: 0.2864 - val_mean_squared_error: 0.1523 - learning_rate: 0.0100
# Epoch 57/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2588 - mean_squared_error: 0.1238 - val_loss: 0.2886 - val_mean_squared_error: 0.1532 - learning_rate: 0.0100
# Epoch 58/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2546 - mean_squared_error: 0.1228 - val_loss: 0.2843 - val_mean_squared_error: 0.1506 - learning_rate: 0.0100
# Epoch 59/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2537 - mean_squared_error: 0.1217 - val_loss: 0.2920 - val_mean_squared_error: 0.1549 - learning_rate: 0.0100
# Epoch 60/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2552 - mean_squared_error: 0.1225 - val_loss: 0.2898 - val_mean_squared_error: 0.1547 - learning_rate: 0.0100
# Epoch 61/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2560 - mean_squared_error: 0.1237 - val_loss: 0.2908 - val_mean_squared_error: 0.1530 - learning_rate: 0.0100
# Epoch 62/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2552 - mean_squared_error: 0.1228 - val_loss: 0.2884 - val_mean_squared_error: 0.1549 - learning_rate: 0.0100
# Epoch 63/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2540 - mean_squared_error: 0.1224 - val_loss: 0.2885 - val_mean_squared_error: 0.1528 - learning_rate: 0.0100
# Epoch 64/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2545 - mean_squared_error: 0.1223 - val_loss: 0.2869 - val_mean_squared_error: 0.1511 - learning_rate: 0.0100
# Epoch 65/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2551 - mean_squared_error: 0.1224 - val_loss: 0.2875 - val_mean_squared_error: 0.1515 - learning_rate: 0.0100
# Epoch 66/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2551 - mean_squared_error: 0.1225 - val_loss: 0.2870 - val_mean_squared_error: 0.1518 - learning_rate: 0.0100
# Epoch 67/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2559 - mean_squared_error: 0.1229 - val_loss: 0.2867 - val_mean_squared_error: 0.1513 - learning_rate: 0.0100
# Epoch 68/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2548 - mean_squared_error: 0.1223 - val_loss: 0.2899 - val_mean_squared_error: 0.1543 - learning_rate: 0.0100
# Epoch 69/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2552 - mean_squared_error: 0.1227 - val_loss: 0.2894 - val_mean_squared_error: 0.1527 - learning_rate: 0.0100
# Epoch 70/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2553 - mean_squared_error: 0.1227 - val_loss: 0.2874 - val_mean_squared_error: 0.1517 - learning_rate: 0.0100
# Epoch 71/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2551 - mean_squared_error: 0.1225 - val_loss: 0.2886 - val_mean_squared_error: 0.1521 - learning_rate: 0.0100
# Epoch 72/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2551 - mean_squared_error: 0.1228 - val_loss: 0.2869 - val_mean_squared_error: 0.1511 - learning_rate: 0.0100
# Epoch 73/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2552 - mean_squared_error: 0.1222 - val_loss: 0.2842 - val_mean_squared_error: 0.1504 - learning_rate: 0.0100
# Epoch 74/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2534 - mean_squared_error: 0.1218 - val_loss: 0.2893 - val_mean_squared_error: 0.1523 - learning_rate: 0.0100
# Epoch 75/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2544 - mean_squared_error: 0.1221 - val_loss: 0.2859 - val_mean_squared_error: 0.1523 - learning_rate: 0.0100
# Epoch 76/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2544 - mean_squared_error: 0.1228 - val_loss: 0.2829 - val_mean_squared_error: 0.1492 - learning_rate: 0.0050
# Epoch 77/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2543 - mean_squared_error: 0.1222 - val_loss: 0.2830 - val_mean_squared_error: 0.1492 - learning_rate: 0.0050
# Epoch 78/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2534 - mean_squared_error: 0.1218 - val_loss: 0.2838 - val_mean_squared_error: 0.1497 - learning_rate: 0.0050
# Epoch 79/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2534 - mean_squared_error: 0.1218 - val_loss: 0.2831 - val_mean_squared_error: 0.1496 - learning_rate: 0.0050
# Epoch 80/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2533 - mean_squared_error: 0.1218 - val_loss: 0.2838 - val_mean_squared_error: 0.1499 - learning_rate: 0.0050
# Epoch 81/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2535 - mean_squared_error: 0.1219 - val_loss: 0.2843 - val_mean_squared_error: 0.1499 - learning_rate: 0.0050
# Epoch 82/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2532 - mean_squared_error: 0.1217 - val_loss: 0.2889 - val_mean_squared_error: 0.1530 - learning_rate: 0.0050
# Epoch 83/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2536 - mean_squared_error: 0.1220 - val_loss: 0.2893 - val_mean_squared_error: 0.1550 - learning_rate: 0.0050
# Epoch 84/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2533 - mean_squared_error: 0.1219 - val_loss: 0.2855 - val_mean_squared_error: 0.1507 - learning_rate: 0.0050
# Epoch 85/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2532 - mean_squared_error: 0.1218 - val_loss: 0.2834 - val_mean_squared_error: 0.1498 - learning_rate: 0.0050
# Epoch 86/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2533 - mean_squared_error: 0.1215 - val_loss: 0.2844 - val_mean_squared_error: 0.1504 - learning_rate: 0.0050
# Epoch 87/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2533 - mean_squared_error: 0.1219 - val_loss: 0.2838 - val_mean_squared_error: 0.1502 - learning_rate: 0.0050
# Epoch 88/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2529 - mean_squared_error: 0.1217 - val_loss: 0.2849 - val_mean_squared_error: 0.1513 - learning_rate: 0.0050
# Epoch 89/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2531 - mean_squared_error: 0.1218 - val_loss: 0.2839 - val_mean_squared_error: 0.1507 - learning_rate: 0.0050
# Epoch 90/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2527 - mean_squared_error: 0.1215 - val_loss: 0.2850 - val_mean_squared_error: 0.1514 - learning_rate: 0.0050
# Epoch 91/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2526 - mean_squared_error: 0.1216 - val_loss: 0.2869 - val_mean_squared_error: 0.1533 - learning_rate: 0.0050
# Epoch 92/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2531 - mean_squared_error: 0.1219 - val_loss: 0.2859 - val_mean_squared_error: 0.1522 - learning_rate: 0.0050
# Epoch 93/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2529 - mean_squared_error: 0.1215 - val_loss: 0.2829 - val_mean_squared_error: 0.1492 - learning_rate: 0.0050
# Epoch 94/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2531 - mean_squared_error: 0.1218 - val_loss: 0.2838 - val_mean_squared_error: 0.1500 - learning_rate: 0.0050
# Epoch 95/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2530 - mean_squared_error: 0.1218 - val_loss: 0.2840 - val_mean_squared_error: 0.1501 - learning_rate: 0.0050
# Epoch 96/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2527 - mean_squared_error: 0.1214 - val_loss: 0.2850 - val_mean_squared_error: 0.1511 - learning_rate: 0.0050
# Epoch 97/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2532 - mean_squared_error: 0.1218 - val_loss: 0.2850 - val_mean_squared_error: 0.1509 - learning_rate: 0.0050
# Epoch 98/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2531 - mean_squared_error: 0.1217 - val_loss: 0.2855 - val_mean_squared_error: 0.1514 - learning_rate: 0.0050
# Epoch 99/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2530 - mean_squared_error: 0.1217 - val_loss: 0.2856 - val_mean_squared_error: 0.1515 - learning_rate: 0.0050
# Epoch 100/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2529 - mean_squared_error: 0.1217 - val_loss: 0.2852 - val_mean_squared_error: 0.1511 - learning_rate: 0.0050
# Epoch 101/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2528 - mean_squared_error: 0.1214 - val_loss: 0.2863 - val_mean_squared_error: 0.1517 - learning_rate: 0.0050
# Epoch 102/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2533 - mean_squared_error: 0.1216 - val_loss: 0.2850 - val_mean_squared_error: 0.1513 - learning_rate: 0.0025
# Epoch 103/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2519 - mean_squared_error: 0.1211 - val_loss: 0.2850 - val_mean_squared_error: 0.1503 - learning_rate: 0.0025
# Epoch 104/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2521 - mean_squared_error: 0.1210 - val_loss: 0.2856 - val_mean_squared_error: 0.1511 - learning_rate: 0.0025
# Epoch 105/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2521 - mean_squared_error: 0.1209 - val_loss: 0.2847 - val_mean_squared_error: 0.1506 - learning_rate: 0.0025
# Epoch 106/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2522 - mean_squared_error: 0.1209 - val_loss: 0.2852 - val_mean_squared_error: 0.1509 - learning_rate: 0.0025
# Epoch 107/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2520 - mean_squared_error: 0.1207 - val_loss: 0.2859 - val_mean_squared_error: 0.1509 - learning_rate: 0.0025
# Epoch 108/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2524 - mean_squared_error: 0.1209 - val_loss: 0.2850 - val_mean_squared_error: 0.1503 - learning_rate: 0.0025
# Epoch 109/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2522 - mean_squared_error: 0.1208 - val_loss: 0.2854 - val_mean_squared_error: 0.1512 - learning_rate: 0.0025
# Epoch 110/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2521 - mean_squared_error: 0.1208 - val_loss: 0.2857 - val_mean_squared_error: 0.1513 - learning_rate: 0.0025
# Epoch 111/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2522 - mean_squared_error: 0.1209 - val_loss: 0.2852 - val_mean_squared_error: 0.1515 - learning_rate: 0.0025
# Epoch 112/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2521 - mean_squared_error: 0.1209 - val_loss: 0.2848 - val_mean_squared_error: 0.1511 - learning_rate: 0.0025
# Epoch 113/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2520 - mean_squared_error: 0.1208 - val_loss: 0.2851 - val_mean_squared_error: 0.1507 - learning_rate: 0.0025
# Epoch 114/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2522 - mean_squared_error: 0.1208 - val_loss: 0.2851 - val_mean_squared_error: 0.1513 - learning_rate: 0.0025
# Epoch 115/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2520 - mean_squared_error: 0.1207 - val_loss: 0.2857 - val_mean_squared_error: 0.1514 - learning_rate: 0.0025
# Epoch 116/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2523 - mean_squared_error: 0.1209 - val_loss: 0.2853 - val_mean_squared_error: 0.1510 - learning_rate: 0.0025
# Epoch 117/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2522 - mean_squared_error: 0.1208 - val_loss: 0.2852 - val_mean_squared_error: 0.1514 - learning_rate: 0.0025
# Epoch 118/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2521 - mean_squared_error: 0.1209 - val_loss: 0.2852 - val_mean_squared_error: 0.1511 - learning_rate: 0.0025
# Epoch 119/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2521 - mean_squared_error: 0.1208 - val_loss: 0.2855 - val_mean_squared_error: 0.1516 - learning_rate: 0.0025
# Epoch 120/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2521 - mean_squared_error: 0.1209 - val_loss: 0.2855 - val_mean_squared_error: 0.1516 - learning_rate: 0.0025
# Epoch 121/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2521 - mean_squared_error: 0.1209 - val_loss: 0.2855 - val_mean_squared_error: 0.1513 - learning_rate: 0.0025
# Epoch 122/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2521 - mean_squared_error: 0.1208 - val_loss: 0.2857 - val_mean_squared_error: 0.1515 - learning_rate: 0.0025
# Epoch 123/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2522 - mean_squared_error: 0.1208 - val_loss: 0.2855 - val_mean_squared_error: 0.1516 - learning_rate: 0.0025
# Epoch 124/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2521 - mean_squared_error: 0.1208 - val_loss: 0.2857 - val_mean_squared_error: 0.1516 - learning_rate: 0.0025
# Epoch 125/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2521 - mean_squared_error: 0.1208 - val_loss: 0.2857 - val_mean_squared_error: 0.1513 - learning_rate: 0.0025
# Epoch 126/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2522 - mean_squared_error: 0.1207 - val_loss: 0.2854 - val_mean_squared_error: 0.1515 - learning_rate: 0.0025
# Epoch 127/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2525 - mean_squared_error: 0.1206 - val_loss: 0.2848 - val_mean_squared_error: 0.1512 - learning_rate: 0.0012
# Epoch 128/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2516 - mean_squared_error: 0.1203 - val_loss: 0.2841 - val_mean_squared_error: 0.1509 - learning_rate: 0.0012
# Epoch 129/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2514 - mean_squared_error: 0.1203 - val_loss: 0.2839 - val_mean_squared_error: 0.1509 - learning_rate: 0.0012
# Epoch 130/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2512 - mean_squared_error: 0.1202 - val_loss: 0.2837 - val_mean_squared_error: 0.1508 - learning_rate: 0.0012
# Epoch 131/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2512 - mean_squared_error: 0.1202 - val_loss: 0.2835 - val_mean_squared_error: 0.1505 - learning_rate: 0.0012
# Epoch 132/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2512 - mean_squared_error: 0.1202 - val_loss: 0.2836 - val_mean_squared_error: 0.1507 - learning_rate: 0.0012
# Epoch 133/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2511 - mean_squared_error: 0.1202 - val_loss: 0.2836 - val_mean_squared_error: 0.1508 - learning_rate: 0.0012
# Epoch 134/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2511 - mean_squared_error: 0.1202 - val_loss: 0.2839 - val_mean_squared_error: 0.1511 - learning_rate: 0.0012
# Epoch 135/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2510 - mean_squared_error: 0.1201 - val_loss: 0.2838 - val_mean_squared_error: 0.1510 - learning_rate: 0.0012
# Epoch 136/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2510 - mean_squared_error: 0.1202 - val_loss: 0.2837 - val_mean_squared_error: 0.1510 - learning_rate: 0.0012
# Epoch 137/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2509 - mean_squared_error: 0.1201 - val_loss: 0.2838 - val_mean_squared_error: 0.1510 - learning_rate: 0.0012
# Epoch 138/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2510 - mean_squared_error: 0.1201 - val_loss: 0.2837 - val_mean_squared_error: 0.1510 - learning_rate: 0.0012
# Epoch 139/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2509 - mean_squared_error: 0.1201 - val_loss: 0.2836 - val_mean_squared_error: 0.1509 - learning_rate: 0.0012
# Epoch 140/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2510 - mean_squared_error: 0.1201 - val_loss: 0.2836 - val_mean_squared_error: 0.1510 - learning_rate: 0.0012
# Epoch 141/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2508 - mean_squared_error: 0.1201 - val_loss: 0.2837 - val_mean_squared_error: 0.1511 - learning_rate: 0.0012
# Epoch 142/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2508 - mean_squared_error: 0.1201 - val_loss: 0.2838 - val_mean_squared_error: 0.1513 - learning_rate: 0.0012
# Epoch 143/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2508 - mean_squared_error: 0.1200 - val_loss: 0.2836 - val_mean_squared_error: 0.1512 - learning_rate: 0.0012
# Epoch 144/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2508 - mean_squared_error: 0.1201 - val_loss: 0.2837 - val_mean_squared_error: 0.1511 - learning_rate: 0.0012
# Epoch 145/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2509 - mean_squared_error: 0.1201 - val_loss: 0.2838 - val_mean_squared_error: 0.1512 - learning_rate: 0.0012
# Epoch 146/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2508 - mean_squared_error: 0.1201 - val_loss: 0.2835 - val_mean_squared_error: 0.1511 - learning_rate: 0.0012
# Epoch 147/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2508 - mean_squared_error: 0.1201 - val_loss: 0.2838 - val_mean_squared_error: 0.1512 - learning_rate: 0.0012
# Epoch 148/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2508 - mean_squared_error: 0.1201 - val_loss: 0.2834 - val_mean_squared_error: 0.1510 - learning_rate: 0.0012
# Epoch 149/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2507 - mean_squared_error: 0.1200 - val_loss: 0.2839 - val_mean_squared_error: 0.1513 - learning_rate: 0.0012
# Epoch 150/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2508 - mean_squared_error: 0.1200 - val_loss: 0.2836 - val_mean_squared_error: 0.1510 - learning_rate: 0.0012
# Epoch 151/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2508 - mean_squared_error: 0.1201 - val_loss: 0.2835 - val_mean_squared_error: 0.1513 - learning_rate: 0.0012
# Epoch 152/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2508 - mean_squared_error: 0.1197 - val_loss: 0.2828 - val_mean_squared_error: 0.1511 - learning_rate: 6.2500e-04
# Epoch 153/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2505 - mean_squared_error: 0.1198 - val_loss: 0.2825 - val_mean_squared_error: 0.1510 - learning_rate: 6.2500e-04
# Epoch 154/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2503 - mean_squared_error: 0.1198 - val_loss: 0.2825 - val_mean_squared_error: 0.1509 - learning_rate: 6.2500e-04
# Epoch 155/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2502 - mean_squared_error: 0.1197 - val_loss: 0.2826 - val_mean_squared_error: 0.1509 - learning_rate: 6.2500e-04
# Epoch 156/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2502 - mean_squared_error: 0.1197 - val_loss: 0.2826 - val_mean_squared_error: 0.1508 - learning_rate: 6.2500e-04
# Epoch 157/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2502 - mean_squared_error: 0.1197 - val_loss: 0.2825 - val_mean_squared_error: 0.1508 - learning_rate: 6.2500e-04
# Epoch 158/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2502 - mean_squared_error: 0.1197 - val_loss: 0.2823 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 159/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2502 - mean_squared_error: 0.1196 - val_loss: 0.2824 - val_mean_squared_error: 0.1506 - learning_rate: 6.2500e-04
# Epoch 160/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2502 - mean_squared_error: 0.1196 - val_loss: 0.2823 - val_mean_squared_error: 0.1506 - learning_rate: 6.2500e-04
# Epoch 161/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2821 - val_mean_squared_error: 0.1506 - learning_rate: 6.2500e-04
# Epoch 162/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2823 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 163/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2822 - val_mean_squared_error: 0.1506 - learning_rate: 6.2500e-04
# Epoch 164/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 165/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 166/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2823 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 167/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2822 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 168/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2824 - val_mean_squared_error: 0.1508 - learning_rate: 6.2500e-04
# Epoch 169/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2500 - mean_squared_error: 0.1196 - val_loss: 0.2823 - val_mean_squared_error: 0.1506 - learning_rate: 6.2500e-04
# Epoch 170/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2825 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 171/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 172/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 173/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 174/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2500 - mean_squared_error: 0.1196 - val_loss: 0.2825 - val_mean_squared_error: 0.1508 - learning_rate: 6.2500e-04
# Epoch 175/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2501 - mean_squared_error: 0.1196 - val_loss: 0.2822 - val_mean_squared_error: 0.1506 - learning_rate: 6.2500e-04
# Epoch 176/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2824 - val_mean_squared_error: 0.1506 - learning_rate: 6.2500e-04
# Epoch 177/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2823 - val_mean_squared_error: 0.1506 - learning_rate: 6.2500e-04
# Epoch 178/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 179/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2500 - mean_squared_error: 0.1196 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 180/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2824 - val_mean_squared_error: 0.1508 - learning_rate: 6.2500e-04
# Epoch 181/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2823 - val_mean_squared_error: 0.1508 - learning_rate: 6.2500e-04
# Epoch 182/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2822 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 183/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2823 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 184/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 185/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2824 - val_mean_squared_error: 0.1507 - learning_rate: 6.2500e-04
# Epoch 186/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2500 - mean_squared_error: 0.1195 - val_loss: 0.2824 - val_mean_squared_error: 0.1509 - learning_rate: 6.2500e-04
# Epoch 187/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2503 - mean_squared_error: 0.1196 - val_loss: 0.2796 - val_mean_squared_error: 0.1505 - learning_rate: 3.1250e-04
# Epoch 188/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2496 - mean_squared_error: 0.1195 - val_loss: 0.2795 - val_mean_squared_error: 0.1505 - learning_rate: 3.1250e-04
# Epoch 189/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2495 - mean_squared_error: 0.1195 - val_loss: 0.2795 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 190/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2495 - mean_squared_error: 0.1195 - val_loss: 0.2796 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 191/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2495 - mean_squared_error: 0.1194 - val_loss: 0.2796 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 192/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2494 - mean_squared_error: 0.1194 - val_loss: 0.2797 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 193/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2495 - mean_squared_error: 0.1194 - val_loss: 0.2797 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 194/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2495 - mean_squared_error: 0.1194 - val_loss: 0.2798 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 195/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2495 - mean_squared_error: 0.1194 - val_loss: 0.2798 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 196/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2495 - mean_squared_error: 0.1194 - val_loss: 0.2797 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 197/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1194 - val_loss: 0.2798 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 198/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1194 - val_loss: 0.2797 - val_mean_squared_error: 0.1504 - learning_rate: 3.1250e-04
# Epoch 199/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1194 - val_loss: 0.2797 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 200/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1194 - val_loss: 0.2798 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 201/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2494 - mean_squared_error: 0.1194 - val_loss: 0.2798 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 202/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2798 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 203/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2494 - mean_squared_error: 0.1194 - val_loss: 0.2797 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 204/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2798 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 205/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2797 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 206/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2797 - val_mean_squared_error: 0.1502 - learning_rate: 3.1250e-04
# Epoch 207/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2797 - val_mean_squared_error: 0.1502 - learning_rate: 3.1250e-04
# Epoch 208/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2798 - val_mean_squared_error: 0.1502 - learning_rate: 3.1250e-04
# Epoch 209/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2797 - val_mean_squared_error: 0.1502 - learning_rate: 3.1250e-04
# Epoch 210/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2797 - val_mean_squared_error: 0.1502 - learning_rate: 3.1250e-04
# Epoch 211/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2797 - val_mean_squared_error: 0.1503 - learning_rate: 3.1250e-04
# Epoch 212/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2796 - val_mean_squared_error: 0.1502 - learning_rate: 3.1250e-04
# Epoch 213/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1193 - val_loss: 0.2796 - val_mean_squared_error: 0.1502 - learning_rate: 3.1250e-04
# Epoch 214/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2496 - mean_squared_error: 0.1193 - val_loss: 0.2786 - val_mean_squared_error: 0.1505 - learning_rate: 1.5625e-04
# Epoch 215/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2491 - mean_squared_error: 0.1192 - val_loss: 0.2786 - val_mean_squared_error: 0.1505 - learning_rate: 1.5625e-04
# Epoch 216/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1505 - learning_rate: 1.5625e-04
# Epoch 217/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1504 - learning_rate: 1.5625e-04
# Epoch 218/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1503 - learning_rate: 1.5625e-04
# Epoch 219/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1503 - learning_rate: 1.5625e-04
# Epoch 220/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1503 - learning_rate: 1.5625e-04
# Epoch 221/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1503 - learning_rate: 1.5625e-04
# Epoch 222/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 223/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 224/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 225/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 226/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 227/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 228/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 229/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 230/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 231/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 232/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 233/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 234/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1503 - learning_rate: 1.5625e-04
# Epoch 235/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 236/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 237/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 238/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 239/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 240/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 241/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2785 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 242/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 243/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 244/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 245/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 246/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 247/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 248/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.5625e-04
# Epoch 249/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2490 - mean_squared_error: 0.1191 - val_loss: 0.2783 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 250/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 251/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 252/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2489 - mean_squared_error: 0.1193 - val_loss: 0.2783 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 253/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 254/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1193 - val_loss: 0.2783 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 255/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1193 - val_loss: 0.2784 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 256/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1193 - val_loss: 0.2784 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 257/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1193 - val_loss: 0.2784 - val_mean_squared_error: 0.1507 - learning_rate: 7.8125e-05
# Epoch 258/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1193 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 259/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 260/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2489 - mean_squared_error: 0.1193 - val_loss: 0.2784 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 261/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 262/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 263/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 264/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 265/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 266/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 267/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 268/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 269/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1506 - learning_rate: 7.8125e-05
# Epoch 270/1000
# ...
# Epoch 291/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 292/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 293/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 294/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 295/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 296/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 297/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 298/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 299/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1504 - learning_rate: 3.9062e-05
# Epoch 300/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2489 - mean_squared_error: 0.1193 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 301/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 302/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 303/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 304/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 305/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 306/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 307/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 308/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 309/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 310/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 311/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 312/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 313/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 314/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2783 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 315/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 316/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 317/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 318/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 319/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 320/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 321/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 322/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 323/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 324/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1502 - learning_rate: 1.9531e-05
# Epoch 325/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 326/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 327/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 328/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 329/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 330/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 331/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 332/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 333/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 334/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 335/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 336/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 337/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 338/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 339/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 340/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 341/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 342/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 343/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 344/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 345/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 346/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 347/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 348/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 349/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 9.7656e-06
# Epoch 350/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 351/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 352/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 353/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 354/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 355/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 356/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 357/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 358/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 359/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 360/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 361/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 362/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 363/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 364/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 365/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 366/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 367/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 368/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 369/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 370/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 371/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 372/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 373/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 374/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 4.8828e-06
# Epoch 375/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 2.4414e-06
# Epoch 376/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 2.4414e-06
# Epoch 377/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 2.4414e-06
# Epoch 378/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2488 - mean_squared_error: 0.1192 - val_loss: 0.2784 - val_mean_squared_error: 0.1501 - learning_rate: 2.4414e-06

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Train MAE (standardized): 0.2671612095579409
# Valid MAE (standardized): 0.27832260362013816
# Train MAE: 2.875826280952086
# Valid MAE: 2.99597184499599

# %% [markdown]
# ## Model 2

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    patience=100, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=25
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(512, activation='leaky_relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds, epochs=1000, validation_data=valid_ds,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=0
)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Train MAE (standardized): 0.2665979557183353
# Valid MAE (standardized): 0.27756446957030845
# Train MAE: 2.8697632371805635
# Valid MAE: 2.987811012801798

# %% [markdown]
# ## Model 3

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    patience=100, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=25
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(512, activation='leaky_relu'),
    tf.keras.layers.Dense(512, activation='leaky_relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds, epochs=1000, validation_data=valid_ds,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=0
)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Train MAE (standardized): 0.2504705226941007
# Valid MAE (standardized): 0.29081412362576214
# Train MAE: 2.696161409624039
# Valid MAE: 3.1304354801467085

# %% [markdown]
# ## Model 3.1

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    patience=100, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=25
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(512, activation='leaky_relu'),
    tf.keras.layers.Dense(512, activation='leaky_relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-5)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds, epochs=1000, validation_data=valid_ds,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=0
)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Train MAE (standardized): 0.26050160793568805
# Valid MAE (standardized): 0.27760966466573456
# Train MAE: 2.8041397782658724
# Valid MAE: 2.9882975007141326
