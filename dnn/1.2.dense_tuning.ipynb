# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
import optuna
import os
import random
import datetime

np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Data

# %%
data_path = 'https://raw.githubusercontent.com/antbartash/max_temp/master/data/data2.csv'
data = pd.read_csv(data_path, index_col=0)
data['DATE'] = data['DATE'].astype('datetime64[ns]')

print(data.shape)
data.head()
# Out:
# (40898, 4)
#        STATION                        NAME       DATE  TMAX
# 0  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-01  12.2
# 1  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-02  10.6
# 2  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-03   8.3
# 3  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-04   6.1
# 4  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-05   6.1

# %%
data = data[['STATION', 'DATE', 'TMAX']]

# add sine and cosine transforms to add periodicality
doy = data['DATE'].dt.dayofyear / 365.25
data['Year_sin'] = np.sin(doy * 2 * np.pi)
data['Year_cos'] = np.cos(doy * 2 * np.pi)

print(data.shape)
data.head()
# Out:
# (40898, 5)
#        STATION       DATE  TMAX  Year_sin  Year_cos
# 0  USW00012916 2010-01-01  12.2  0.017202  0.999852
# 1  USW00012916 2010-01-02  10.6  0.034398  0.999408
# 2  USW00012916 2010-01-03   8.3  0.051584  0.998669
# 3  USW00012916 2010-01-04   6.1  0.068755  0.997634
# 4  USW00012916 2010-01-05   6.1  0.085906  0.996303

# %% [markdown]
# ## Data preprocessing

# %%
# TRAIN/VALID/TEST SPLIT

train_df = data.loc[data['DATE'].dt.year <= 2021].reset_index(drop=True).copy()
valid_df = data.loc[data['DATE'].dt.year == 2022].reset_index(drop=True).copy()
test_df = data.loc[data['DATE'].dt.year == 2023].reset_index(drop=True).copy()

print(f'Train: {train_df.shape}')
print(f'Valid: {valid_df.shape}')
print(f'Test: {test_df.shape}')
# Out:
# Train: (35058, 5)
# Valid: (2920, 5)
# Test: (2920, 5)

# %%
# SCALING

train_df.drop(columns=['DATE'], inplace=True)
valid_df.drop(columns=['DATE'], inplace=True)
test_df.drop(columns=['DATE'], inplace=True)

# keep station to drop mixed windows later (encode to avoid errors from scaler)
encoder = OrdinalEncoder()
encoder.fit(train_df[['STATION']])
train_df['STATION'] = encoder.transform(train_df[['STATION']])[:, 0]
valid_df['STATION'] = encoder.transform(valid_df[['STATION']])[:, 0]
test_df['STATION'] = encoder.transform(test_df[['STATION']])[:, 0]

# scaling
scaler = StandardScaler()
scaler.fit(train_df)
train_df = pd.DataFrame(scaler.transform(train_df),
                        columns=scaler.feature_names_in_, index=train_df.index)
valid_df = pd.DataFrame(scaler.transform(valid_df),
                        columns=scaler.feature_names_in_, index=valid_df.index)
test_df = pd.DataFrame(scaler.transform(test_df),
                       columns=scaler.feature_names_in_, index=test_df.index)

train_df.head()
# Out:
#     STATION      TMAX  Year_sin  Year_cos
# 0 -1.091014 -0.747812  0.024401  1.414059
# 1 -1.091014 -0.896450  0.048721  1.413431
# 2 -1.091014 -1.110117  0.073027  1.412386
# 3 -1.091014 -1.314495  0.097312  1.410922
# 4 -1.091014 -1.314495  0.121567  1.409041

# %%
def tmax_inverse_transform(value, scale=scaler.scale_[1], mean=scaler.mean_[1]):
    return value * scale + mean

# %%
# TF DATASET

def create_dataset(data, target_col, source_col, seq_length):
  input_data = data[:-seq_length]
  # adding source_col to target allows to drop samples with features and target
  # from diff sources (source_col will be dropped from the target later)
  targets = data[[source_col, target_col]][seq_length:]
  dataset = tf.keras.preprocessing.timeseries_dataset_from_array(
      input_data, targets,
      sequence_length=seq_length,
      sequence_stride=1,
      batch_size=32,
      shuffle=False,
      seed=42
    )
  for batch in dataset:
    inputs, targets = batch
    assert np.array_equal(inputs[0], data[:seq_length])  # First sequence: steps [0-13]
    # Corresponding target: step 14
    assert np.array_equal(targets[0, 1], data.loc[seq_length, target_col])
    break
  return dataset

train_ds = create_dataset(train_df, 'TMAX', 'STATION', 14)
valid_ds = create_dataset(valid_df, 'TMAX', 'STATION', 14)
test_ds = create_dataset(test_df, 'TMAX', 'STATION', 14)

# %%
# DATASET CLEANING

def filter_mixed_windows(dataset):
    def is_valid_window(inputs, targets):
        # Extract the first feature (station) from inputs and targets
        input_station_ids = inputs[:, :, 0]  # Shape: (batch_size, sequence_length)
        target_station_ids = targets[:, 0]  # Shape: (batch_size)

        # Check if all station IDs in the inputs are the same
        input_same_station = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == tf.reduce_min(input_station_ids, axis=1))

        # Check if the target's station ID matches the input station ID
        target_matches_input = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == target_station_ids)

        # Only keep windows where both conditions are true
        return tf.logical_and(input_same_station, target_matches_input)

    # Filter the dataset
    filtered_dataset = dataset.filter(is_valid_window)
    return filtered_dataset

train_ds = filter_mixed_windows(train_ds)
valid_ds = filter_mixed_windows(valid_ds)
test_ds = filter_mixed_windows(test_ds)

# %%
def drop_first_column(feature, label):
    feature = feature[:, :, 1:]  # Keep all rows, drop the first column
    label = label[:, 1:]    # Keep all rows, drop the first column
    return feature, label

train_ds = train_ds.map(drop_first_column)
valid_ds = valid_ds.map(drop_first_column)
test_ds = test_ds.map(drop_first_column)

# %%
def load_data(batch_size, prefetch=tf.data.AUTOTUNE,
              train_ds=train_ds, valid_ds=valid_ds, test_ds=test_ds):
    train_ds = train_ds.rebatch(batch_size).prefetch(prefetch)
    valid_ds = valid_ds.rebatch(batch_size).prefetch(prefetch)
    test_ds = test_ds.rebatch(batch_size).prefetch(prefetch)
    train_num_batches = len(list(train_ds))
    valid_num_batches = len(list(valid_ds))
    test_num_batches = len(list(test_ds))
    # print(f'load_data - num_batches (train, valid, test): {train_num_batches}, {valid_num_batches}, {test_num_batches}')
    train_ds_repeat = train_ds.repeat()
    valid_ds_repeat = valid_ds.repeat()
    test_ds_repeat = test_ds.repeat()
    return train_ds_repeat, valid_ds_repeat, test_ds_repeat, train_num_batches, valid_num_batches, test_num_batches

# %% [markdown]
# # Model

# %%
def create_model(trial, input_shape):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Input(shape=input_shape))
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    
    # layer 0
    n_units_0 = trial.suggest_int('nunints_layer_0', 32, 2048, step=32)
    actv_func_0 = trial.suggest_categorical('actv_func_layer_0', ['relu', 'leaky_relu', 'elu', 'sigmoid', 'tanh', 'gelu'])

    bias_reg_init_0 = trial.suggest_categorical('bias_reg_init_layer_0', ['l1', 'l2', 'l1l2', None])
    if bias_reg_init_0 == 'l1':
        bias_reg_0 = tf.keras.regularizers.l1(trial.suggest_float('bias_reg_layer_0', 0.0001, 0.5))
    elif bias_reg_init_0 == 'l2':
        bias_reg_0 = tf.keras.regularizers.l2(trial.suggest_float('bias_reg_layer_0', 0.0001, 0.5))
    elif bias_reg_init_0 == 'l1l2':
        bias_reg_0 = tf.keras.regularizers.L1L2(trial.suggest_float('bias_reg_layer_0_l1', 0.0001, 0.5),
                                                trial.suggest_float('bias_reg_layer_0_l2', 0.0001, 0.5))
    else:
        bias_reg_0 = None

    kernel_reg_init_0 = trial.suggest_categorical('kernel_reg_init_layer_0', ['l1', 'l2', 'l1l2', None])
    if kernel_reg_init_0 == 'l1':
        kernel_reg_0 = tf.keras.regularizers.l1(trial.suggest_float('kernel_reg_layer_0', 0.0001, 0.5))
    elif kernel_reg_init_0 == 'l2':
        kernel_reg_0 = tf.keras.regularizers.l2(trial.suggest_float('kernel_reg_layer_0', 0.0001, 0.5))
    elif kernel_reg_init_0 == 'l1l2':
        kernel_reg_0 = tf.keras.regularizers.L1L2(trial.suggest_float('kernel_reg_layer_0_l1', 0.0001, 0.5),
                                                  trial.suggest_float('kernel_reg_layer_0_l2', 0.0001, 0.5))
    else:
        kernel_reg_0 = None

    kernel_initializer_0 = trial.suggest_categorical(
        'kernel_initializer_layer_0', ['glorot_uniform', 'glorot_normal',
                                       'he_uniform', 'he_normal',
                                       'lecun_uniform', 'lecun_normal']
    )
    
    model.add(
        tf.keras.layers.Dense(
            units=n_units_0, activation=actv_func_0, 
            kernel_initializer=kernel_initializer_0,
            bias_regularizer=bias_reg_0,
            kernel_regularizer=kernel_reg_0
        )
    )

    
    # hidden layers
    num_layers = trial.suggest_int('num_layers', 0, 3)
    batch_norm = trial.suggest_categorical(f'batch_norm', [True, False])
    for layer_num in range(num_layers):
        layer_i = layer_num + 1
        n_units = trial.suggest_int(f'nunits_layer_{layer_i}', 32, 2048, step=32)
        actv_func = trial.suggest_categorical(f'actv_func_layer_{layer_i}', ['relu', 'leaky_relu', 'elu', 'sigmoid', 'tanh', 'gelu'])

        bias_reg_init = trial.suggest_categorical(f'bias_reg_init_layer_{layer_i}', ['l1', 'l2', 'l1l2', None])
        if bias_reg_init == 'l1':
            bias_reg = tf.keras.regularizers.l1(trial.suggest_float(f'bias_reg_layer_{layer_i}', 0.0001, 0.5))
        elif bias_reg_init == 'l2':
            bias_reg = tf.keras.regularizers.l2(trial.suggest_float(f'bias_reg_layer_{layer_i}', 0.0001, 0.5))
        elif bias_reg_init == 'l1l2':
            bias_reg = tf.keras.regularizers.L1L2(trial.suggest_float(f'bias_reg_layer_{layer_i}_l1', 0.0001, 0.5),
                                                  trial.suggest_float(f'bias_reg_layer_{layer_i}_l2', 0.0001, 0.5))
        else:
            bias_reg = None

        kernel_reg_init = trial.suggest_categorical(f'kernel_reg_init_layer_{layer_i}', ['l1', 'l2', 'l1l2', None])
        if kernel_reg_init == 'l1':
            kernel_reg = tf.keras.regularizers.l1(trial.suggest_float(f'kernel_reg_layer_{layer_i}', 0.0001, 0.5))
        elif kernel_reg_init == 'l2':
            kernel_reg = tf.keras.regularizers.l2(trial.suggest_float(f'kernel_reg_layer_{layer_i}', 0.0001, 0.5))
        elif kernel_reg_init == 'l1l2':
            kernel_reg = tf.keras.regularizers.L1L2(trial.suggest_float(f'kernel_reg_layer_{layer_i}_l1', 0.0001, 0.5),
                                                    trial.suggest_float(f'kernel_reg_layer_{layer_i}_l2', 0.0001, 0.5))
        else:
            kernel_reg = None

        kernel_initializer = trial.suggest_categorical(
            f'kernel_initializer_layer_{layer_i}', ['glorot_uniform', 'glorot_normal',
                                                    'he_uniform', 'he_normal',
                                                    'lecun_uniform', 'lecun_normal']
        )
        
        if batch_norm:
            model.add(tf.keras.layers.BatchNormalization())
        dropout_rate = trial.suggest_float(f'dropout_rate_layer_{layer_i}', 0.0, 0.999)
        model.add(tf.keras.layers.Dropout(dropout_rate))
        model.add(
            tf.keras.layers.Dense(
                n_units, actv_func, 
                kernel_initializer=kernel_initializer,
                bias_regularizer=bias_reg,
                kernel_regularizer=kernel_reg
            )
        )
    if batch_norm:
        model.add(tf.keras.layers.BatchNormalization())
    dropout_rate = trial.suggest_float(f'dropout_rate_layer_output', 0.0, 0.999)
    model.add(tf.keras.layers.Dropout(dropout_rate))
    model.add(tf.keras.layers.Dense(1, activation='linear'))
    return model

# %% [markdown]
# # Optimizer

# %%
def create_optimizer(trial):
    opt_kwargs = {}
    opt_init = trial.suggest_categorical('optimizer', ['SGD', 'Adam', 'Nadam', 'Adamax'])
    if opt_init == 'SGD':
        opt_kwargs['learning_rate'] = trial.suggest_float('opt_lr', 1e-2, 1e-1, log=True)
        opt_kwargs['momentum'] = trial.suggest_float('opt_momentum', 1e-5, 0.1, log=True)
        opt_kwargs['nesterov'] = trial.suggest_categorical('opt_nesterov', [True, False])
    if opt_init == 'Adam':
        opt_kwargs['learning_rate'] = trial.suggest_float('opt_lr', 1e-2, 1e-1, log=True)
        opt_kwargs['beta_1'] = trial.suggest_categorical('opt_beta_1', [0.9, 0.95, 0.99, 0.999])
        opt_kwargs['beta_2'] = trial.suggest_categorical('opt_beta_2', [0.9, 0.95, 0.99, 0.999])
    if opt_init == 'Nadam':
        opt_kwargs['learning_rate'] = trial.suggest_float('opt_lr', 1e-2, 1e-1, log=True)
        opt_kwargs['beta_1'] = trial.suggest_categorical('opt_beta_1', [0.9, 0.95, 0.99, 0.999])
        opt_kwargs['beta_2'] = trial.suggest_categorical('opt_beta_2', [0.9, 0.95, 0.99, 0.999])
    if opt_init == 'Adamax':
        opt_kwargs['learning_rate'] = trial.suggest_float('opt_lr', 1e-2, 1e-1, log=True)
        opt_kwargs['beta_1'] = trial.suggest_categorical('opt_beta_1', [0.9, 0.95, 0.99, 0.999])
        opt_kwargs['beta_2'] = trial.suggest_categorical('opt_beta_2', [0.9, 0.95, 0.99, 0.999])
    optimizer = getattr(tf.optimizers, opt_init)(**opt_kwargs)
    return optimizer

# %% [markdown]
# # Objective/train

# %%
INPUT_SHAPE = (14, 3, )

def objective(trial):
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 512, 1024])
    train_ds_repeat, valid_ds_repeat, _, train_num_batches, valid_num_batches, _ = load_data(batch_size=batch_size)
    
    model = create_model(trial, input_shape=INPUT_SHAPE)
    optimizer = create_optimizer(trial)
    model.compile(
        loss=tf.keras.losses.MeanAbsoluteError(),
        optimizer=optimizer,
        metrics=[tf.keras.metrics.MeanSquaredError()]
    )
    
    # callbacks
    logdir = os.path.join("logs/optuna", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
    earlystopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25)
    lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', patience=10,
        factor=trial.suggest_float('lr_scheduler_factor', 0.1, 0.75)
    )

    history = model.fit(
        train_ds_repeat, epochs=500, validation_data=valid_ds_repeat,
        steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
        callbacks=[tensorboard_callback, earlystopping_callback, lr_scheduler_callback],
        verbose=0
    )
    print('\n')
    return np.min(history.history['val_loss'])

# %% [markdown]
# # Run

# %%
sampler = optuna.samplers.TPESampler(
    n_startup_trials=25, n_ei_candidates=24,
    multivariate=False, seed=42
)
study = optuna.create_study(direction='minimize', sampler=sampler, study_name='study', storage='sqlite:///db.sqlite3')
study.optimize(
    objective, n_trials=1000,
    timeout=3600*11, # in seconds
    n_jobs=4,
    show_progress_bar=True
)
# Out:
# [I 2024-12-28 21:53:33,378] A new study created in RDB with name: study
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [I 2024-12-28 21:58:57,545] Trial 2 finished with value: 0.8081564903259277 and parameters: {'batch_size': 512, 'nunints_layer_0': 864, 'actv_func_layer_0': 'gelu', 'bias_reg_init_layer_0': None, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.36230931801459904, 'kernel_initializer_layer_0': 'glorot_normal', 'num_layers': 1, 'batch_norm': False, 'nunits_layer_1': 928, 'actv_func_layer_1': 'relu', 'bias_reg_init_layer_1': None, 'kernel_reg_init_layer_1': 'l2', 'kernel_reg_layer_1': 0.04655416081511716, 'kernel_initializer_layer_1': 'glorot_uniform', 'dropout_rate_layer_1': 0.4752258352444604, 'dropout_rate_layer_output': 0.7040392279427679, 'optimizer': 'Adamax', 'opt_lr': 0.09654003073960916, 'opt_beta_1': 0.9, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.6442636281823356}. Best is trial 2 with value: 0.8081564903259277.
#
#
# [I 2024-12-28 22:01:59,652] Trial 0 finished with value: 0.4523944854736328 and parameters: {'batch_size': 512, 'nunints_layer_0': 576, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.3608016122807322, 'bias_reg_layer_0_l2': 0.16634573760876084, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.4673250290017079, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': True, 'dropout_rate_layer_output': 0.11056740566226894, 'optimizer': 'Nadam', 'opt_lr': 0.042061932562589256, 'opt_beta_1': 0.9, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.13268940246455044}. Best is trial 0 with value: 0.4523944854736328.
#
#
# [I 2024-12-28 22:26:37,355] Trial 3 finished with value: 0.46816447377204895 and parameters: {'batch_size': 1024, 'nunints_layer_0': 1120, 'actv_func_layer_0': 'leaky_relu', 'bias_reg_init_layer_0': None, 'kernel_reg_init_layer_0': 'l1', 'kernel_reg_layer_0': 0.012232723969056588, 'kernel_initializer_layer_0': 'glorot_normal', 'num_layers': 1, 'batch_norm': True, 'nunits_layer_1': 1376, 'actv_func_layer_1': 'elu', 'bias_reg_init_layer_1': None, 'kernel_reg_init_layer_1': 'l1', 'kernel_reg_layer_1': 0.0798646410354784, 'kernel_initializer_layer_1': 'glorot_uniform', 'dropout_rate_layer_1': 0.5275018527446529, 'dropout_rate_layer_output': 0.6053278880474698, 'optimizer': 'Nadam', 'opt_lr': 0.040923362335997936, 'opt_beta_1': 0.999, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.4337745667059095}. Best is trial 0 with value: 0.4523944854736328.
#
#
# [I 2024-12-28 22:28:16,490] Trial 5 finished with value: 0.46322131156921387 and parameters: {'batch_size': 256, 'nunints_layer_0': 1728, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1', 'bias_reg_layer_0': 0.30169558499240806, 'kernel_reg_init_layer_0': 'l1', 'kernel_reg_layer_0': 0.23980248163953805, 'kernel_initializer_layer_0': 'he_uniform', 'num_layers':
 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.5675795599696889}. Best is trial 18 with value: 0.4498819410800934.
#
#
# [I 2024-12-29 03:24:31,140] Trial 25 finished with value: 0.47306719422340393 and parameters: {'batch_size': 1024, 'nunints_layer_0': 160, 'actv_func_layer_0': 'sigmoid', 'bias_reg_init_layer_0': 'l1', 'bias_reg_layer_0': 0.17555377176812956, 'kernel_reg_init_layer_0': None, 'kernel_initializer_layer_0': 'he_uniform', 'num_layers': 2, 'batch_norm': True, 'nunits_layer_1': 416, 'actv_func_layer_1': 'leaky_relu', 'bias_reg_init_layer_1': 'l1l2', 'bias_reg_layer_1_l1': 0.0972708431173533, 'bias_reg_layer_1_l2': 0.12715300168074153, 'kernel_reg_init_layer_1': 'l1l2', 'kernel_reg_layer_1_l1': 0.29550371269373094, 'kernel_reg_layer_1_l2': 0.3693981652678565, 'kernel_initializer_layer_1': 'lecun_normal', 'dropout_rate_layer_1': 0.8603668582755603, 'nunits_layer_2': 1152, 'actv_func_layer_2': 'elu', 'bias_reg_init_layer_2': None, 'kernel_reg_init_layer_2': None, 'kernel_initializer_layer_2': 'glorot_normal', 'dropout_rate_layer_2': 0.3427473491014009, 'dropout_rate_layer_output': 0.5615541799420104, 'optimizer': 'SGD', 'opt_lr': 0.02755478541896107, 'opt_momentum': 0.0002772180507154748, 'opt_nesterov': True, 'lr_scheduler_factor': 0.5716634931221195}. Best is trial 18 with value: 0.4498819410800934.
#
#
# [I 2024-12-29 03:27:57,403] Trial 27 finished with value: 0.4538998305797577 and parameters: {'batch_size': 1024, 'nunints_layer_0': 1472, 'actv_func_layer_0': 'leaky_relu', 'bias_reg_init_layer_0': 'l2', 'bias_reg_layer_0': 0.2200251890598808, 'kernel_reg_init_layer_0': 'l1', 'kernel_reg_layer_0': 0.03664218615706613, 'kernel_initializer_layer_0': 'glorot_uniform', 'num_layers': 0, 'batch_norm': True, 'dropout_rate_layer_output': 0.16996009075967744, 'optimizer': 'SGD', 'opt_lr': 0.05154393967203699, 'opt_momentum': 7.3175828102499e-05, 'opt_nesterov': True, 'lr_scheduler_factor': 0.21618157303260194}. Best is trial 18 with value: 0.4498819410800934.
#
#
# [I 2024-12-29 03:29:13,962] Trial 26 finished with value: 0.4252004623413086 and parameters: {'batch_size': 256, 'nunints_layer_0': 768, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.025784330595142027, 'bias_reg_layer_0_l2': 0.4412956100795506, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.3663801415246079, 'kernel_initializer_layer_0': 'he_uniform', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.06419080384030548, 'optimizer': 'Nadam', 'opt_lr': 0.010016641531330178, 'opt_beta_1': 0.999, 'opt_beta_2': 0.99, 'lr_scheduler_factor': 0.42699392672267034}. Best is trial 26 with value: 0.4252004623413086.
#
#
# [I 2024-12-29 03:35:08,344] Trial 29 finished with value: 0.4586893618106842 and parameters: {'batch_size': 1024, 'nunints_layer_0': 704, 'actv_func_layer_0': 'leaky_relu', 'bias_reg_init_layer_0': 'l2', 'bias_reg_layer_0': 0.43106425234952056, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.44615695015444795, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': True, 'dropout_rate_layer_output': 0.052763898654866186, 'optimizer': 'Adamax', 'opt_lr': 0.046423212272330885, 'opt_beta_1': 0.9, 'opt_beta_2': 0.9, 'lr_scheduler_factor': 0.11370024643270442}. Best is trial 26 with value: 0.4252004623413086.
#
#
# [I 2024-12-29 03:44:34,419] Trial 28 finished with value: 0.45773884654045105 and parameters: {'batch_size': 1024, 'nunints_layer_0': 640, 'actv_func_layer_0': 'leaky_relu', 'bias_reg_init_layer_0': 'l2', 'bias_reg_layer_0': 0.48868109973325025, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.12358342149358278, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': True, 'dropout_rate_layer_output': 0.0670137252032229, 'optimizer': 'Adamax', 'opt_lr': 0.037568922255828426, 'opt_beta_1': 0.9, 'opt_beta_2': 0.9, 'lr_scheduler_factor': 0.13417134688357954}. Best is trial 26 with value: 0.4252004623413086.
#
#
# [I 2024-12-29 03:48:37,666] Trial 33 finished with value: 13.149394989013672 and parameters: {'batch_size': 512, 'nunints_layer_0': 384, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.3363418228890922, 'bias_reg_layer_0_l2': 0.4185477038173311, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.4926833601350212, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.11964543950079332, 'optimizer': 'Nadam', 'opt_lr': 0.019742296815387656, 'opt_beta_1': 0.999, 'opt_beta_2': 0.99, 'lr_scheduler_factor': 0.3153515055675231}. Best is trial 26 with value: 0.4252004623413086.
#
#
# [I 2024-12-29 04:07:21,417] Trial 30 finished with value: 0.45607489347457886 and parameters: {'batch_size': 1024, 'nunints_layer_0': 704, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l2', 'bias_reg_layer_0': 0.10283386676130739, 'kernel_reg_init_layer_0': 'l1', 'kernel_reg_layer_0': 0.4805160881830117, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': True, 'dropout_rate_layer_output': 0.024203715913529683, 'optimizer': 'Adamax', 'opt_lr': 0.04700707234109936, 'opt_beta_1': 0.99, 'opt_beta_2': 0.95, 'lr_scheduler_factor': 0.10618412122298747}. Best is trial 26 with value: 0.4252004623413086.
#
#
# [I 2024-12-29 04:14:04,564] Trial 34 finished with value: 0.4501616656780243 and parameters: {'batch_size': 1024, 'nunints_layer_0': 736, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.23367556572681583, 'bias_reg_layer_0_l2': 0.3090579278174719, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.4280231518937293, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': True, 'dropout_rate_layer_output': 0.1537818873961218, 'optimizer': 'Nadam', 'opt_lr': 0.050765944331695866, 'opt_beta_1': 0.99, 'opt_beta_2': 0.95, 'lr_scheduler_factor': 0.15365580460903283}. Best is trial 26 with value: 0.4252004623413086.
#
#
# [I 2024-12-29 04:17:04,136] Trial 31 finished with value: 0.4247857928276062 and parameters: {'batch_size': 512, 'nunints_layer_0': 672, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.36022711298068144, 'bias_reg_layer_0_l2': 0.4055128061904274, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.4743925106052487, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.02692895162811125, 'optimizer': 'Nadam', 'opt_lr': 0.03973202582816978, 'opt_beta_1': 0.999, 'opt_beta_2': 0.99, 'lr_scheduler_factor': 0.10406926985321129}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 04:21:21,469] Trial 35 finished with value: 0.4524206221103668 and parameters: {'batch_size': 512, 'nunints_layer_0': 416, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.4839715444993916, 'bias_reg_layer_0_l2': 0.3156253985795136, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.414444250809145, 'kernel_initializer_layer_0': 'glorot_uniform', 'num_layers': 0, 'batch_norm': True, 'dropout_rate_layer_output': 0.1414339994012297, 'optimizer': 'Nadam', 'opt_lr': 0.051966434459609454, 'opt_beta_1': 0.999, 'opt_beta_2': 0.99, 'lr_scheduler_factor': 0.16552560470649735}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 04:26:27,003] Trial 36 finished with value: 0.45679089426994324 and parameters: {'batch_size': 512, 'nunints_layer_0': 768, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.22882729482866102, 'bias_reg_layer_0_l2': 0.3110025510111676, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.42811832084827334, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': True, 'dropout_rate_layer_output': 0.1033719893612812, 'optimizer': 'Nadam', 'opt_lr': 0.03354295612386868, 'opt_beta_1': 0.99, 'opt_beta_2': 0.95, 'lr_scheduler_factor': 0.14886481163889043}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 04:37:41,886] Trial 32 finished with value: 0.43602055311203003 and parameters: {'batch_size': 512, 'nunints_layer_0': 352, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.3112931210759269, 'bias_reg_layer_0_l2': 0.41557558525242466, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.46665796172233903, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.05178887665354809, 'optimizer': 'Nadam', 'opt_lr': 0.03593730237498761, 'opt_beta_1': 0.999, 'opt_beta_2': 0.99, 'lr_scheduler_factor': 0.34218191397335523}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 04:42:01,082] Trial 40 finished with value: 6.652834892272949 and parameters: {'batch_size': 512, 'nunints_layer_0': 320, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.3026942959373362, 'bias_reg_layer_0_l2': 0.4952689982206529, 'kernel_reg_init_layer_0': 'l2', 'kernel_reg_layer_0': 0.25588051325143535, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.00241998632470199, 'optimizer': 'Nadam', 'opt_lr': 0.010031988209013225, 'opt_beta_1': 0.999, 'opt_beta_2': 0.99, 'lr_scheduler_factor': 0.32759070727448575}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 04:47:07,117] Trial 39 finished with value: 0.44125935435295105 and parameters: {'batch_size': 256, 'nunints_layer_0': 992, 'actv_func_layer_0': 'tanh', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0
 'actv_func_layer_0': 'gelu', 'bias_reg_init_layer_0': 'l1', 'bias_reg_layer_0': 0.40627418930257075, 'kernel_reg_init_layer_0': 'l1', 'kernel_reg_layer_0': 0.1537492760712682, 'kernel_initializer_layer_0': 'he_normal', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.3123336200248585, 'optimizer': 'Adam', 'opt_lr': 0.0126853007557102, 'opt_beta_1': 0.95, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.5317888150023157}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 08:46:56,370] Trial 68 finished with value: 0.4675026834011078 and parameters: {'batch_size': 32, 'nunints_layer_0': 928, 'actv_func_layer_0': 'gelu', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.38322090549315524, 'bias_reg_layer_0_l2': 0.1843353998480149, 'kernel_reg_init_layer_0': 'l1', 'kernel_reg_layer_0': 0.23284953320691268, 'kernel_initializer_layer_0': 'he_normal', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.2983011516327266, 'optimizer': 'Adam', 'opt_lr': 0.015416577736382896, 'opt_beta_1': 0.95, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.5137327766602587}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 09:10:50,073] Trial 70 finished with value: 0.4965652823448181 and parameters: {'batch_size': 32, 'nunints_layer_0': 960, 'actv_func_layer_0': 'gelu', 'bias_reg_init_layer_0': 'l1', 'bias_reg_layer_0': 0.08260822398586223, 'kernel_reg_init_layer_0': 'l1', 'kernel_reg_layer_0': 0.1686896715415288, 'kernel_initializer_layer_0': 'he_normal', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.3158489142664242, 'optimizer': 'Adam', 'opt_lr': 0.014691643188260495, 'opt_beta_1': 0.95, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.5302245784717038}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 09:11:40,959] Trial 67 finished with value: 0.46043190360069275 and parameters: {'batch_size': 32, 'nunints_layer_0': 960, 'actv_func_layer_0': 'gelu', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.372858063485449, 'bias_reg_layer_0_l2': 0.17932737061029155, 'kernel_reg_init_layer_0': 'l1', 'kernel_reg_layer_0': 0.16617794179122625, 'kernel_initializer_layer_0': 'lecun_uniform', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.22388918701642252, 'optimizer': 'Adamax', 'opt_lr': 0.014392251561404891, 'opt_beta_1': 0.95, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.5379766460420057}. Best is trial 31 with value: 0.4247857928276062.
#
#
# [I 2024-12-29 09:27:24,544] Trial 71 finished with value: 0.4234468638896942 and parameters: {'batch_size': 32, 'nunints_layer_0': 928, 'actv_func_layer_0': 'gelu', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.3825531288065288, 'bias_reg_layer_0_l2': 0.1566136667517353, 'kernel_reg_init_layer_0': None, 'kernel_initializer_layer_0': 'he_normal', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.3805954215962635, 'optimizer': 'Adam', 'opt_lr': 0.014715720535795028, 'opt_beta_1': 0.95, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.6120967737206469}. Best is trial 71 with value: 0.4234468638896942.
#
#
# [I 2024-12-29 09:45:17,310] Trial 72 finished with value: 0.45145103335380554 and parameters: {'batch_size': 32, 'nunints_layer_0': 1088, 'actv_func_layer_0': 'gelu', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.4550905075864969, 'bias_reg_layer_0_l2': 0.1440908647533513, 'kernel_reg_init_layer_0': None, 'kernel_initializer_layer_0': 'lecun_normal', 'num_layers': 1, 'batch_norm': False, 'nunits_layer_1': 1632, 'actv_func_layer_1': 'elu', 'bias_reg_init_layer_1': 'l2', 'bias_reg_layer_1': 0.3803601033041881, 'kernel_reg_init_layer_1': 'l1', 'kernel_reg_layer_1': 0.00668715287040042, 'kernel_initializer_layer_1': 'glorot_normal', 'dropout_rate_layer_1': 0.3296821100988594, 'dropout_rate_layer_output': 0.39361080263427806, 'optimizer': 'Adamax', 'opt_lr': 0.014637816903422364, 'opt_beta_1': 0.95, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.5904034113932318}. Best is trial 71 with value: 0.4234468638896942.

# %%
print(f"Best score: {study.best_trial.value}")
print(f"Best params: {study.best_trial.params}")
# Out:
# Best score: 0.4234468638896942
# Best params: {'batch_size': 32, 'nunints_layer_0': 928, 'actv_func_layer_0': 'gelu', 'bias_reg_init_layer_0': 'l1l2', 'bias_reg_layer_0_l1': 0.3825531288065288, 'bias_reg_layer_0_l2': 0.1566136667517353, 'kernel_reg_init_layer_0': None, 'kernel_initializer_layer_0': 'he_normal', 'num_layers': 0, 'batch_norm': False, 'dropout_rate_layer_output': 0.3805954215962635, 'optimizer': 'Adam', 'opt_lr': 0.014715720535795028, 'opt_beta_1': 0.95, 'opt_beta_2': 0.999, 'lr_scheduler_factor': 0.6120967737206469}
