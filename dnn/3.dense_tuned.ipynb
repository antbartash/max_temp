# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
import os
import random
import datetime

np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# # Data

# %%
data_path = 'https://raw.githubusercontent.com/antbartash/max_temp/master/data/data2.csv'
data = pd.read_csv(data_path, index_col=0)
data['DATE'] = data['DATE'].astype('datetime64[ns]')

print(data.shape)
data.head()
# Out:
# (40898, 4)
#        STATION                        NAME       DATE  TMAX
# 0  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-01  12.2
# 1  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-02  10.6
# 2  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-03   8.3
# 3  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-04   6.1
# 4  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-05   6.1

# %%
data = data[['STATION', 'DATE', 'TMAX']]

# add sine and cosine transforms to add periodicality
doy = data['DATE'].dt.dayofyear / 365.25
data['Year_sin'] = np.sin(doy * 2 * np.pi)
data['Year_cos'] = np.cos(doy * 2 * np.pi)

print(data.shape)
data.head()
# Out:
# (40898, 5)
#        STATION       DATE  TMAX  Year_sin  Year_cos
# 0  USW00012916 2010-01-01  12.2  0.017202  0.999852
# 1  USW00012916 2010-01-02  10.6  0.034398  0.999408
# 2  USW00012916 2010-01-03   8.3  0.051584  0.998669
# 3  USW00012916 2010-01-04   6.1  0.068755  0.997634
# 4  USW00012916 2010-01-05   6.1  0.085906  0.996303

# %% [markdown]
# ## Data preprocessing

# %%
# TRAIN/VALID/TEST SPLIT

train_df = data.loc[data['DATE'].dt.year <= 2021].reset_index(drop=True).copy()
valid_df = data.loc[data['DATE'].dt.year == 2022].reset_index(drop=True).copy()
test_df = data.loc[data['DATE'].dt.year == 2023].reset_index(drop=True).copy()

print(f'Train: {train_df.shape}')
print(f'Valid: {valid_df.shape}')
print(f'Test: {test_df.shape}')
# Out:
# Train: (35058, 5)
# Valid: (2920, 5)
# Test: (2920, 5)

# %%
# SCALING

train_df.drop(columns=['DATE'], inplace=True)
valid_df.drop(columns=['DATE'], inplace=True)
test_df.drop(columns=['DATE'], inplace=True)

# keep station to drop mixed windows later (encode to avoid errors from scaler)
encoder = OrdinalEncoder()
encoder.fit(train_df[['STATION']])
train_df['STATION'] = encoder.transform(train_df[['STATION']])[:, 0]
valid_df['STATION'] = encoder.transform(valid_df[['STATION']])[:, 0]
test_df['STATION'] = encoder.transform(test_df[['STATION']])[:, 0]

# scaling
scaler = StandardScaler()
scaler.fit(train_df)
train_df = pd.DataFrame(scaler.transform(train_df),
                        columns=scaler.feature_names_in_, index=train_df.index)
valid_df = pd.DataFrame(scaler.transform(valid_df),
                        columns=scaler.feature_names_in_, index=valid_df.index)
test_df = pd.DataFrame(scaler.transform(test_df),
                       columns=scaler.feature_names_in_, index=test_df.index)

train_df.head()
# Out:
#     STATION      TMAX  Year_sin  Year_cos
# 0 -1.091014 -0.747812  0.024401  1.414059
# 1 -1.091014 -0.896450  0.048721  1.413431
# 2 -1.091014 -1.110117  0.073027  1.412386
# 3 -1.091014 -1.314495  0.097312  1.410922
# 4 -1.091014 -1.314495  0.121567  1.409041

# %%
def tmax_inverse_transform(arr, scale=scaler.scale_[1], mean=scaler.mean_[1]):
    return arr * scale + mean

# %%
# TF DATASET

def create_dataset(data, target_col, source_col, seq_length):
  input_data = data[:-seq_length]
  # adding source_col to target allows to drop samples with features and target
  # from diff sources (source_col will be dropped from the target later)
  targets = data[[source_col, target_col]][seq_length:]
  dataset = tf.keras.preprocessing.timeseries_dataset_from_array(
      input_data, targets,
      sequence_length=seq_length,
      sequence_stride=1,
      batch_size=32,
      shuffle=False,
      seed=42
    )
  for batch in dataset:
    inputs, targets = batch
    assert np.array_equal(inputs[0], data[:seq_length])  # First sequence: steps [0-13]
    # Corresponding target: step 14
    assert np.array_equal(targets[0, 1], data.loc[seq_length, target_col])
    break
  return dataset

train_ds = create_dataset(train_df, 'TMAX', 'STATION', 14)
valid_ds = create_dataset(valid_df, 'TMAX', 'STATION', 14)
test_ds = create_dataset(test_df, 'TMAX', 'STATION', 14)

# %%
# DATASET CLEANING

def filter_mixed_windows(dataset):
    def is_valid_window(inputs, targets):
        # Extract the first feature (station) from inputs and targets
        input_station_ids = inputs[:, :, 0]  # Shape: (batch_size, sequence_length)
        target_station_ids = targets[:, 0]  # Shape: (batch_size)

        # Check if all station IDs in the inputs are the same
        input_same_station = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == tf.reduce_min(input_station_ids, axis=1))

        # Check if the target's station ID matches the input station ID
        target_matches_input = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == target_station_ids)

        # Only keep windows where both conditions are true
        return tf.logical_and(input_same_station, target_matches_input)

    # Filter the dataset
    filtered_dataset = dataset.filter(is_valid_window)
    return filtered_dataset

train_ds = filter_mixed_windows(train_ds)
valid_ds = filter_mixed_windows(valid_ds)
test_ds = filter_mixed_windows(test_ds)

# %%
def drop_first_column(feature, label):
    feature = feature[:, :, 1:]  # Keep all rows, drop the first column
    label = label[:, 1:]    # Keep all rows, drop the first column
    return feature, label

train_ds = train_ds.map(drop_first_column)
valid_ds = valid_ds.map(drop_first_column)
test_ds = test_ds.map(drop_first_column)

# %%
def load_data(batch_size, prefetch=tf.data.AUTOTUNE,
              train_ds=train_ds, valid_ds=valid_ds, test_ds=test_ds):
    train_ds = train_ds.rebatch(batch_size).prefetch(prefetch)
    valid_ds = valid_ds.rebatch(batch_size).prefetch(prefetch)
    test_ds = test_ds.rebatch(batch_size).prefetch(prefetch)
    train_num_batches = len(list(train_ds))
    valid_num_batches = len(list(valid_ds))
    test_num_batches = len(list(test_ds))
    # print(f'load_data - num_batches (train, valid, test): {train_num_batches}, {valid_num_batches}, {test_num_batches}')
    train_ds_repeat = train_ds.repeat()
    valid_ds_repeat = valid_ds.repeat()
    test_ds_repeat = test_ds.repeat()
    return train_ds_repeat, valid_ds_repeat, test_ds_repeat, train_num_batches, valid_num_batches, test_num_batches

train_ds_repeat, valid_ds_repeat, test_ds_repeat, train_num_batches, valid_num_batches, test_num_batches = load_data(batch_size=32)

# %% [markdown]
# # Model

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=25, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.6120967737206469, patience=10
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(
        928, activation='gelu',
        bias_regularizer=tf.keras.regularizers.L1L2(0.3825531288065288, 0.1566136667517353),
        kernel_regularizer=None,
        kernel_initializer='he_normal'
    ),
    tf.keras.layers.Dropout(0.3805954215962635),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Adam(learning_rate=0.014715720535795028, beta_1=0.95, beta_2=0.999)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds_repeat, epochs=1000, validation_data=valid_ds_repeat,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=1
)
# Out:
# Epoch 1/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 8.3492 - mean_squared_error: 267.7570 - val_loss: 9.3753 - val_mean_squared_error: 150.6408 - learning_rate: 0.0147
# Epoch 2/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 9.4409 - mean_squared_error: 362.9760 - val_loss: 6.6287 - val_mean_squared_error: 49.1485 - learning_rate: 0.0147
# Epoch 3/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 10.5756 - mean_squared_error: 339.2594 - val_loss: 15.9351 - val_mean_squared_error: 449.2632 - learning_rate: 0.0147
# Epoch 4/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 14.3465 - mean_squared_error: 838.4722 - val_loss: 22.3534 - val_mean_squared_error: 868.5627 - learning_rate: 0.0147
# Epoch 5/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 11.3166 - mean_squared_error: 513.2926 - val_loss: 9.7186 - val_mean_squared_error: 160.2125 - learning_rate: 0.0147
# Epoch 6/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 12.7540 - mean_squared_error: 601.8530 - val_loss: 12.4818 - val_mean_squared_error: 222.8042 - learning_rate: 0.0147
# Epoch 7/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 12.3079 - mean_squared_error: 505.0529 - val_loss: 11.1789 - val_mean_squared_error: 159.8778 - learning_rate: 0.0147
# Epoch 8/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 8.1269 - mean_squared_error: 182.8067 - val_loss: 13.8023 - val_mean_squared_error: 298.5879 - learning_rate: 0.0147
# Epoch 9/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 11.6979 - mean_squared_error: 475.1148 - val_loss: 13.2605 - val_mean_squared_error: 220.0804 - learning_rate: 0.0147
# Epoch 10/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 7.5306 - mean_squared_error: 166.8848 - val_loss: 5.9338 - val_mean_squared_error: 52.9950 - learning_rate: 0.0147
# Epoch 11/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 18.3428 - mean_squared_error: 1213.3977 - val_loss: 11.9565 - val_mean_squared_error: 265.9882 - learning_rate: 0.0147
# Epoch 12/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 8.8438 - mean_squared_error: 416.7551 - val_loss: 7.4554 - val_mean_squared_error: 73.0141 - learning_rate: 0.0147
# Epoch 13/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 10.1435 - mean_squared_error: 281.2362 - val_loss: 11.5273 - val_mean_squared_error: 181.0932 - learning_rate: 0.0147
# Epoch 14/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 16.5735 - mean_squared_error: 976.7775 - val_loss: 10.6303 - val_mean_squared_error: 176.9156 - learning_rate: 0.0147
# Epoch 15/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 11.2715 - mean_squared_error: 421.4259 - val_loss: 11.9055 - val_mean_squared_error: 171.9214 - learning_rate: 0.0147
# Epoch 16/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 8.3739 - mean_squared_error: 212.6408 - val_loss: 18.4288 - val_mean_squared_error: 580.9057 - learning_rate: 0.0147
# Epoch 17/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 8.7167 - mean_squared_error: 322.2038 - val_loss: 9.0122 - val_mean_squared_error: 102.9693 - learning_rate: 0.0147
# Epoch 18/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 8.8556 - mean_squared_error: 190.3040 - val_loss: 18.0053 - val_mean_squared_error: 528.6502 - learning_rate: 0.0147
# Epoch 19/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 10.9920 - mean_squared_error: 438.2443 - val_loss: 9.8832 - val_mean_squared_error: 116.6799 - learning_rate: 0.0147
# Epoch 20/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 12.7962 - mean_squared_error: 700.5669 - val_loss: 9.5916 - val_mean_squared_error: 114.6500 - learning_rate: 0.0147
# Epoch 21/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 3.4125 - mean_squared_error: 45.9533 - val_loss: 0.8564 - val_mean_squared_error: 0.6803 - learning_rate: 0.0090
# Epoch 22/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 2.1749 - mean_squared_error: 13.8097 - val_loss: 4.3488 - val_mean_squared_error: 21.9925 - learning_rate: 0.0090
# Epoch 23/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 3.6408 - mean_squared_error: 38.5372 - val_loss: 6.7662 - val_mean_squared_error: 67.5811 - learning_rate: 0.0090
# Epoch 24/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 4.2626 - mean_squared_error: 54.9972 - val_loss: 4.4897 - val_mean_squared_error: 26.3584 - learning_rate: 0.0090
# Epoch 25/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 3.9678 - mean_squared_error: 46.3589 - val_loss: 3.7963 - val_mean_squared_error: 19.5653 - learning_rate: 0.0090
# Epoch 26/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 3.5289 - mean_squared_error: 42.4047 - val_loss: 1.4137 - val_mean_squared_error: 2.0582 - learning_rate: 0.0090
# Epoch 27/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 2.4516 - mean_squared_error: 18.7927 - val_loss: 3.5215 - val_mean_squared_error: 14.6457 - learning_rate: 0.0090
# Epoch 28/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 4.0475 - mean_squared_error: 50.9133 - val_loss: 2.2361 - val_mean_squared_error: 5.6394 - learning_rate: 0.0090
# Epoch 29/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 3.6487 - mean_squared_error: 40.2299 - val_loss: 9.7746 - val_mean_squared_error: 116.5190 - learning_rate: 0.0090
# Epoch 30/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 8.5656 - mean_squared_error: 282.5725 - val_loss: 2.9381 - val_mean_squared_error: 9.3319 - learning_rate: 0.0090
# Epoch 31/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 2.0887 - mean_squared_error: 10.7729 - val_loss: 3.8081 - val_mean_squared_error: 20.5621 - learning_rate: 0.0090
# Epoch 32/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.8227 - mean_squared_error: 11.5168 - val_loss: 0.9539 - val_mean_squared_error: 1.3642 - learning_rate: 0.0055
# Epoch 33/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.9952 - mean_squared_error: 2.0600 - val_loss: 2.0059 - val_mean_squared_error: 5.4014 - learning_rate: 0.0055
# Epoch 34/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.5842 - mean_squared_error: 7.3379 - val_loss: 3.3147 - val_mean_squared_error: 14.7320 - learning_rate: 0.0055
# Epoch 35/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.6948 - mean_squared_error: 7.6400 - val_loss: 2.3033 - val_mean_squared_error: 9.6553 - learning_rate: 0.0055
# Epoch 36/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.6487 - mean_squared_error: 8.5734 - val_loss: 0.5524 - val_mean_squared_error: 0.2793 - learning_rate: 0.0055
# Epoch 37/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.9898 - mean_squared_error: 1.9057 - val_loss: 1.8741 - val_mean_squared_error: 4.3247 - learning_rate: 0.0055
# Epoch 38/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.4440 - mean_squared_error: 5.0810 - val_loss: 2.1467 - val_mean_squared_error: 8.9019 - learning_rate: 0.0055
# Epoch 39/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.5535 - mean_squared_error: 5.4327 - val_loss: 1.2708 - val_mean_squared_error: 1.7445 - learning_rate: 0.0055
# Epoch 40/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.3831 - mean_squared_error: 5.5321 - val_loss: 1.0478 - val_mean_squared_error: 1.2882 - learning_rate: 0.0055
# Epoch 41/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.4143 - mean_squared_error: 4.2266 - val_loss: 1.3888 - val_mean_squared_error: 2.4130 - learning_rate: 0.0055
# Epoch 42/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.3709 - mean_squared_error: 5.3167 - val_loss: 1.2308 - val_mean_squared_error: 1.6110 - learning_rate: 0.0055
# Epoch 43/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.2890 - mean_squared_error: 4.3813 - val_loss: 1.4923 - val_mean_squared_error: 2.8618 - learning_rate: 0.0055
# Epoch 44/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 2.5323 - mean_squared_error: 19.3526 - val_loss: 4.2464 - val_mean_squared_error: 30.6476 - learning_rate: 0.0055
# Epoch 45/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 2.2052 - mean_squared_error: 21.7077 - val_loss: 1.7332 - val_mean_squared_error: 4.5077 - learning_rate: 0.0055
# Epoch 46/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.9970 - mean_squared_error: 9.5569 - val_loss: 1.3730 - val_mean_squared_error: 2.6509 - learning_rate: 0.0055
# Epoch 47/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5886 - mean_squared_error: 0.5498 - val_loss: 0.4639 - val_mean_squared_error: 0.2267 - learning_rate: 0.0034
# Epoch 48/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5107 - mean_squared_error: 0.4259 - val_loss: 0.5618 - val_mean_squared_error: 0.3425 - learning_rate: 0.0034
# Epoch 49/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.7836 - mean_squared_error: 1.1736 - val_loss: 1.0035 - val_mean_squared_error: 1.2086 - learning_rate: 0.0034
# Epoch 50/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.6172 - mean_squared_error: 0.5521 - val_loss: 0.7710 - val_mean_squared_error: 0.6939 - learning_rate: 0.0034
# Epoch 51/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.0541 - mean_squared_error: 3.2492 - val_loss: 1.2731 - val_mean_squared_error: 2.4249 - learning_rate: 0.0034
# Epoch 52/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5933 - mean_squared_error: 0.5428 - val_loss: 2.6808 - val_mean_squared_error: 12.6127 - learning_rate: 0.0034
# Epoch 53/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.2461 - mean_squared_error: 5.7243 - val_loss: 1.1292 - val_mean_squared_error: 1.6029 - learning_rate: 0.0034
# Epoch 54/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.7801 - mean_squared_error: 1.2819 - val_loss: 4.5668 - val_mean_squared_error: 40.9702 - learning_rate: 0.0034
# Epoch 55/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 1.2670 - mean_squared_error: 10.0381 - val_loss: 0.6985 - val_mean_squared_error: 0.5685 - learning_rate: 0.0034
# Epoch 56/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.8497 - mean_squared_error: 1.8771 - val_loss: 2.4539 - val_mean_squared_error: 10.3121 - learning_rate: 0.0034
# Epoch 57/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.9687 - mean_squared_error: 2.8645 - val_loss: 0.9960 - val_mean_squared_error: 1.6053 - learning_rate: 0.0034
# Epoch 58/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4378 - mean_squared_error: 0.2923 - val_loss: 0.3715 - val_mean_squared_error: 0.1824 - learning_rate: 0.0021
# Epoch 59/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3674 - mean_squared_error: 0.1705 - val_loss: 0.4596 - val_mean_squared_error: 0.3008 - learning_rate: 0.0021
# Epoch 60/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5491 - mean_squared_error: 0.5518 - val_loss: 0.3559 - val_mean_squared_error: 0.1715 - learning_rate: 0.0021
# Epoch 61/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.4360 - mean_squared_error: 0.2807 - val_loss: 0.7641 - val_mean_squared_error: 0.7118 - learning_rate: 0.0021
# Epoch 62/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5135 - mean_squared_error: 0.4574 - val_loss: 0.3891 - val_mean_squared_error: 0.2058 - learning_rate: 0.0021
# Epoch 63/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5007 - mean_squared_error: 0.4222 - val_loss: 0.4540 - val_mean_squared_error: 0.2393 - learning_rate: 0.0021
# Epoch 64/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5116 - mean_squared_error: 0.4325 - val_loss: 1.3859 - val_mean_squared_error: 2.5642 - learning_rate: 0.0021
# Epoch 65/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5759 - mean_squared_error: 0.7048 - val_loss: 0.4709 - val_mean_squared_error: 0.3179 - learning_rate: 0.0021
# Epoch 66/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4240 - mean_squared_error: 0.2739 - val_loss: 0.3557 - val_mean_squared_error: 0.1594 - learning_rate: 0.0021
# Epoch 67/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4305 - mean_squared_error: 0.2413 - val_loss: 0.4027 - val_mean_squared_error: 0.2020 - learning_rate: 0.0021
# Epoch 68/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3618 - mean_squared_error: 0.1655 - val_loss: 0.4221 - val_mean_squared_error: 0.2470 - learning_rate: 0.0021
# Epoch 69/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4019 - mean_squared_error: 0.2177 - val_loss: 0.8792 - val_mean_squared_error: 1.2491 - learning_rate: 0.0021
# Epoch 70/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5214 - mean_squared_error: 0.4333 - val_loss: 0.6270 - val_mean_squared_error: 0.5151 - learning_rate: 0.0021
# Epoch 71/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.5413 - mean_squared_error: 0.5453 - val_loss: 0.6790 - val_mean_squared_error: 0.6062 - learning_rate: 0.0021
# Epoch 72/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5224 - mean_squared_error: 0.5480 - val_loss: 0.3533 - val_mean_squared_error: 0.1649 - learning_rate: 0.0021
# Epoch 73/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4281 - mean_squared_error: 0.2509 - val_loss: 0.6988 - val_mean_squared_error: 0.6369 - learning_rate: 0.0021
# Epoch 74/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5247 - mean_squared_error: 0.4361 - val_loss: 0.4471 - val_mean_squared_error: 0.2355 - learning_rate: 0.0021
# Epoch 75/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4179 - mean_squared_error: 0.2264 - val_loss: 0.3971 - val_mean_squared_error: 0.1925 - learning_rate: 0.0021
# Epoch 76/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.5712 - mean_squared_error: 0.6463 - val_loss: 0.3963 - val_mean_squared_error: 0.2258 - learning_rate: 0.0021
# Epoch 77/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4754 - mean_squared_error: 0.3307 - val_loss: 0.3837 - val_mean_squared_error: 0.1837 - learning_rate: 0.0021
# Epoch 78/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4109 - mean_squared_error: 0.2621 - val_loss: 0.5354 - val_mean_squared_error: 0.3735 - learning_rate: 0.0021
# Epoch 79/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5195 - mean_squared_error: 0.4527 - val_loss: 0.3463 - val_mean_squared_error: 0.1527 - learning_rate: 0.0021
# Epoch 80/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3975 - mean_squared_error: 0.2089 - val_loss: 0.6372 - val_mean_squared_error: 0.5829 - learning_rate: 0.0021
# Epoch 81/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.4466 - mean_squared_error: 0.2920 - val_loss: 0.4461 - val_mean_squared_error: 0.2567 - learning_rate: 0.0021
# Epoch 82/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4925 - mean_squared_error: 0.4096 - val_loss: 0.3490 - val_mean_squared_error: 0.1567 - learning_rate: 0.0021
# Epoch 83/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3744 - mean_squared_error: 0.1832 - val_loss: 0.4010 - val_mean_squared_error: 0.1916 - learning_rate: 0.0021
# Epoch 84/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4418 - mean_squared_error: 0.2691 - val_loss: 0.3845 - val_mean_squared_error: 0.1862 - learning_rate: 0.0021
# Epoch 85/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3790 - mean_squared_error: 0.1846 - val_loss: 0.3994 - val_mean_squared_error: 0.1948 - learning_rate: 0.0021
# Epoch 86/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.4010 - mean_squared_error: 0.2212 - val_loss: 0.3613 - val_mean_squared_error: 0.1743 - learning_rate: 0.0021
# Epoch 87/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4495 - mean_squared_error: 0.3112 - val_loss: 1.3377 - val_mean_squared_error: 2.6574 - learning_rate: 0.0021
# Epoch 88/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5543 - mean_squared_error: 0.7196 - val_loss: 0.7691 - val_mean_squared_error: 0.7631 - learning_rate: 0.0021
# Epoch 89/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.4983 - mean_squared_error: 0.3937 - val_loss: 0.4437 - val_mean_squared_error: 0.2484 - learning_rate: 0.0021
# Epoch 90/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3297 - mean_squared_error: 0.1510 - val_loss: 0.3580 - val_mean_squared_error: 0.1862 - learning_rate: 0.0013
# Epoch 91/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3183 - mean_squared_error: 0.1433 - val_loss: 0.3228 - val_mean_squared_error: 0.1523 - learning_rate: 0.0013
# Epoch 92/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3679 - mean_squared_error: 0.2139 - val_loss: 0.3349 - val_mean_squared_error: 0.1733 - learning_rate: 0.0013
# Epoch 93/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3280 - mean_squared_error: 0.1545 - val_loss: 0.3269 - val_mean_squared_error: 0.1555 - learning_rate: 0.0013
# Epoch 94/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3400 - mean_squared_error: 0.1685 - val_loss: 0.3139 - val_mean_squared_error: 0.1489 - learning_rate: 0.0013
# Epoch 95/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3215 - mean_squared_error: 0.1458 - val_loss: 0.3659 - val_mean_squared_error: 0.1885 - learning_rate: 0.0013
# Epoch 96/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3342 - mean_squared_error: 0.1601 - val_loss: 0.3252 - val_mean_squared_error: 0.1570 - learning_rate: 0.0013
# Epoch 97/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.3304 - mean_squared_error: 0.1575 - val_loss: 0.3384 - val_mean_squared_error: 0.1631 - learning_rate: 0.0013
# Epoch 98/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3181 - mean_squared_error: 0.1436 - val_loss: 0.3360 - val_mean_squared_error: 0.1601 - learning_rate: 0.0013
# Epoch 99/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3319 - mean_squared_error: 0.1563 - val_loss: 0.4580 - val_mean_squared_error: 0.2775 - learning_rate: 0.0013
# Epoch 100/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3636 - mean_squared_error: 0.1927 - val_loss: 0.3503 - val_mean_squared_error: 0.1824 - learning_rate: 0.0013
# Epoch 101/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3322 - mean_squared_error: 0.1565 - val_loss: 0.3222 - val_mean_squared_error: 0.1569 - learning_rate: 0.0013
# Epoch 102/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.3106 - mean_squared_error: 0.1370 - val_loss: 0.3252 - val_mean_squared_error: 0.1615 - learning_rate: 0.0013
# Epoch 103/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3407 - mean_squared_error: 0.1687 - val_loss: 0.3441 - val_mean_squared_error: 0.1670 - learning_rate: 0.0013
# Epoch 104/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3595 - mean_squared_error: 0.1844 - val_loss: 0.3402 - val_mean_squared_error: 0.1740 - learning_rate: 0.0013
# Epoch 105/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2898 - mean_squared_error: 0.1313 - val_loss: 0.3250 - val_mean_squared_error: 0.1649 - learning_rate: 7.7393e-04
# Epoch 106/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2874 - mean_squared_error: 0.1308 - val_loss: 0.3093 - val_mean_squared_error: 0.1528 - learning_rate: 7.7393e-04
# Epoch 107/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2870 - mean_squared_error: 0.1309 - val_loss: 0.3102 - val_mean_squared_error: 0.1528 - learning_rate: 7.7393e-04
# Epoch 108/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2903 - mean_squared_error: 0.1317 - val_loss: 0.3225 - val_mean_squared_error: 0.1657 - learning_rate: 7.7393e-04
# Epoch 109/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2925 - mean_squared_error: 0.1336 - val_loss: 0.3097 - val_mean_squared_error: 0.1552 - learning_rate: 7.7393e-04
# Epoch 110/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2862 - mean_squared_error: 0.1304 - val_loss: 0.3143 - val_mean_squared_error: 0.1590 - learning_rate: 7.7393e-04
# Epoch 111/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2962 - mean_squared_error: 0.1353 - val_loss: 0.3119 - val_mean_squared_error: 0.1557 - learning_rate: 7.7393e-04
# Epoch 112/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2901 - mean_squared_error: 0.1315 - val_loss: 0.3079 - val_mean_squared_error: 0.1518 - learning_rate: 7.7393e-04
# Epoch 113/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2926 - mean_squared_error: 0.1325 - val_loss: 0.3110 - val_mean_squared_error: 0.1575 - learning_rate: 7.7393e-04
# Epoch 114/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2942 - mean_squared_error: 0.1337 - val_loss: 0.3185 - val_mean_squared_error: 0.1615 - learning_rate: 7.7393e-04
# Epoch 115/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2872 - mean_squared_error: 0.1317 - val_loss: 0.3045 - val_mean_squared_error: 0.1506 - learning_rate: 7.7393e-04
# Epoch 116/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2873 - mean_squared_error: 0.1303 - val_loss: 0.3048 - val_mean_squared_error: 0.1500 - learning_rate: 7.7393e-04
# Epoch 117/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2838 - mean_squared_error: 0.1283 - val_loss: 0.3108 - val_mean_squared_error: 0.1581 - learning_rate: 7.7393e-04
# Epoch 118/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2973 - mean_squared_error: 0.1370 - val_loss: 0.3071 - val_mean_squared_error: 0.1532 - learning_rate: 7.7393e-04
# Epoch 119/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2878 - mean_squared_error: 0.1313 - val_loss: 0.3169 - val_mean_squared_error: 0.1609 - learning_rate: 7.7393e-04
# Epoch 120/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2943 - mean_squared_error: 0.1339 - val_loss: 0.3044 - val_mean_squared_error: 0.1505 - learning_rate: 7.7393e-04
# Epoch 121/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2876 - mean_squared_error: 0.1304 - val_loss: 0.3143 - val_mean_squared_error: 0.1549 - learning_rate: 7.7393e-04
# Epoch 122/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.3011 - mean_squared_error: 0.1388 - val_loss: 0.3318 - val_mean_squared_error: 0.1768 - learning_rate: 7.7393e-04
# Epoch 123/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2908 - mean_squared_error: 0.1333 - val_loss: 0.3202 - val_mean_squared_error: 0.1623 - learning_rate: 7.7393e-04
# Epoch 124/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2917 - mean_squared_error: 0.1336 - val_loss: 0.3294 - val_mean_squared_error: 0.1745 - learning_rate: 7.7393e-04
# Epoch 125/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2911 - mean_squared_error: 0.1328 - val_loss: 0.3352 - val_mean_squared_error: 0.1798 - learning_rate: 7.7393e-04
# Epoch 126/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2762 - mean_squared_error: 0.1279 - val_loss: 0.3026 - val_mean_squared_error: 0.1512 - learning_rate: 4.7372e-04
# Epoch 127/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2741 - mean_squared_error: 0.1271 - val_loss: 0.3026 - val_mean_squared_error: 0.1516 - learning_rate: 4.7372e-04
# Epoch 128/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2732 - mean_squared_error: 0.1262 - val_loss: 0.3160 - val_mean_squared_error: 0.1586 - learning_rate: 4.7372e-04
# Epoch 129/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2745 - mean_squared_error: 0.1264 - val_loss: 0.3013 - val_mean_squared_error: 0.1503 - learning_rate: 4.7372e-04
# Epoch 130/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2718 - mean_squared_error: 0.1244 - val_loss: 0.3001 - val_mean_squared_error: 0.1508 - learning_rate: 4.7372e-04
# Epoch 131/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2732 - mean_squared_error: 0.1258 - val_loss: 0.3066 - val_mean_squared_error: 0.1527 - learning_rate: 4.7372e-04
# Epoch 132/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2721 - mean_squared_error: 0.1257 - val_loss: 0.2998 - val_mean_squared_error: 0.1515 - learning_rate: 4.7372e-04
# Epoch 133/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2714 - mean_squared_error: 0.1260 - val_loss: 0.3011 - val_mean_squared_error: 0.1508 - learning_rate: 4.7372e-04
# Epoch 134/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2721 - mean_squared_error: 0.1254 - val_loss: 0.2999 - val_mean_squared_error: 0.1498 - learning_rate: 4.7372e-04
# Epoch 135/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2726 - mean_squared_error: 0.1250 - val_loss: 0.3044 - val_mean_squared_error: 0.1561 - learning_rate: 4.7372e-04
# Epoch 136/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2725 - mean_squared_error: 0.1256 - val_loss: 0.2993 - val_mean_squared_error: 0.1503 - learning_rate: 4.7372e-04
# Epoch 137/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2720 - mean_squared_error: 0.1255 - val_loss: 0.2999 - val_mean_squared_error: 0.1500 - learning_rate: 4.7372e-04
# Epoch 138/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2748 - mean_squared_error: 0.1258 - val_loss: 0.3005 - val_mean_squared_error: 0.1504 - learning_rate: 4.7372e-04
# Epoch 139/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2719 - mean_squared_error: 0.1252 - val_loss: 0.3026 - val_mean_squared_error: 0.1513 - learning_rate: 4.7372e-04
# Epoch 140/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2721 - mean_squared_error: 0.1256 - val_loss: 0.3042 - val_mean_squared_error: 0.1517 - learning_rate: 4.7372e-04
# Epoch 141/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2744 - mean_squared_error: 0.1266 - val_loss: 0.2989 - val_mean_squared_error: 0.1492 - learning_rate: 4.7372e-04
# Epoch 142/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2722 - mean_squared_error: 0.1255 - val_loss: 0.2993 - val_mean_squared_error: 0.1500 - learning_rate: 4.7372e-04
# Epoch 143/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2719 - mean_squared_error: 0.1252 - val_loss: 0.2984 - val_mean_squared_error: 0.1510 - learning_rate: 4.7372e-04
# Epoch 144/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2713 - mean_squared_error: 0.1255 - val_loss: 0.3015 - val_mean_squared_error: 0.1507 - learning_rate: 4.7372e-04
# Epoch 145/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2724 - mean_squared_error: 0.1258 - val_loss: 0.3005 - val_mean_squared_error: 0.1509 - learning_rate: 4.7372e-04
# Epoch 146/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2721 - mean_squared_error: 0.1259 - val_loss: 0.3000 - val_mean_squared_error: 0.1517 - learning_rate: 4.7372e-04
# Epoch 147/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2711 - mean_squared_error: 0.1247 - val_loss: 0.3043 - val_mean_squared_error: 0.1515 - learning_rate: 4.7372e-04
# Epoch 148/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2735 - mean_squared_error: 0.1260 - val_loss: 0.2985 - val_mean_squared_error: 0.1497 - learning_rate: 4.7372e-04
# Epoch 149/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2716 - mean_squared_error: 0.1256 - val_loss: 0.3010 - val_mean_squared_error: 0.1518 - learning_rate: 4.7372e-04
# Epoch 150/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2715 - mean_squared_error: 0.1252 - val_loss: 0.2997 - val_mean_squared_error: 0.1504 - learning_rate: 4.7372e-04
# Epoch 151/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2719 - mean_squared_error: 0.1253 - val_loss: 0.3031 - val_mean_squared_error: 0.1570 - learning_rate: 4.7372e-04
# Epoch 152/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2719 - mean_squared_error: 0.1264 - val_loss: 0.2988 - val_mean_squared_error: 0.1495 - learning_rate: 4.7372e-04
# Epoch 153/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2708 - mean_squared_error: 0.1249 - val_loss: 0.2981 - val_mean_squared_error: 0.1490 - learning_rate: 4.7372e-04
# Epoch 154/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2711 - mean_squared_error: 0.1253 - val_loss: 0.3000 - val_mean_squared_error: 0.1501 - learning_rate: 4.7372e-04
# Epoch 155/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2725 - mean_squared_error: 0.1254 - val_loss: 0.2997 - val_mean_squared_error: 0.1505 - learning_rate: 4.7372e-04
# Epoch 156/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2723 - mean_squared_error: 0.1253 - val_loss: 0.3007 - val_mean_squared_error: 0.1519 - learning_rate: 4.7372e-04
# Epoch 157/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2716 - mean_squared_error: 0.1255 - val_loss: 0.2986 - val_mean_squared_error: 0.1504 - learning_rate: 4.7372e-04
# Epoch 158/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2719 - mean_squared_error: 0.1252 - val_loss: 0.3009 - val_mean_squared_error: 0.1508 - learning_rate: 4.7372e-04
# Epoch 159/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2722 - mean_squared_error: 0.1254 - val_loss: 0.3034 - val_mean_squared_error: 0.1529 - learning_rate: 4.7372e-04
# Epoch 160/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2719 - mean_squared_error: 0.1257 - val_loss: 0.3003 - val_mean_squared_error: 0.1504 - learning_rate: 4.7372e-04
# Epoch 161/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2717 - mean_squared_error: 0.1252 - val_loss: 0.3021 - val_mean_squared_error: 0.1533 - learning_rate: 4.7372e-04
# Epoch 162/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2716 - mean_squared_error: 0.1254 - val_loss: 0.3017 - val_mean_squared_error: 0.1540 - learning_rate: 4.7372e-04
# Epoch 163/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2737 - mean_squared_error: 0.1267 - val_loss: 0.3005 - val_mean_squared_error: 0.1504 - learning_rate: 4.7372e-04
# Epoch 164/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2663 - mean_squared_error: 0.1239 - val_loss: 0.2950 - val_mean_squared_error: 0.1505 - learning_rate: 2.8996e-04
# Epoch 165/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2635 - mean_squared_error: 0.1231 - val_loss: 0.2974 - val_mean_squared_error: 0.1510 - learning_rate: 2.8996e-04
# Epoch 166/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2639 - mean_squared_error: 0.1233 - val_loss: 0.2930 - val_mean_squared_error: 0.1501 - learning_rate: 2.8996e-04
# Epoch 167/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2633 - mean_squared_error: 0.1232 - val_loss: 0.2978 - val_mean_squared_error: 0.1513 - learning_rate: 2.8996e-04
# Epoch 168/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2647 - mean_squared_error: 0.1237 - val_loss: 0.3001 - val_mean_squared_error: 0.1520 - learning_rate: 2.8996e-04
# Epoch 169/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2639 - mean_squared_error: 0.1232 - val_loss: 0.2947 - val_mean_squared_error: 0.1514 - learning_rate: 2.8996e-04
# Epoch 170/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2640 - mean_squared_error: 0.1240 - val_loss: 0.2988 - val_mean_squared_error: 0.1514 - learning_rate: 2.8996e-04
# Epoch 171/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2647 - mean_squared_error: 0.1236 - val_loss: 0.2929 - val_mean_squared_error: 0.1499 - learning_rate: 2.8996e-04
# Epoch 172/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2633 - mean_squared_error: 0.1230 - val_loss: 0.2947 - val_mean_squared_error: 0.1499 - learning_rate: 2.8996e-04
# Epoch 173/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2641 - mean_squared_error: 0.1236 - val_loss: 0.2959 - val_mean_squared_error: 0.1507 - learning_rate: 2.8996e-04
# Epoch 174/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2648 - mean_squared_error: 0.1235 - val_loss: 0.2980 - val_mean_squared_error: 0.1511 - learning_rate: 2.8996e-04
# Epoch 175/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2648 - mean_squared_error: 0.1237 - val_loss: 0.2927 - val_mean_squared_error: 0.1495 - learning_rate: 2.8996e-04
# Epoch 176/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2644 - mean_squared_error: 0.1233 - val_loss: 0.2938 - val_mean_squared_error: 0.1501 - learning_rate: 2.8996e-04
# Epoch 177/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2646 - mean_squared_error: 0.1236 - val_loss: 0.2928 - val_mean_squared_error: 0.1496 - learning_rate: 2.8996e-04
# Epoch 178/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2630 - mean_squared_error: 0.1227 - val_loss: 0.2974 - val_mean_squared_error: 0.1510 - learning_rate: 2.8996e-04
# Epoch 179/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2649 - mean_squared_error: 0.1236 - val_loss: 0.2944 - val_mean_squared_error: 0.1503 - learning_rate: 2.8996e-04
# Epoch 180/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2647 - mean_squared_error: 0.1239 - val_loss: 0.2950 - val_mean_squared_error: 0.1503 - learning_rate: 2.8996e-04
# Epoch 181/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2644 - mean_squared_error: 0.1234 - val_loss: 0.2996 - val_mean_squared_error: 0.1517 - learning_rate: 2.8996e-04
# Epoch 182/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2644 - mean_squared_error: 0.1232 - val_loss: 0.2979 - val_mean_squared_error: 0.1513 - learning_rate: 2.8996e-04
# Epoch 183/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2647 - mean_squared_error: 0.1233 - val_loss: 0.2957 - val_mean_squared_error: 0.1502 - learning_rate: 2.8996e-04
# Epoch 184/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2644 - mean_squared_error: 0.1235 - val_loss: 0.2959 - val_mean_squared_error: 0.1511 - learning_rate: 2.8996e-04
# Epoch 185/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2642 - mean_squared_error: 0.1233 - val_loss: 0.2966 - val_mean_squared_error: 0.1507 - learning_rate: 2.8996e-04
# Epoch 186/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2608 - mean_squared_error: 0.1228 - val_loss: 0.2916 - val_mean_squared_error: 0.1499 - learning_rate: 1.7749e-04
# Epoch 187/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2598 - mean_squared_error: 0.1224 - val_loss: 0.2905 - val_mean_squared_error: 0.1493 - learning_rate: 1.7749e-04
# Epoch 188/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.2590 - mean_squared_error: 0.1221 - val_loss: 0.2924 - val_mean_squared_error: 0.1501 - learning_rate: 1.7749e-04
# Epoch 189/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2593 - mean_squared_error: 0.1219 - val_loss: 0.2936 - val_mean_squared_error: 0.1506 - learning_rate: 1.7749e-04
# Epoch 190/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2596 - mean_squared_error: 0.1221 - val_loss: 0.2936 - val_mean_squared_error: 0.1509 - learning_rate: 1.7749e-04
# Epoch 191/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2603 - mean_squared_error: 0.1228 - val_loss: 0.2916 - val_mean_squared_error: 0.1502 - learning_rate: 1.7749e-04
# Epoch 192/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2593 - mean_squared_error: 0.1221 - val_loss: 0.2922 - val_mean_squared_error: 0.1500 - learning_rate: 1.7749e-04
# Epoch 193/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2589 - mean_squared_error: 0.1220 - val_loss: 0.2940 - val_mean_squared_error: 0.1508 - learning_rate: 1.7749e-04
# Epoch 194/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2595 - mean_squared_error: 0.1223 - val_loss: 0.2927 - val_mean_squared_error: 0.1503 - learning_rate: 1.7749e-04
# Epoch 195/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2590 - mean_squared_error: 0.1220 - val_loss: 0.2908 - val_mean_squared_error: 0.1498 - learning_rate: 1.7749e-04
# Epoch 196/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2591 - mean_squared_error: 0.1221 - val_loss: 0.2909 - val_mean_squared_error: 0.1496 - learning_rate: 1.7749e-04
# Epoch 197/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2595 - mean_squared_error: 0.1219 - val_loss: 0.2896 - val_mean_squared_error: 0.1494 - learning_rate: 1.7749e-04
# Epoch 198/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2584 - mean_squared_error: 0.1217 - val_loss: 0.2912 - val_mean_squared_error: 0.1498 - learning_rate: 1.7749e-04
# Epoch 199/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2586 - mean_squared_error: 0.1217 - val_loss: 0.2929 - val_mean_squared_error: 0.1501 - learning_rate: 1.7749e-04
# Epoch 200/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2592 - mean_squared_error: 0.1218 - val_loss: 0.2890 - val_mean_squared_error: 0.1487 - learning_rate: 1.7749e-04
# Epoch 201/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2586 - mean_squared_error: 0.1218 - val_loss: 0.2910 - val_mean_squared_error: 0.1499 - learning_rate: 1.7749e-04
# Epoch 202/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2595 - mean_squared_error: 0.1221 - val_loss: 0.2895 - val_mean_squared_error: 0.1491 - learning_rate: 1.7749e-04
# Epoch 203/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2588 - mean_squared_error: 0.1217 - val_loss: 0.2906 - val_mean_squared_error: 0.1496 - learning_rate: 1.7749e-04
# Epoch 204/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2593 - mean_squared_error: 0.1223 - val_loss: 0.2890 - val_mean_squared_error: 0.1492 - learning_rate: 1.7749e-04
# Epoch 205/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2587 - mean_squared_error: 0.1216 - val_loss: 0.2898 - val_mean_squared_error: 0.1497 - learning_rate: 1.7749e-04
# Epoch 206/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2587 - mean_squared_error: 0.1220 - val_loss: 0.2941 - val_mean_squared_error: 0.1508 - learning_rate: 1.7749e-04
# Epoch 207/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2595 - mean_squared_error: 0.1221 - val_loss: 0.2906 - val_mean_squared_error: 0.1495 - learning_rate: 1.7749e-04
# Epoch 208/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2588 - mean_squared_error: 0.1218 - val_loss: 0.2896 - val_mean_squared_error: 0.1497 - learning_rate: 1.7749e-04
# Epoch 209/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2591 - mean_squared_error: 0.1220 - val_loss: 0.2891 - val_mean_squared_error: 0.1490 - learning_rate: 1.7749e-04
# Epoch 210/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2586 - mean_squared_error: 0.1216 - val_loss: 0.2908 - val_mean_squared_error: 0.1494 - learning_rate: 1.7749e-04
# Epoch 211/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2578 - mean_squared_error: 0.1220 - val_loss: 0.2857 - val_mean_squared_error: 0.1485 - learning_rate: 1.0864e-04
# Epoch 212/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2560 - mean_squared_error: 0.1214 - val_loss: 0.2857 - val_mean_squared_error: 0.1488 - learning_rate: 1.0864e-04
# Epoch 213/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2561 - mean_squared_error: 0.1210 - val_loss: 0.2856 - val_mean_squared_error: 0.1487 - learning_rate: 1.0864e-04
# Epoch 214/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2563 - mean_squared_error: 0.1214 - val_loss: 0.2869 - val_mean_squared_error: 0.1490 - learning_rate: 1.0864e-04
# Epoch 215/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2564 - mean_squared_error: 0.1214 - val_loss: 0.2887 - val_mean_squared_error: 0.1493 - learning_rate: 1.0864e-04
# Epoch 216/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2565 - mean_squared_error: 0.1213 - val_loss: 0.2863 - val_mean_squared_error: 0.1489 - learning_rate: 1.0864e-04
# Epoch 217/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2563 - mean_squared_error: 0.1214 - val_loss: 0.2861 - val_mean_squared_error: 0.1488 - learning_rate: 1.0864e-04
# Epoch 218/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2559 - mean_squared_error: 0.1211 - val_loss: 0.2860 - val_mean_squared_error: 0.1486 - learning_rate: 1.0864e-04
# Epoch 219/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2562 - mean_squared_error: 0.1212 - val_loss: 0.2876 - val_mean_squared_error: 0.1496 - learning_rate: 1.0864e-04
# Epoch 220/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2563 - mean_squared_error: 0.1212 - val_loss: 0.2887 - val_mean_squared_error: 0.1491 - learning_rate: 1.0864e-04
# Epoch 221/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2567 - mean_squared_error: 0.1213 - val_loss: 0.2857 - val_mean_squared_error: 0.1484 - learning_rate: 1.0864e-04
# Epoch 222/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2561 - mean_squared_error: 0.1209 - val_loss: 0.2859 - val_mean_squared_error: 0.1481 - learning_rate: 1.0864e-04
# Epoch 223/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2556 - mean_squared_error: 0.1208 - val_loss: 0.2891 - val_mean_squared_error: 0.1495 - learning_rate: 1.0864e-04
# Epoch 224/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2563 - mean_squared_error: 0.1216 - val_loss: 0.2823 - val_mean_squared_error: 0.1489 - learning_rate: 6.6497e-05
# Epoch 225/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2546 - mean_squared_error: 0.1209 - val_loss: 0.2845 - val_mean_squared_error: 0.1487 - learning_rate: 6.6497e-05
# Epoch 226/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2549 - mean_squared_error: 0.1211 - val_loss: 0.2833 - val_mean_squared_error: 0.1488 - learning_rate: 6.6497e-05
# Epoch 227/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2545 - mean_squared_error: 0.1206 - val_loss: 0.2831 - val_mean_squared_error: 0.1485 - learning_rate: 6.6497e-05
# Epoch 228/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2548 - mean_squared_error: 0.1211 - val_loss: 0.2829 - val_mean_squared_error: 0.1486 - learning_rate: 6.6497e-05
# Epoch 229/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2547 - mean_squared_error: 0.1210 - val_loss: 0.2819 - val_mean_squared_error: 0.1482 - learning_rate: 6.6497e-05
# Epoch 230/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2544 - mean_squared_error: 0.1211 - val_loss: 0.2829 - val_mean_squared_error: 0.1486 - learning_rate: 6.6497e-05
# Epoch 231/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2548 - mean_squared_error: 0.1213 - val_loss: 0.2833 - val_mean_squared_error: 0.1486 - learning_rate: 6.6497e-05
# Epoch 232/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2544 - mean_squared_error: 0.1210 - val_loss: 0.2816 - val_mean_squared_error: 0.1485 - learning_rate: 6.6497e-05
# Epoch 233/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2546 - mean_squared_error: 0.1208 - val_loss: 0.2843 - val_mean_squared_error: 0.1489 - learning_rate: 6.6497e-05
# Epoch 234/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2547 - mean_squared_error: 0.1211 - val_loss: 0.2825 - val_mean_squared_error: 0.1486 - learning_rate: 6.6497e-05
# Epoch 235/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2543 - mean_squared_error: 0.1206 - val_loss: 0.2822 - val_mean_squared_error: 0.1487 - learning_rate: 6.6497e-05
# Epoch 236/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2546 - mean_squared_error: 0.1208 - val_loss: 0.2819 - val_mean_squared_error: 0.1484 - learning_rate: 6.6497e-05
# Epoch 237/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2545 - mean_squared_error: 0.1208 - val_loss: 0.2836 - val_mean_squared_error: 0.1487 - learning_rate: 6.6497e-05
# Epoch 238/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2542 - mean_squared_error: 0.1207 - val_loss: 0.2835 - val_mean_squared_error: 0.1486 - learning_rate: 6.6497e-05
# Epoch 239/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2549 - mean_squared_error: 0.1210 - val_loss: 0.2828 - val_mean_squared_error: 0.1486 - learning_rate: 6.6497e-05
# Epoch 240/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2545 - mean_squared_error: 0.1210 - val_loss: 0.2835 - val_mean_squared_error: 0.1490 - learning_rate: 6.6497e-05
# Epoch 241/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2553 - mean_squared_error: 0.1213 - val_loss: 0.2836 - val_mean_squared_error: 0.1487 - learning_rate: 6.6497e-05
# Epoch 242/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2545 - mean_squared_error: 0.1209 - val_loss: 0.2820 - val_mean_squared_error: 0.1488 - learning_rate: 6.6497e-05
# Epoch 243/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2541 - mean_squared_error: 0.1209 - val_loss: 0.2801 - val_mean_squared_error: 0.1488 - learning_rate: 4.0703e-05
# Epoch 244/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2535 - mean_squared_error: 0.1207 - val_loss: 0.2800 - val_mean_squared_error: 0.1489 - learning_rate: 4.0703e-05
# Epoch 245/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2534 - mean_squared_error: 0.1207 - val_loss: 0.2799 - val_mean_squared_error: 0.1491 - learning_rate: 4.0703e-05
# Epoch 246/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2532 - mean_squared_error: 0.1208 - val_loss: 0.2799 - val_mean_squared_error: 0.1487 - learning_rate: 4.0703e-05
# Epoch 247/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2528 - mean_squared_error: 0.1205 - val_loss: 0.2797 - val_mean_squared_error: 0.1488 - learning_rate: 4.0703e-05
# Epoch 248/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2533 - mean_squared_error: 0.1207 - val_loss: 0.2802 - val_mean_squared_error: 0.1484 - learning_rate: 4.0703e-05
# Epoch 249/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2537 - mean_squared_error: 0.1208 - val_loss: 0.2794 - val_mean_squared_error: 0.1487 - learning_rate: 4.0703e-05
# Epoch 250/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2533 - mean_squared_error: 0.1207 - val_loss: 0.2801 - val_mean_squared_error: 0.1492 - learning_rate: 4.0703e-05
# Epoch 251/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2537 - mean_squared_error: 0.1210 - val_loss: 0.2799 - val_mean_squared_error: 0.1490 - learning_rate: 4.0703e-05
# Epoch 252/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2532 - mean_squared_error: 0.1207 - val_loss: 0.2801 - val_mean_squared_error: 0.1489 - learning_rate: 4.0703e-05
# Epoch 253/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2535 - mean_squared_error: 0.1209 - val_loss: 0.2801 - val_mean_squared_error: 0.1485 - learning_rate: 4.0703e-05
# Epoch 254/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2532 - mean_squared_error: 0.1206 - val_loss: 0.2800 - val_mean_squared_error: 0.1493 - learning_rate: 4.0703e-05
# Epoch 255/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2529 - mean_squared_error: 0.1205 - val_loss: 0.2798 - val_mean_squared_error: 0.1487 - learning_rate: 4.0703e-05
# Epoch 256/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2531 - mean_squared_error: 0.1205 - val_loss: 0.2793 - val_mean_squared_error: 0.1488 - learning_rate: 4.0703e-05
# Epoch 257/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2531 - mean_squared_error: 0.1204 - val_loss: 0.2796 - val_mean_squared_error: 0.1485 - learning_rate: 4.0703e-05
# Epoch 258/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2533 - mean_squared_error: 0.1207 - val_loss: 0.2799 - val_mean_squared_error: 0.1486 - learning_rate: 4.0703e-05
# Epoch 259/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2532 - mean_squared_error: 0.1207 - val_loss: 0.2798 - val_mean_squared_error: 0.1488 - learning_rate: 4.0703e-05
# Epoch 260/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2534 - mean_squared_error: 0.1206 - val_loss: 0.2794 - val_mean_squared_error: 0.1486 - learning_rate: 4.0703e-05
# Epoch 261/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2533 - mean_squared_error: 0.1207 - val_loss: 0.2795 - val_mean_squared_error: 0.1486 - learning_rate: 4.0703e-05
# Epoch 262/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2534 - mean_squared_error: 0.1208 - val_loss: 0.2799 - val_mean_squared_error: 0.1486 - learning_rate: 4.0703e-05
# Epoch 263/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2529 - mean_squared_error: 0.1206 - val_loss: 0.2799 - val_mean_squared_error: 0.1488 - learning_rate: 4.0703e-05
# Epoch 264/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2529 - mean_squared_error: 0.1207 - val_loss: 0.2800 - val_mean_squared_error: 0.1484 - learning_rate: 4.0703e-05
# Epoch 265/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2533 - mean_squared_error: 0.1206 - val_loss: 0.2800 - val_mean_squared_error: 0.1487 - learning_rate: 4.0703e-05
# Epoch 266/1000
# ...
# Epoch 276/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2525 - mean_squared_error: 0.1206 - val_loss: 0.2788 - val_mean_squared_error: 0.1492 - learning_rate: 2.4914e-05
# Epoch 277/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2522 - mean_squared_error: 0.1205 - val_loss: 0.2787 - val_mean_squared_error: 0.1492 - learning_rate: 2.4914e-05
# Epoch 278/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2525 - mean_squared_error: 0.1207 - val_loss: 0.2787 - val_mean_squared_error: 0.1494 - learning_rate: 2.4914e-05
# Epoch 279/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2527 - mean_squared_error: 0.1208 - val_loss: 0.2789 - val_mean_squared_error: 0.1494 - learning_rate: 2.4914e-05
# Epoch 280/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2522 - mean_squared_error: 0.1208 - val_loss: 0.2783 - val_mean_squared_error: 0.1496 - learning_rate: 1.5250e-05
# Epoch 281/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2518 - mean_squared_error: 0.1206 - val_loss: 0.2783 - val_mean_squared_error: 0.1496 - learning_rate: 1.5250e-05
# Epoch 282/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2521 - mean_squared_error: 0.1206 - val_loss: 0.2782 - val_mean_squared_error: 0.1496 - learning_rate: 1.5250e-05
# Epoch 283/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2518 - mean_squared_error: 0.1207 - val_loss: 0.2783 - val_mean_squared_error: 0.1497 - learning_rate: 1.5250e-05
# Epoch 284/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2524 - mean_squared_error: 0.1209 - val_loss: 0.2783 - val_mean_squared_error: 0.1493 - learning_rate: 1.5250e-05
# Epoch 285/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2523 - mean_squared_error: 0.1208 - val_loss: 0.2782 - val_mean_squared_error: 0.1494 - learning_rate: 1.5250e-05
# Epoch 286/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2522 - mean_squared_error: 0.1208 - val_loss: 0.2782 - val_mean_squared_error: 0.1494 - learning_rate: 1.5250e-05
# Epoch 287/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2523 - mean_squared_error: 0.1207 - val_loss: 0.2783 - val_mean_squared_error: 0.1494 - learning_rate: 1.5250e-05
# Epoch 288/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2520 - mean_squared_error: 0.1206 - val_loss: 0.2783 - val_mean_squared_error: 0.1494 - learning_rate: 1.5250e-05
# Epoch 289/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1205 - val_loss: 0.2782 - val_mean_squared_error: 0.1495 - learning_rate: 1.5250e-05
# Epoch 290/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2522 - mean_squared_error: 0.1206 - val_loss: 0.2783 - val_mean_squared_error: 0.1494 - learning_rate: 1.5250e-05
# Epoch 291/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2518 - mean_squared_error: 0.1205 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 9.3343e-06
# Epoch 292/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2520 - mean_squared_error: 0.1207 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 9.3343e-06
# Epoch 293/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1206 - val_loss: 0.2780 - val_mean_squared_error: 0.1493 - learning_rate: 9.3343e-06
# Epoch 294/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2520 - mean_squared_error: 0.1206 - val_loss: 0.2781 - val_mean_squared_error: 0.1496 - learning_rate: 9.3343e-06
# Epoch 295/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2519 - mean_squared_error: 0.1206 - val_loss: 0.2782 - val_mean_squared_error: 0.1497 - learning_rate: 9.3343e-06
# Epoch 296/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2519 - mean_squared_error: 0.1207 - val_loss: 0.2781 - val_mean_squared_error: 0.1496 - learning_rate: 9.3343e-06
# Epoch 297/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1203 - val_loss: 0.2781 - val_mean_squared_error: 0.1496 - learning_rate: 9.3343e-06
# Epoch 298/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2518 - mean_squared_error: 0.1205 - val_loss: 0.2781 - val_mean_squared_error: 0.1495 - learning_rate: 9.3343e-06
# Epoch 299/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1205 - val_loss: 0.2781 - val_mean_squared_error: 0.1495 - learning_rate: 9.3343e-06
# Epoch 300/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1204 - val_loss: 0.2781 - val_mean_squared_error: 0.1495 - learning_rate: 9.3343e-06
# Epoch 301/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2521 - mean_squared_error: 0.1208 - val_loss: 0.2782 - val_mean_squared_error: 0.1496 - learning_rate: 9.3343e-06
# Epoch 302/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2518 - mean_squared_error: 0.1204 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 5.7135e-06
# Epoch 303/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1205 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 5.7135e-06
# Epoch 304/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2519 - mean_squared_error: 0.1208 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 5.7135e-06
# Epoch 305/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2519 - mean_squared_error: 0.1207 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 5.7135e-06
# Epoch 306/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1204 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 5.7135e-06
# Epoch 307/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2518 - mean_squared_error: 0.1206 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 5.7135e-06
# Epoch 308/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1206 - val_loss: 0.2780 - val_mean_squared_error: 0.1497 - learning_rate: 5.7135e-06
# Epoch 309/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2519 - mean_squared_error: 0.1205 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 5.7135e-06
# Epoch 310/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 5.7135e-06
# Epoch 311/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2520 - mean_squared_error: 0.1207 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 5.7135e-06
# Epoch 312/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1496 - learning_rate: 3.4972e-06
# Epoch 313/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2521 - mean_squared_error: 0.1207 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 3.4972e-06
# Epoch 314/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 315/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1204 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 316/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2519 - mean_squared_error: 0.1207 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 317/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1207 - val_loss: 0.2779 - val_mean_squared_error: 0.1496 - learning_rate: 3.4972e-06
# Epoch 318/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1205 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 319/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1205 - val_loss: 0.2780 - val_mean_squared_error: 0.1497 - learning_rate: 3.4972e-06
# Epoch 320/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2514 - mean_squared_error: 0.1206 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 321/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2514 - mean_squared_error: 0.1204 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 322/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2512 - mean_squared_error: 0.1205 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 3.4972e-06
# Epoch 323/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1205 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 324/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1206 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 325/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1204 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 3.4972e-06
# Epoch 326/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2518 - mean_squared_error: 0.1207 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 3.4972e-06
# Epoch 327/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1496 - learning_rate: 2.1406e-06
# Epoch 328/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1207 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 2.1406e-06
# Epoch 329/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 2.1406e-06
# Epoch 330/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1206 - val_loss: 0.2780 - val_mean_squared_error: 0.1496 - learning_rate: 2.1406e-06
# Epoch 331/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 2.1406e-06
# Epoch 332/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1206 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 2.1406e-06
# Epoch 333/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1208 - val_loss: 0.2779 - val_mean_squared_error: 0.1496 - learning_rate: 2.1406e-06
# Epoch 334/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1205 - val_loss: 0.2780 - val_mean_squared_error: 0.1495 - learning_rate: 2.1406e-06
# Epoch 335/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2514 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 2.1406e-06
# Epoch 336/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2519 - mean_squared_error: 0.1209 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 2.1406e-06
# Epoch 337/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1209 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 1.3103e-06
# Epoch 338/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1207 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 1.3103e-06
# Epoch 339/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1205 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 1.3103e-06
# Epoch 340/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2520 - mean_squared_error: 0.1209 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 1.3103e-06
# Epoch 341/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2514 - mean_squared_error: 0.1203 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 1.3103e-06
# Epoch 342/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1207 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 1.3103e-06
# Epoch 343/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 1.3103e-06
# Epoch 344/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1208 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 1.3103e-06
# Epoch 345/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2510 - mean_squared_error: 0.1205 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 1.3103e-06
# Epoch 346/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2512 - mean_squared_error: 0.1204 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 1.3103e-06
# Epoch 347/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1205 - val_loss: 0.2779 - val_mean_squared_error: 0.1495 - learning_rate: 8.0202e-07
# Epoch 348/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1204 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 349/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 350/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2518 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 351/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 352/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2516 - mean_squared_error: 0.1207 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 353/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2512 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 354/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1204 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 355/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 356/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 8.0202e-07
# Epoch 357/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 4.9091e-07
# Epoch 358/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1209 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 4.9091e-07
# Epoch 359/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2515 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 4.9091e-07
# Epoch 360/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2517 - mean_squared_error: 0.1207 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 4.9091e-07
# Epoch 361/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.2513 - mean_squared_error: 0.1205 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 4.9091e-07
# Epoch 362/1000
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.2511 - mean_squared_error: 0.1206 - val_loss: 0.2779 - val_mean_squared_error: 0.1494 - learning_rate: 4.9091e-07

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds_repeat.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds_repeat.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Train MAE (standardized): 0.2688078251451451
# Valid MAE (standardized): 0.2778438217216092
# Train MAE: 2.893551102000206
# Valid MAE: 2.990818057039856

# %% [markdown]
# ## Model 2

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=25, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.6120967737206469, patience=10
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(
        928, activation='gelu',
        bias_regularizer=tf.keras.regularizers.L1L2(0.3825531288065288, 0.1566136667517353),
        kernel_regularizer=None,
        kernel_initializer='he_normal'
    ),
    tf.keras.layers.Dropout(0.3805954215962635),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Adam(learning_rate=1.5e-6, beta_1=0.95, beta_2=0.999)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds_repeat, epochs=1000, validation_data=valid_ds_repeat,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=0
)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds_repeat.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds_repeat.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MAE (standardized): 0.27059785026890854
# Valid MAE (standardized): 0.2801189158091954
# Train MAE: 2.912819667784051
# Valid MAE: 3.015308085240328

# %% [markdown]
# ## Model 3

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=25, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.6, patience=10
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(
        928, activation='gelu',
        bias_regularizer=tf.keras.regularizers.L1L2(0.4, 0.15),
        kernel_regularizer=None,
        kernel_initializer='he_normal'
    ),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Adam(learning_rate=1.5e-6, beta_1=0.95, beta_2=0.999)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds_repeat, epochs=1000, validation_data=valid_ds_repeat,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=0
)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds_repeat.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds_repeat.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MAE (standardized): 0.27012079757542323
# Valid MAE (standardized): 0.28043619072504505
# Train MAE: 2.907684470005262
# Valid MAE: 3.018723335814671

# %% [markdown]
# ## Model 3.1 - more patience+Nadam

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=100, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.6, patience=25
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(
        928, activation='gelu',
        bias_regularizer=tf.keras.regularizers.L1L2(0.4, 0.15),
        kernel_regularizer=None,
        kernel_initializer='he_normal'
    ),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Nadam(learning_rate=1.5e-6, beta_1=0.95, beta_2=0.999)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds_repeat, epochs=1000, validation_data=valid_ds_repeat,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback],
    verbose=0
)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
y_train = np.concatenate([targets.numpy().reshape(-1) for _, targets in train_ds_repeat.take(train_num_batches)]).reshape(-1, 1)
y_valid = np.concatenate([targets.numpy().reshape(-1) for _, targets in valid_ds_repeat.take(valid_num_batches)]).reshape(-1, 1)

y_train_pred = model.predict(train_ds, steps=train_num_batches)
y_valid_pred = model.predict(valid_ds, steps=valid_num_batches)

print(f'Train MAE (standardized): {mean_absolute_error(y_train, y_train_pred)}')
print(f'Valid MAE (standardized): {mean_absolute_error(y_valid, y_valid_pred)}')

print(f'Train MAE: {mean_absolute_error(tmax_inverse_transform(y_train), tmax_inverse_transform(y_train_pred))}')
print(f'Valid MAE: {mean_absolute_error(tmax_inverse_transform(y_valid), tmax_inverse_transform(y_valid_pred))}')
# Out:
# 1088/1088 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MAE (standardized): 0.26955155272026404
# Valid MAE (standardized): 0.2787214140078307
# Train MAE: 2.9015568903335245
# Valid MAE: 3.000264830205675
