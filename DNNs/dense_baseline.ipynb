# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
import os
import random
import datetime

np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# # Data

# %%
data_path = 'https://raw.githubusercontent.com/antbartash/max_temp/master/data/data2.csv'
data = pd.read_csv(data_path, index_col=0)
data['DATE'] = data['DATE'].astype('datetime64[ns]')

print(data.shape)
data.head()
# Out:
# (40898, 4)
#        STATION                        NAME       DATE  TMAX
# 0  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-01  12.2
# 1  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-02  10.6
# 2  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-03   8.3
# 3  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-04   6.1
# 4  USW00012916  NEW ORLEANS AIRPORT, LA US 2010-01-05   6.1

# %%
# only 1 station
# data = data[data['STATION'] == 'USW00012916'].reset_index(drop=True)
# data = data[['DATE', 'TMAX']]

data = data[['STATION', 'DATE', 'TMAX']]

# add sine and cosine transforms to add periodicality
doy = data['DATE'].dt.dayofyear / 365.2425
data['Year_sin'] = np.sin(doy * 2 * np.pi)
data['Year_cos'] = np.cos(doy * 2 * np.pi)

print(data.shape)
data.head()
# Out:
# (40898, 5)
#        STATION       DATE  TMAX  Year_sin  Year_cos
# 0  USW00012916 2010-01-01  12.2  0.017202  0.999852
# 1  USW00012916 2010-01-02  10.6  0.034399  0.999408
# 2  USW00012916 2010-01-03   8.3  0.051585  0.998669
# 3  USW00012916 2010-01-04   6.1  0.068757  0.997633
# 4  USW00012916 2010-01-05   6.1  0.085908  0.996303

# %%
# Station TMAX plot

STATION_IDX = 2
data_plot = data[data['STATION'] == data['STATION'].unique()[STATION_IDX]].copy()

fix, ax = plt.subplots(figsize=(12, 2))
ax.plot(data_plot['DATE'], data_plot['TMAX'], label='TMAX')

ax2 = ax.twinx()
ax2.plot(np.nan, np.nan, label='TMAX')
ax2.plot(data_plot['DATE'], data_plot['Year_sin'], label='Year_sin')
ax2.plot(data_plot['DATE'], data_plot['Year_cos'], label='Year_cos')

ax.set_ylabel('TMAX')
ax2.set_ylabel('sin, cos')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Station TMAX plot
PLOT_YEAR = 2010

fix, ax = plt.subplots(figsize=(12, 2))
ax.plot(data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'DATE'],
        data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'TMAX'],
        label='TMAX')

ax2 = ax.twinx()
ax2.plot(np.nan, np.nan, label='TMAX')
ax2.plot(data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'DATE'],
        data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'Year_sin'],
        label='Year_sin')
ax2.plot(data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'DATE'],
        data_plot.loc[data_plot['DATE'].dt.year==PLOT_YEAR, 'Year_cos'],
        label='Year_cos')

ax.set_ylabel('TMAX')
ax2.set_ylabel('sin, cos')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Train/valid/test split

# %%
train_df = data.loc[data['DATE'].dt.year <= 2021].reset_index(drop=True).copy()
valid_df = data.loc[data['DATE'].dt.year == 2022].reset_index(drop=True).copy()
test_df = data.loc[data['DATE'].dt.year == 2023].reset_index(drop=True).copy()

print(f'Train: {train_df.shape}')
print(f'Valid: {valid_df.shape}')
print(f'Test: {test_df.shape}')
# Out:
# Train: (35058, 5)
# Valid: (2920, 5)
# Test: (2920, 5)

# %% [markdown]
# ## Scaling

# %%
# train_df.set_index('DATE', inplace=True)
# valid_df.set_index('DATE', inplace=True)
# test_df.set_index('DATE', inplace=True)
train_df.drop(columns=['DATE'], inplace=True)
valid_df.drop(columns=['DATE'], inplace=True)
test_df.drop(columns=['DATE'], inplace=True)

# keep station to drop mixed windows later (encode to avoid errors from scaler)
encoder = OrdinalEncoder()
encoder.fit(train_df[['STATION']])
train_df['STATION'] = encoder.transform(train_df[['STATION']])[:, 0]
valid_df['STATION'] = encoder.transform(valid_df[['STATION']])[:, 0]
test_df['STATION'] = encoder.transform(test_df[['STATION']])[:, 0]

# scaling
scaler = StandardScaler()
scaler.fit(train_df)
train_df = pd.DataFrame(scaler.transform(train_df),
                        columns=scaler.feature_names_in_, index=train_df.index)
valid_df = pd.DataFrame(scaler.transform(valid_df),
                        columns=scaler.feature_names_in_, index=valid_df.index)
test_df = pd.DataFrame(scaler.transform(test_df),
                       columns=scaler.feature_names_in_, index=test_df.index)

train_df.head()
# Out:
#     STATION      TMAX  Year_sin  Year_cos
# 0 -1.091014 -0.747812  0.024402  1.414016
# 1 -1.091014 -0.896450  0.048723  1.413388
# 2 -1.091014 -1.110117  0.073029  1.412342
# 3 -1.091014 -1.314495  0.097314  1.410878
# 4 -1.091014 -1.314495  0.121571  1.408997

# %% [markdown]
# ## TF Dataset

# %%
def create_dataset(data, target_col, source_col, seq_length):
  input_data = data[:-seq_length]
  # adding source_col to target allows to drop samples with features and target
  # from diff sources (source_col will be dropped from the target later)
  targets = data[[source_col, target_col]][seq_length:]
  dataset = tf.keras.preprocessing.timeseries_dataset_from_array(
      input_data, targets,
      sequence_length=seq_length,
      sequence_stride=1,
      batch_size=32,
      shuffle=False,
      seed=42
    )
  for batch in dataset:
    inputs, targets = batch
    assert np.array_equal(inputs[0], data[:seq_length])  # First sequence: steps [0-13]
    # Corresponding target: step 14
    assert np.array_equal(targets[0, 1], data.loc[seq_length, target_col])
    break
  return dataset

train_ds = create_dataset(train_df, 'TMAX', 'STATION', 14)
valid_ds = create_dataset(valid_df, 'TMAX', 'STATION', 14)
test_ds = create_dataset(test_df, 'TMAX', 'STATION', 14)

# %% [markdown]
# ### Check

# %%
train_df.head(15)
# Out:
#      STATION      TMAX  Year_sin  Year_cos
# 0  -1.091014 -0.747812  0.024402  1.414016
# 1  -1.091014 -0.896450  0.048723  1.413388
# 2  -1.091014 -1.110117  0.073029  1.412342
# 3  -1.091014 -1.314495  0.097314  1.410878
# 4  -1.091014 -1.314495  0.121571  1.408997
# 5  -1.091014 -1.110117  0.145791  1.406699
# 6  -1.091014 -0.329766  0.169968  1.403984
# 7  -1.091014 -1.723250  0.194095  1.400854
# 8  -1.091014 -1.621062  0.218165  1.397309
# 9  -1.091014 -1.472423  0.242170  1.393351
# 10 -1.091014 -1.007929  0.266103  1.388981
# 11 -1.091014 -0.543434  0.289958  1.384200
# 12 -1.091014 -0.952189  0.313727  1.379009
# 13 -1.091014 -0.385506  0.337403  1.373410
# 14 -1.091014 -0.487695  0.360979  1.367404

# %%
list(train_ds.unbatch().as_numpy_iterator())[0]
# Out:
# (array([[-1.09101358, -0.74781154,  0.02440159,  1.41401556],
#         [-1.09101358, -0.89644984,  0.04872265,  1.41338789],
#         [-1.09101358, -1.1101174 ,  0.07302932,  1.41234198],
#         [-1.09101358, -1.31449507,  0.09731439,  1.41087814],
#         [-1.09101358, -1.31449507,  0.12157069,  1.4089968 ],
#         [-1.09101358, -1.1101174 ,  0.14579103,  1.40669853],
#         [-1.09101358, -0.32976632,  0.16996825,  1.40398399],
#         [-1.09101358, -1.72325039,  0.19409519,  1.40085399],
#         [-1.09101358, -1.62106156,  0.21816472,  1.39730947],
#         [-1.09101358, -1.47242326,  0.24216971,  1.39335146],
#         [-1.09101358, -1.00792857,  0.26610305,  1.38898114],
#         [-1.09101358, -0.54343388,  0.28995767,  1.38419981],
#         [-1.09101358, -0.95218921,  0.3137265 ,  1.37900887],
#         [-1.09101358, -0.38550568,  0.33740252,  1.37340987]]),
#  array([-1.09101358, -0.48769452]))

# %% [markdown]
# ## Different sources

# %% [markdown]
# ### Problem

# %%
# some samples has info from different sources in features (the first column)
list(train_ds.unbatch().as_numpy_iterator())[4382]
# Out:
# (array([[-1.09101358,  0.74786136, -0.00582654,  1.4142125 ],
#         [ 1.52765803, -1.47242326,  0.02440159,  1.41401556],
#         [ 1.52765803, -1.77898976,  0.04872265,  1.41338789],
#         [ 1.52765803, -2.40141264,  0.07302932,  1.41234198],
#         [ 1.52765803, -1.98336742,  0.09731439,  1.41087814],
#         [ 1.52765803, -1.98336742,  0.12157069,  1.4089968 ],
#         [ 1.52765803, -1.77898976,  0.14579103,  1.40669853],
#         [ 1.52765803, -1.62106156,  0.16996825,  1.40398399],
#         [ 1.52765803, -1.82543923,  0.19409519,  1.40085399],
#         [ 1.52765803, -1.98336742,  0.21816472,  1.39730947],
#         [ 1.52765803, -2.08555625,  0.24216971,  1.39335146],
#         [ 1.52765803, -1.93691795,  0.26610305,  1.38898114],
#         [ 1.52765803, -1.72325039,  0.28995767,  1.38419981],
#         [ 1.52765803, -1.72325039,  0.3137265 ,  1.37900887]]),
#  array([ 1.52765803, -1.36094454]))

# %%
# some samples has info from different sources in target (the first column)
list(train_ds.unbatch().as_numpy_iterator())[4369]
# Out:
# (array([[-1.09101358,  0.5434837 , -0.31933006,  1.37768853],
#         [-1.09101358, -0.12538866, -0.29558309,  1.38297857],
#         [-1.09101358, -0.89644984, -0.27174863,  1.38785937],
#         [-1.09101358, -0.85000038, -0.24783372,  1.39232948],
#         [-1.09101358, -0.32976632, -0.22384546,  1.39638759],
#         [-1.09101358, -0.12538866, -0.19979093,  1.40003248],
#         [-1.09101358,  0.44129487, -0.17567725,  1.40326309],
#         [-1.09101358,  0.49703423, -0.15151157,  1.40607845],
#         [-1.09101358,  0.44129487, -0.12730102,  1.40847774],
#         [-1.09101358,  0.5434837 , -0.10305279,  1.41046024],
#         [-1.09101358,  0.5434837 , -0.07877403,  1.41202537],
#         [-1.09101358,  0.64567253, -0.05447195,  1.41317266],
#         [-1.09101358,  0.80360072, -0.03015372,  1.41390177],
#         [-1.09101358,  0.74786136, -0.00582654,  1.4142125 ]]),
#  array([ 1.52765803, -1.47242326]))

# %%
def filter_mixed_windows(dataset):
    def is_valid_window(inputs, targets):
        # Extract the first feature (station) from inputs and targets
        input_station_ids = inputs[:, :, 0]  # Shape: (batch_size, sequence_length)
        target_station_ids = targets[:, 0]  # Shape: (batch_size)

        # Check if all station IDs in the inputs are the same
        input_same_station = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == tf.reduce_min(input_station_ids, axis=1))

        # Check if the target's station ID matches the input station ID
        target_matches_input = tf.reduce_all(tf.reduce_max(input_station_ids, axis=1) == target_station_ids)

        # Only keep windows where both conditions are true
        return tf.logical_and(input_same_station, target_matches_input)

    # Filter the dataset
    filtered_dataset = dataset.filter(is_valid_window)
    return filtered_dataset

train_ds = filter_mixed_windows(train_ds)
valid_ds = filter_mixed_windows(valid_ds)
test_ds = filter_mixed_windows(test_ds)

# %% [markdown]
# ### Check

# %%
# different sources problem (features) fixed
list(filter_mixed_windows(train_ds).unbatch().as_numpy_iterator())[4382]
# Out:
# (array([[ 1.52765803, -1.72325039,  0.7398862 ,  1.20531056],
#         [ 1.52765803, -1.82543923,  0.76051095,  1.19240712],
#         [ 1.52765803, -1.51887273,  0.78091067,  1.17915085],
#         [ 1.52765803, -1.62106156,  0.80107932,  1.16554564],
#         [ 1.52765803, -1.67680093,  0.82101092,  1.15159555],
#         [ 1.52765803, -1.82543923,  0.84069959,  1.13730468],
#         [ 1.52765803, -1.77898976,  0.86013949,  1.12267728],
#         [ 1.52765803, -1.62106156,  0.87932488,  1.10771766],
#         [ 1.52765803, -1.36094454,  0.89825006,  1.09243026],
#         [ 1.52765803, -1.77898976,  0.91690946,  1.07681961],
#         [ 1.52765803, -1.62106156,  0.93529753,  1.06089031],
#         [ 1.52765803, -1.62106156,  0.95340885,  1.04464709],
#         [ 1.52765803, -1.88117859,  0.97123804,  1.02809474],
#         [ 1.52765803, -1.51887273,  0.98877985,  1.01123818]]),
#  array([ 1.52765803, -1.47242326]))

# %%
list(train_ds.unbatch().as_numpy_iterator())[4369]
# Out:
# (array([[ 1.52765803, -1.05437804,  0.45414617,  1.33935605],
#         [ 1.52765803, -1.4166839 ,  0.47711924,  1.33134764],
#         [ 1.52765803, -1.4166839 ,  0.49995114,  1.32294526],
#         [ 1.52765803, -1.2587557 ,  0.52263512,  1.31415141],
#         [ 1.52765803, -1.47242326,  0.54516445,  1.30496868],
#         [ 1.52765803, -0.95218921,  0.56753247,  1.2953998 ],
#         [ 1.52765803, -0.58988335,  0.58973257,  1.2854476 ],
#         [ 1.52765803, -1.00792857,  0.61175818,  1.27511501],
#         [ 1.52765803, -1.51887273,  0.63360276,  1.26440511],
#         [ 1.52765803, -1.36094454,  0.65525987,  1.25332105],
#         [ 1.52765803, -2.34567328,  0.67672309,  1.24186613],
#         [ 1.52765803, -2.50360148,  0.69798607,  1.23004372],
#         [ 1.52765803, -1.98336742,  0.71904252,  1.21785733],
#         [ 1.52765803, -1.72325039,  0.7398862 ,  1.20531056]]),
#  array([ 1.52765803, -1.82543923]))

# %% [markdown]
# ## Drop source column

# %%
def drop_first_column(feature, label):
    feature = feature[:, :, 1:]  # Keep all rows, drop the first column
    label = label[:, 1:]    # Keep all rows, drop the first column
    return feature, label

train_ds = train_ds.map(drop_first_column)
valid_ds = valid_ds.map(drop_first_column)
test_ds = test_ds.map(drop_first_column)

# %% [markdown]
# # Final dataset

# %%
for element in train_ds.take(1):
    print(f'Features batch shape: {element[0].shape}')
    print(f'Target batch shape: {element[1].shape}')
# Out:
# Features batch shape: (32, 14, 3)
# Target batch shape: (32, 1)

# %%
# 1st row features
element[0][0]
# Out:
# <tf.Tensor: shape=(14, 3), dtype=float64, numpy=
# array([[-0.74781154,  0.02440159,  1.41401556],
#        [-0.89644984,  0.04872265,  1.41338789],
#        [-1.1101174 ,  0.07302932,  1.41234198],
#        [-1.31449507,  0.09731439,  1.41087814],
#        [-1.31449507,  0.12157069,  1.4089968 ],
#        [-1.1101174 ,  0.14579103,  1.40669853],
#        [-0.32976632,  0.16996825,  1.40398399],
#        [-1.72325039,  0.19409519,  1.40085399],
#        [-1.62106156,  0.21816472,  1.39730947],
#        [-1.47242326,  0.24216971,  1.39335146],
#        [-1.00792857,  0.26610305,  1.38898114],
#        [-0.54343388,  0.28995767,  1.38419981],
#        [-0.95218921,  0.3137265 ,  1.37900887],
#        [-0.38550568,  0.33740252,  1.37340987]])>

# %%
# 1st row target
element[1][0]
# Out:
# <tf.Tensor: shape=(1,), dtype=float64, numpy=array([-0.48769452])>

# %% [markdown]
# # Baseline/test model

# %%
BATCH_SIZE = 128
train_ds = train_ds.unbatch().batch(BATCH_SIZE)
valid_ds = valid_ds.unbatch().batch(BATCH_SIZE)
test_ds = test_ds.unbatch().batch(BATCH_SIZE)

train_num_batches = len(list(train_ds))
valid_num_batches = len(list(valid_ds))
test_num_batches = len(list(test_ds))
print(train_num_batches, valid_num_batches, test_num_batches)

train_ds = train_ds.repeat()
valid_ds = valid_ds.repeat()
test_ds = test_ds.repeat()
# Out:
# 272 21 21

# %%
INPUT_SHAPE = (14, 3, )

# tensorboard callback
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    patience=100, restore_best_weights=True
)

# lr scheduler
lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=25
)


model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=INPUT_SHAPE),
    # Shape: (time, features) => (time*features)
    tf.keras.layers.Reshape(target_shape=(-1,)), # otherwise, the model is applied to each input time step
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001)
model.compile(loss='mean_absolute_error', optimizer=optimizer,
              metrics=['mean_squared_error'])

history = model.fit(
    train_ds, epochs=1000, validation_data=valid_ds,
    steps_per_epoch=train_num_batches, validation_steps=valid_num_batches,
    callbacks=[tensorboard_callback, early_stopping_callback, lr_scheduler_callback]
)
# Out:
# Epoch 1/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.3021 - mean_squared_error: 0.1624 - val_loss: 0.3024 - val_mean_squared_error: 0.1594 - learning_rate: 0.0010
# Epoch 2/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2629 - mean_squared_error: 0.1278 - val_loss: 0.3003 - val_mean_squared_error: 0.1579 - learning_rate: 0.0010
# Epoch 3/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2607 - mean_squared_error: 0.1262 - val_loss: 0.3003 - val_mean_squared_error: 0.1583 - learning_rate: 0.0010
# Epoch 4/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2598 - mean_squared_error: 0.1255 - val_loss: 0.2997 - val_mean_squared_error: 0.1580 - learning_rate: 0.0010
# Epoch 5/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2590 - mean_squared_error: 0.1252 - val_loss: 0.2990 - val_mean_squared_error: 0.1569 - learning_rate: 0.0010
# Epoch 6/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2592 - mean_squared_error: 0.1255 - val_loss: 0.2989 - val_mean_squared_error: 0.1567 - learning_rate: 0.0010
# Epoch 7/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2585 - mean_squared_error: 0.1249 - val_loss: 0.2984 - val_mean_squared_error: 0.1565 - learning_rate: 0.0010
# Epoch 8/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2585 - mean_squared_error: 0.1250 - val_loss: 0.2957 - val_mean_squared_error: 0.1552 - learning_rate: 0.0010
# Epoch 9/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2577 - mean_squared_error: 0.1244 - val_loss: 0.2975 - val_mean_squared_error: 0.1556 - learning_rate: 0.0010
# Epoch 10/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2577 - mean_squared_error: 0.1242 - val_loss: 0.2994 - val_mean_squared_error: 0.1565 - learning_rate: 0.0010
# Epoch 11/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2578 - mean_squared_error: 0.1242 - val_loss: 0.2992 - val_mean_squared_error: 0.1560 - learning_rate: 0.0010
# Epoch 12/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2573 - mean_squared_error: 0.1239 - val_loss: 0.3013 - val_mean_squared_error: 0.1571 - learning_rate: 0.0010
# Epoch 13/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2575 - mean_squared_error: 0.1239 - val_loss: 0.2995 - val_mean_squared_error: 0.1564 - learning_rate: 0.0010
# Epoch 14/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2567 - mean_squared_error: 0.1234 - val_loss: 0.3006 - val_mean_squared_error: 0.1567 - learning_rate: 0.0010
# Epoch 15/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2570 - mean_squared_error: 0.1234 - val_loss: 0.2992 - val_mean_squared_error: 0.1557 - learning_rate: 0.0010
# Epoch 16/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2562 - mean_squared_error: 0.1229 - val_loss: 0.2997 - val_mean_squared_error: 0.1562 - learning_rate: 0.0010
# Epoch 17/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2563 - mean_squared_error: 0.1230 - val_loss: 0.2999 - val_mean_squared_error: 0.1562 - learning_rate: 0.0010
# Epoch 18/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2567 - mean_squared_error: 0.1232 - val_loss: 0.2990 - val_mean_squared_error: 0.1557 - learning_rate: 0.0010
# Epoch 19/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2563 - mean_squared_error: 0.1229 - val_loss: 0.2983 - val_mean_squared_error: 0.1550 - learning_rate: 0.0010
# Epoch 20/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2562 - mean_squared_error: 0.1228 - val_loss: 0.2972 - val_mean_squared_error: 0.1541 - learning_rate: 0.0010
# Epoch 21/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2560 - mean_squared_error: 0.1228 - val_loss: 0.2958 - val_mean_squared_error: 0.1533 - learning_rate: 0.0010
# Epoch 22/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2557 - mean_squared_error: 0.1226 - val_loss: 0.2954 - val_mean_squared_error: 0.1530 - learning_rate: 0.0010
# Epoch 23/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2553 - mean_squared_error: 0.1224 - val_loss: 0.2956 - val_mean_squared_error: 0.1530 - learning_rate: 0.0010
# Epoch 24/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2551 - mean_squared_error: 0.1222 - val_loss: 0.2950 - val_mean_squared_error: 0.1529 - learning_rate: 0.0010
# Epoch 25/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2549 - mean_squared_error: 0.1221 - val_loss: 0.2945 - val_mean_squared_error: 0.1522 - learning_rate: 0.0010
# Epoch 26/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2548 - mean_squared_error: 0.1221 - val_loss: 0.2956 - val_mean_squared_error: 0.1530 - learning_rate: 0.0010
# Epoch 27/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2548 - mean_squared_error: 0.1221 - val_loss: 0.2948 - val_mean_squared_error: 0.1527 - learning_rate: 0.0010
# Epoch 28/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2548 - mean_squared_error: 0.1221 - val_loss: 0.2943 - val_mean_squared_error: 0.1526 - learning_rate: 0.0010
# Epoch 29/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2549 - mean_squared_error: 0.1220 - val_loss: 0.2951 - val_mean_squared_error: 0.1533 - learning_rate: 0.0010
# Epoch 30/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2548 - mean_squared_error: 0.1220 - val_loss: 0.2937 - val_mean_squared_error: 0.1523 - learning_rate: 0.0010
# Epoch 31/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2542 - mean_squared_error: 0.1216 - val_loss: 0.2931 - val_mean_squared_error: 0.1519 - learning_rate: 0.0010
# Epoch 32/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2540 - mean_squared_error: 0.1214 - val_loss: 0.2938 - val_mean_squared_error: 0.1525 - learning_rate: 0.0010
# Epoch 33/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2541 - mean_squared_error: 0.1214 - val_loss: 0.2928 - val_mean_squared_error: 0.1520 - learning_rate: 0.0010
# Epoch 34/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2537 - mean_squared_error: 0.1212 - val_loss: 0.2934 - val_mean_squared_error: 0.1522 - learning_rate: 0.0010
# Epoch 35/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2539 - mean_squared_error: 0.1213 - val_loss: 0.2932 - val_mean_squared_error: 0.1521 - learning_rate: 0.0010
# Epoch 36/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2538 - mean_squared_error: 0.1213 - val_loss: 0.2937 - val_mean_squared_error: 0.1521 - learning_rate: 0.0010
# Epoch 37/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2538 - mean_squared_error: 0.1213 - val_loss: 0.2937 - val_mean_squared_error: 0.1522 - learning_rate: 0.0010
# Epoch 38/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2538 - mean_squared_error: 0.1213 - val_loss: 0.2925 - val_mean_squared_error: 0.1515 - learning_rate: 0.0010
# Epoch 39/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2538 - mean_squared_error: 0.1212 - val_loss: 0.2921 - val_mean_squared_error: 0.1512 - learning_rate: 0.0010
# Epoch 40/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2533 - mean_squared_error: 0.1209 - val_loss: 0.2929 - val_mean_squared_error: 0.1519 - learning_rate: 0.0010
# Epoch 41/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2537 - mean_squared_error: 0.1211 - val_loss: 0.2925 - val_mean_squared_error: 0.1515 - learning_rate: 0.0010
# Epoch 42/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2535 - mean_squared_error: 0.1210 - val_loss: 0.2921 - val_mean_squared_error: 0.1513 - learning_rate: 0.0010
# Epoch 43/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2533 - mean_squared_error: 0.1208 - val_loss: 0.2928 - val_mean_squared_error: 0.1519 - learning_rate: 0.0010
# Epoch 44/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2533 - mean_squared_error: 0.1208 - val_loss: 0.2922 - val_mean_squared_error: 0.1514 - learning_rate: 0.0010
# Epoch 45/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2532 - mean_squared_error: 0.1208 - val_loss: 0.2918 - val_mean_squared_error: 0.1512 - learning_rate: 0.0010
# Epoch 46/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2530 - mean_squared_error: 0.1206 - val_loss: 0.2912 - val_mean_squared_error: 0.1512 - learning_rate: 0.0010
# Epoch 47/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2527 - mean_squared_error: 0.1205 - val_loss: 0.2917 - val_mean_squared_error: 0.1512 - learning_rate: 0.0010
# Epoch 48/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2526 - mean_squared_error: 0.1205 - val_loss: 0.2917 - val_mean_squared_error: 0.1514 - learning_rate: 0.0010
# Epoch 49/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2529 - mean_squared_error: 0.1205 - val_loss: 0.2911 - val_mean_squared_error: 0.1509 - learning_rate: 0.0010
# Epoch 50/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2525 - mean_squared_error: 0.1203 - val_loss: 0.2915 - val_mean_squared_error: 0.1510 - learning_rate: 0.0010
# Epoch 51/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2527 - mean_squared_error: 0.1204 - val_loss: 0.2918 - val_mean_squared_error: 0.1513 - learning_rate: 0.0010
# Epoch 52/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2528 - mean_squared_error: 0.1204 - val_loss: 0.2914 - val_mean_squared_error: 0.1511 - learning_rate: 0.0010
# Epoch 53/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2525 - mean_squared_error: 0.1203 - val_loss: 0.2913 - val_mean_squared_error: 0.1509 - learning_rate: 0.0010
# Epoch 54/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2525 - mean_squared_error: 0.1202 - val_loss: 0.2917 - val_mean_squared_error: 0.1516 - learning_rate: 0.0010
# Epoch 55/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2525 - mean_squared_error: 0.1202 - val_loss: 0.2916 - val_mean_squared_error: 0.1513 - learning_rate: 0.0010
# Epoch 56/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2526 - mean_squared_error: 0.1203 - val_loss: 0.2911 - val_mean_squared_error: 0.1512 - learning_rate: 0.0010
# Epoch 57/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2520 - mean_squared_error: 0.1200 - val_loss: 0.2912 - val_mean_squared_error: 0.1510 - learning_rate: 0.0010
# Epoch 58/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2520 - mean_squared_error: 0.1199 - val_loss: 0.2922 - val_mean_squared_error: 0.1517 - learning_rate: 0.0010
# Epoch 59/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2524 - mean_squared_error: 0.1201 - val_loss: 0.2916 - val_mean_squared_error: 0.1512 - learning_rate: 0.0010
# Epoch 60/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2519 - mean_squared_error: 0.1199 - val_loss: 0.2917 - val_mean_squared_error: 0.1511 - learning_rate: 0.0010
# Epoch 61/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2519 - mean_squared_error: 0.1200 - val_loss: 0.2928 - val_mean_squared_error: 0.1519 - learning_rate: 0.0010
# Epoch 62/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2525 - mean_squared_error: 0.1201 - val_loss: 0.2918 - val_mean_squared_error: 0.1515 - learning_rate: 0.0010
# Epoch 63/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2520 - mean_squared_error: 0.1199 - val_loss: 0.2919 - val_mean_squared_error: 0.1513 - learning_rate: 0.0010
# Epoch 64/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2520 - mean_squared_error: 0.1198 - val_loss: 0.2925 - val_mean_squared_error: 0.1517 - learning_rate: 0.0010
# Epoch 65/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2520 - mean_squared_error: 0.1199 - val_loss: 0.2922 - val_mean_squared_error: 0.1517 - learning_rate: 0.0010
# Epoch 66/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2519 - mean_squared_error: 0.1198 - val_loss: 0.2917 - val_mean_squared_error: 0.1514 - learning_rate: 0.0010
# Epoch 67/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2519 - mean_squared_error: 0.1198 - val_loss: 0.2918 - val_mean_squared_error: 0.1514 - learning_rate: 0.0010
# Epoch 68/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2518 - mean_squared_error: 0.1198 - val_loss: 0.2924 - val_mean_squared_error: 0.1515 - learning_rate: 0.0010
# Epoch 69/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2519 - mean_squared_error: 0.1198 - val_loss: 0.2927 - val_mean_squared_error: 0.1518 - learning_rate: 0.0010
# Epoch 70/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2517 - mean_squared_error: 0.1197 - val_loss: 0.2917 - val_mean_squared_error: 0.1513 - learning_rate: 0.0010
# Epoch 71/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2516 - mean_squared_error: 0.1197 - val_loss: 0.2924 - val_mean_squared_error: 0.1515 - learning_rate: 0.0010
# Epoch 72/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2515 - mean_squared_error: 0.1196 - val_loss: 0.2937 - val_mean_squared_error: 0.1523 - learning_rate: 0.0010
# Epoch 73/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2516 - mean_squared_error: 0.1196 - val_loss: 0.2930 - val_mean_squared_error: 0.1519 - learning_rate: 0.0010
# Epoch 74/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2514 - mean_squared_error: 0.1195 - val_loss: 0.2942 - val_mean_squared_error: 0.1522 - learning_rate: 0.0010
# Epoch 75/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2529 - mean_squared_error: 0.1200 - val_loss: 0.2907 - val_mean_squared_error: 0.1510 - learning_rate: 5.0000e-04
# Epoch 76/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2506 - mean_squared_error: 0.1190 - val_loss: 0.2904 - val_mean_squared_error: 0.1508 - learning_rate: 5.0000e-04
# Epoch 77/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2505 - mean_squared_error: 0.1189 - val_loss: 0.2906 - val_mean_squared_error: 0.1508 - learning_rate: 5.0000e-04
# Epoch 78/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2503 - mean_squared_error: 0.1188 - val_loss: 0.2903 - val_mean_squared_error: 0.1510 - learning_rate: 5.0000e-04
# Epoch 79/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2502 - mean_squared_error: 0.1187 - val_loss: 0.2907 - val_mean_squared_error: 0.1510 - learning_rate: 5.0000e-04
# Epoch 80/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2501 - mean_squared_error: 0.1186 - val_loss: 0.2899 - val_mean_squared_error: 0.1508 - learning_rate: 5.0000e-04
# Epoch 81/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2498 - mean_squared_error: 0.1185 - val_loss: 0.2902 - val_mean_squared_error: 0.1507 - learning_rate: 5.0000e-04
# Epoch 82/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2499 - mean_squared_error: 0.1186 - val_loss: 0.2914 - val_mean_squared_error: 0.1510 - learning_rate: 5.0000e-04
# Epoch 83/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2504 - mean_squared_error: 0.1187 - val_loss: 0.2906 - val_mean_squared_error: 0.1509 - learning_rate: 5.0000e-04
# Epoch 84/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2499 - mean_squared_error: 0.1184 - val_loss: 0.2903 - val_mean_squared_error: 0.1509 - learning_rate: 5.0000e-04
# Epoch 85/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2496 - mean_squared_error: 0.1182 - val_loss: 0.2904 - val_mean_squared_error: 0.1509 - learning_rate: 5.0000e-04
# Epoch 86/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2496 - mean_squared_error: 0.1183 - val_loss: 0.2903 - val_mean_squared_error: 0.1510 - learning_rate: 5.0000e-04
# Epoch 87/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2495 - mean_squared_error: 0.1182 - val_loss: 0.2908 - val_mean_squared_error: 0.1510 - learning_rate: 5.0000e-04
# Epoch 88/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2495 - mean_squared_error: 0.1181 - val_loss: 0.2901 - val_mean_squared_error: 0.1509 - learning_rate: 5.0000e-04
# Epoch 89/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2494 - mean_squared_error: 0.1181 - val_loss: 0.2903 - val_mean_squared_error: 0.1512 - learning_rate: 5.0000e-04
# Epoch 90/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2492 - mean_squared_error: 0.1180 - val_loss: 0.2908 - val_mean_squared_error: 0.1515 - learning_rate: 5.0000e-04
# Epoch 91/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2491 - mean_squared_error: 0.1180 - val_loss: 0.2906 - val_mean_squared_error: 0.1513 - learning_rate: 5.0000e-04
# Epoch 92/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2491 - mean_squared_error: 0.1180 - val_loss: 0.2904 - val_mean_squared_error: 0.1513 - learning_rate: 5.0000e-04
# Epoch 93/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2488 - mean_squared_error: 0.1179 - val_loss: 0.2900 - val_mean_squared_error: 0.1510 - learning_rate: 5.0000e-04
# Epoch 94/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2487 - mean_squared_error: 0.1176 - val_loss: 0.2907 - val_mean_squared_error: 0.1514 - learning_rate: 5.0000e-04
# Epoch 95/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2486 - mean_squared_error: 0.1177 - val_loss: 0.2899 - val_mean_squared_error: 0.1511 - learning_rate: 5.0000e-04
# Epoch 96/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2486 - mean_squared_error: 0.1177 - val_loss: 0.2900 - val_mean_squared_error: 0.1510 - learning_rate: 5.0000e-04
# Epoch 97/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2485 - mean_squared_error: 0.1176 - val_loss: 0.2915 - val_mean_squared_error: 0.1519 - learning_rate: 5.0000e-04
# Epoch 98/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2484 - mean_squared_error: 0.1174 - val_loss: 0.2914 - val_mean_squared_error: 0.1517 - learning_rate: 5.0000e-04
# Epoch 99/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2484 - mean_squared_error: 0.1174 - val_loss: 0.2917 - val_mean_squared_error: 0.1519 - learning_rate: 5.0000e-04
# Epoch 100/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2486 - mean_squared_error: 0.1176 - val_loss: 0.2909 - val_mean_squared_error: 0.1517 - learning_rate: 5.0000e-04
# Epoch 101/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2483 - mean_squared_error: 0.1173 - val_loss: 0.2907 - val_mean_squared_error: 0.1515 - learning_rate: 5.0000e-04
# Epoch 102/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2481 - mean_squared_error: 0.1173 - val_loss: 0.2914 - val_mean_squared_error: 0.1520 - learning_rate: 5.0000e-04
# Epoch 103/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2481 - mean_squared_error: 0.1173 - val_loss: 0.2905 - val_mean_squared_error: 0.1516 - learning_rate: 5.0000e-04
# Epoch 104/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2479 - mean_squared_error: 0.1171 - val_loss: 0.2908 - val_mean_squared_error: 0.1519 - learning_rate: 5.0000e-04
# Epoch 105/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2478 - mean_squared_error: 0.1171 - val_loss: 0.2917 - val_mean_squared_error: 0.1519 - learning_rate: 5.0000e-04
# Epoch 106/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2488 - mean_squared_error: 0.1173 - val_loss: 0.2875 - val_mean_squared_error: 0.1515 - learning_rate: 2.5000e-04
# Epoch 107/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2470 - mean_squared_error: 0.1170 - val_loss: 0.2873 - val_mean_squared_error: 0.1514 - learning_rate: 2.5000e-04
# Epoch 108/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2469 - mean_squared_error: 0.1169 - val_loss: 0.2876 - val_mean_squared_error: 0.1514 - learning_rate: 2.5000e-04
# Epoch 109/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2468 - mean_squared_error: 0.1168 - val_loss: 0.2873 - val_mean_squared_error: 0.1513 - learning_rate: 2.5000e-04
# Epoch 110/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2467 - mean_squared_error: 0.1168 - val_loss: 0.2880 - val_mean_squared_error: 0.1515 - learning_rate: 2.5000e-04
# Epoch 111/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2467 - mean_squared_error: 0.1167 - val_loss: 0.2882 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 112/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2466 - mean_squared_error: 0.1167 - val_loss: 0.2878 - val_mean_squared_error: 0.1514 - learning_rate: 2.5000e-04
# Epoch 113/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2466 - mean_squared_error: 0.1167 - val_loss: 0.2878 - val_mean_squared_error: 0.1515 - learning_rate: 2.5000e-04
# Epoch 114/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2463 - mean_squared_error: 0.1166 - val_loss: 0.2878 - val_mean_squared_error: 0.1515 - learning_rate: 2.5000e-04
# Epoch 115/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2463 - mean_squared_error: 0.1166 - val_loss: 0.2877 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 116/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2462 - mean_squared_error: 0.1165 - val_loss: 0.2878 - val_mean_squared_error: 0.1515 - learning_rate: 2.5000e-04
# Epoch 117/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2462 - mean_squared_error: 0.1165 - val_loss: 0.2877 - val_mean_squared_error: 0.1516 - learning_rate: 2.5000e-04
# Epoch 118/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2461 - mean_squared_error: 0.1164 - val_loss: 0.2875 - val_mean_squared_error: 0.1515 - learning_rate: 2.5000e-04
# Epoch 119/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2459 - mean_squared_error: 0.1163 - val_loss: 0.2880 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 120/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2459 - mean_squared_error: 0.1163 - val_loss: 0.2880 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 121/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2459 - mean_squared_error: 0.1163 - val_loss: 0.2886 - val_mean_squared_error: 0.1519 - learning_rate: 2.5000e-04
# Epoch 122/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2459 - mean_squared_error: 0.1162 - val_loss: 0.2880 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 123/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2457 - mean_squared_error: 0.1162 - val_loss: 0.2882 - val_mean_squared_error: 0.1519 - learning_rate: 2.5000e-04
# Epoch 124/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2456 - mean_squared_error: 0.1161 - val_loss: 0.2883 - val_mean_squared_error: 0.1520 - learning_rate: 2.5000e-04
# Epoch 125/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2456 - mean_squared_error: 0.1161 - val_loss: 0.2883 - val_mean_squared_error: 0.1518 - learning_rate: 2.5000e-04
# Epoch 126/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2456 - mean_squared_error: 0.1160 - val_loss: 0.2889 - val_mean_squared_error: 0.1521 - learning_rate: 2.5000e-04
# Epoch 127/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2456 - mean_squared_error: 0.1161 - val_loss: 0.2881 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 128/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2455 - mean_squared_error: 0.1160 - val_loss: 0.2885 - val_mean_squared_error: 0.1521 - learning_rate: 2.5000e-04
# Epoch 129/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2454 - mean_squared_error: 0.1160 - val_loss: 0.2887 - val_mean_squared_error: 0.1521 - learning_rate: 2.5000e-04
# Epoch 130/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2454 - mean_squared_error: 0.1159 - val_loss: 0.2885 - val_mean_squared_error: 0.1521 - learning_rate: 2.5000e-04
# Epoch 131/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2453 - mean_squared_error: 0.1159 - val_loss: 0.2879 - val_mean_squared_error: 0.1517 - learning_rate: 2.5000e-04
# Epoch 132/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2452 - mean_squared_error: 0.1158 - val_loss: 0.2885 - val_mean_squared_error: 0.1520 - learning_rate: 2.5000e-04
# Epoch 133/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2459 - mean_squared_error: 0.1160 - val_loss: 0.2837 - val_mean_squared_error: 0.1509 - learning_rate: 1.2500e-04
# Epoch 134/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2445 - mean_squared_error: 0.1158 - val_loss: 0.2836 - val_mean_squared_error: 0.1508 - learning_rate: 1.2500e-04
# Epoch 135/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2444 - mean_squared_error: 0.1158 - val_loss: 0.2838 - val_mean_squared_error: 0.1508 - learning_rate: 1.2500e-04
# Epoch 136/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2444 - mean_squared_error: 0.1157 - val_loss: 0.2839 - val_mean_squared_error: 0.1509 - learning_rate: 1.2500e-04
# Epoch 137/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2443 - mean_squared_error: 0.1157 - val_loss: 0.2840 - val_mean_squared_error: 0.1509 - learning_rate: 1.2500e-04
# Epoch 138/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2443 - mean_squared_error: 0.1157 - val_loss: 0.2840 - val_mean_squared_error: 0.1510 - learning_rate: 1.2500e-04
# Epoch 139/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2442 - mean_squared_error: 0.1157 - val_loss: 0.2840 - val_mean_squared_error: 0.1510 - learning_rate: 1.2500e-04
# Epoch 140/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2442 - mean_squared_error: 0.1156 - val_loss: 0.2842 - val_mean_squared_error: 0.1511 - learning_rate: 1.2500e-04
# Epoch 141/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2442 - mean_squared_error: 0.1156 - val_loss: 0.2842 - val_mean_squared_error: 0.1511 - learning_rate: 1.2500e-04
# Epoch 142/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2441 - mean_squared_error: 0.1156 - val_loss: 0.2842 - val_mean_squared_error: 0.1511 - learning_rate: 1.2500e-04
# Epoch 143/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2441 - mean_squared_error: 0.1155 - val_loss: 0.2843 - val_mean_squared_error: 0.1512 - learning_rate: 1.2500e-04
# Epoch 144/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2441 - mean_squared_error: 0.1155 - val_loss: 0.2843 - val_mean_squared_error: 0.1512 - learning_rate: 1.2500e-04
# Epoch 145/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2440 - mean_squared_error: 0.1155 - val_loss: 0.2844 - val_mean_squared_error: 0.1513 - learning_rate: 1.2500e-04
# Epoch 146/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2440 - mean_squared_error: 0.1155 - val_loss: 0.2843 - val_mean_squared_error: 0.1513 - learning_rate: 1.2500e-04
# Epoch 147/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2439 - mean_squared_error: 0.1155 - val_loss: 0.2844 - val_mean_squared_error: 0.1513 - learning_rate: 1.2500e-04
# Epoch 148/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2439 - mean_squared_error: 0.1154 - val_loss: 0.2844 - val_mean_squared_error: 0.1513 - learning_rate: 1.2500e-04
# Epoch 149/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2439 - mean_squared_error: 0.1154 - val_loss: 0.2844 - val_mean_squared_error: 0.1513 - learning_rate: 1.2500e-04
# Epoch 150/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2439 - mean_squared_error: 0.1154 - val_loss: 0.2844 - val_mean_squared_error: 0.1514 - learning_rate: 1.2500e-04
# Epoch 151/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2438 - mean_squared_error: 0.1154 - val_loss: 0.2843 - val_mean_squared_error: 0.1514 - learning_rate: 1.2500e-04
# Epoch 152/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2438 - mean_squared_error: 0.1153 - val_loss: 0.2845 - val_mean_squared_error: 0.1515 - learning_rate: 1.2500e-04
# Epoch 153/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2438 - mean_squared_error: 0.1153 - val_loss: 0.2844 - val_mean_squared_error: 0.1514 - learning_rate: 1.2500e-04
# Epoch 154/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2437 - mean_squared_error: 0.1153 - val_loss: 0.2845 - val_mean_squared_error: 0.1516 - learning_rate: 1.2500e-04
# Epoch 155/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2437 - mean_squared_error: 0.1152 - val_loss: 0.2845 - val_mean_squared_error: 0.1516 - learning_rate: 1.2500e-04
# Epoch 156/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2436 - mean_squared_error: 0.1152 - val_loss: 0.2846 - val_mean_squared_error: 0.1517 - learning_rate: 1.2500e-04
# Epoch 157/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2436 - mean_squared_error: 0.1152 - val_loss: 0.2846 - val_mean_squared_error: 0.1517 - learning_rate: 1.2500e-04
# Epoch 158/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2436 - mean_squared_error: 0.1152 - val_loss: 0.2846 - val_mean_squared_error: 0.1516 - learning_rate: 1.2500e-04
# Epoch 159/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2435 - mean_squared_error: 0.1151 - val_loss: 0.2845 - val_mean_squared_error: 0.1516 - learning_rate: 1.2500e-04
# Epoch 160/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2439 - mean_squared_error: 0.1151 - val_loss: 0.2820 - val_mean_squared_error: 0.1515 - learning_rate: 6.2500e-05
# Epoch 161/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2432 - mean_squared_error: 0.1150 - val_loss: 0.2819 - val_mean_squared_error: 0.1515 - learning_rate: 6.2500e-05
# Epoch 162/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2431 - mean_squared_error: 0.1149 - val_loss: 0.2819 - val_mean_squared_error: 0.1516 - learning_rate: 6.2500e-05
# Epoch 163/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2431 - mean_squared_error: 0.1149 - val_loss: 0.2819 - val_mean_squared_error: 0.1515 - learning_rate: 6.2500e-05
# Epoch 164/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2430 - mean_squared_error: 0.1148 - val_loss: 0.2819 - val_mean_squared_error: 0.1515 - learning_rate: 6.2500e-05
# Epoch 165/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2430 - mean_squared_error: 0.1149 - val_loss: 0.2819 - val_mean_squared_error: 0.1515 - learning_rate: 6.2500e-05
# Epoch 166/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2430 - mean_squared_error: 0.1148 - val_loss: 0.2819 - val_mean_squared_error: 0.1515 - learning_rate: 6.2500e-05
# Epoch 167/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2429 - mean_squared_error: 0.1148 - val_loss: 0.2820 - val_mean_squared_error: 0.1516 - learning_rate: 6.2500e-05
# Epoch 168/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2429 - mean_squared_error: 0.1148 - val_loss: 0.2819 - val_mean_squared_error: 0.1516 - learning_rate: 6.2500e-05
# Epoch 169/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2429 - mean_squared_error: 0.1148 - val_loss: 0.2819 - val_mean_squared_error: 0.1515 - learning_rate: 6.2500e-05
# Epoch 170/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2428 - mean_squared_error: 0.1147 - val_loss: 0.2820 - val_mean_squared_error: 0.1516 - learning_rate: 6.2500e-05
# Epoch 171/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2428 - mean_squared_error: 0.1147 - val_loss: 0.2820 - val_mean_squared_error: 0.1516 - learning_rate: 6.2500e-05
# Epoch 172/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2428 - mean_squared_error: 0.1147 - val_loss: 0.2819 - val_mean_squared_error: 0.1516 - learning_rate: 6.2500e-05
# Epoch 173/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2428 - mean_squared_error: 0.1147 - val_loss: 0.2820 - val_mean_squared_error: 0.1517 - learning_rate: 6.2500e-05
# Epoch 174/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2428 - mean_squared_error: 0.1147 - val_loss: 0.2820 - val_mean_squared_error: 0.1517 - learning_rate: 6.2500e-05
# Epoch 175/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2427 - mean_squared_error: 0.1147 - val_loss: 0.2820 - val_mean_squared_error: 0.1518 - learning_rate: 6.2500e-05
# Epoch 176/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2427 - mean_squared_error: 0.1147 - val_loss: 0.2820 - val_mean_squared_error: 0.1517 - learning_rate: 6.2500e-05
# Epoch 177/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2427 - mean_squared_error: 0.1146 - val_loss: 0.2821 - val_mean_squared_error: 0.1518 - learning_rate: 6.2500e-05
# Epoch 178/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2427 - mean_squared_error: 0.1146 - val_loss: 0.2821 - val_mean_squared_error: 0.1518 - learning_rate: 6.2500e-05
# Epoch 179/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2427 - mean_squared_error: 0.1146 - val_loss: 0.2821 - val_mean_squared_error: 0.1518 - learning_rate: 6.2500e-05
# Epoch 180/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2426 - mean_squared_error: 0.1146 - val_loss: 0.2821 - val_mean_squared_error: 0.1518 - learning_rate: 6.2500e-05
# Epoch 181/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2426 - mean_squared_error: 0.1146 - val_loss: 0.2821 - val_mean_squared_error: 0.1518 - learning_rate: 6.2500e-05
# Epoch 182/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2426 - mean_squared_error: 0.1146 - val_loss: 0.2821 - val_mean_squared_error: 0.1518 - learning_rate: 6.2500e-05
# Epoch 183/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2426 - mean_squared_error: 0.1146 - val_loss: 0.2822 - val_mean_squared_error: 0.1519 - learning_rate: 6.2500e-05
# Epoch 184/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2426 - mean_squared_error: 0.1146 - val_loss: 0.2822 - val_mean_squared_error: 0.1519 - learning_rate: 6.2500e-05
# Epoch 185/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2426 - mean_squared_error: 0.1145 - val_loss: 0.2822 - val_mean_squared_error: 0.1519 - learning_rate: 6.2500e-05
# Epoch 186/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2426 - mean_squared_error: 0.1145 - val_loss: 0.2822 - val_mean_squared_error: 0.1519 - learning_rate: 6.2500e-05
# Epoch 187/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2425 - mean_squared_error: 0.1145 - val_loss: 0.2823 - val_mean_squared_error: 0.1520 - learning_rate: 6.2500e-05
# Epoch 188/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2425 - mean_squared_error: 0.1145 - val_loss: 0.2822 - val_mean_squared_error: 0.1519 - learning_rate: 6.2500e-05
# Epoch 189/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2425 - mean_squared_error: 0.1145 - val_loss: 0.2823 - val_mean_squared_error: 0.1520 - learning_rate: 6.2500e-05
# Epoch 190/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2425 - mean_squared_error: 0.1145 - val_loss: 0.2823 - val_mean_squared_error: 0.1520 - learning_rate: 6.2500e-05
# Epoch 191/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2427 - mean_squared_error: 0.1143 - val_loss: 0.2816 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 192/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2423 - mean_squared_error: 0.1143 - val_loss: 0.2815 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 193/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2423 - mean_squared_error: 0.1143 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 194/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2422 - mean_squared_error: 0.1143 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 195/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2422 - mean_squared_error: 0.1143 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 196/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2422 - mean_squared_error: 0.1143 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 197/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2422 - mean_squared_error: 0.1143 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 198/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2421 - mean_squared_error: 0.1143 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 199/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2421 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 200/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2421 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 201/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2421 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 202/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2421 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 203/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2421 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 204/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2421 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 205/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2421 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 206/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2420 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 207/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2420 - mean_squared_error: 0.1142 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 208/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2420 - mean_squared_error: 0.1142 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 209/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2420 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 210/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2420 - mean_squared_error: 0.1141 - val_loss: 0.2815 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 211/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2420 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 212/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2420 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 213/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2419 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 214/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2419 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 215/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2419 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 216/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2419 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 217/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2419 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 218/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2419 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 219/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2419 - mean_squared_error: 0.1141 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 220/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2418 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 221/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2418 - mean_squared_error: 0.1140 - val_loss: 0.2813 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 222/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2418 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 223/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2418 - mean_squared_error: 0.1140 - val_loss: 0.2813 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 224/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2418 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 225/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2418 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 226/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2418 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 227/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2418 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 228/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2417 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 229/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2417 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 230/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2417 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 231/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2417 - mean_squared_error: 0.1140 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 232/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2417 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1524 - learning_rate: 3.1250e-05
# Epoch 233/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2417 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 234/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2417 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 235/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2417 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 236/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2417 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 237/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2417 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 238/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2417 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 239/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2416 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 240/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2416 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1525 - learning_rate: 3.1250e-05
# Epoch 241/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2416 - mean_squared_error: 0.1139 - val_loss: 0.2815 - val_mean_squared_error: 0.1526 - learning_rate: 3.1250e-05
# Epoch 242/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2416 - mean_squared_error: 0.1139 - val_loss: 0.2815 - val_mean_squared_error: 0.1526 - learning_rate: 3.1250e-05
# Epoch 243/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2416 - mean_squared_error: 0.1139 - val_loss: 0.2815 - val_mean_squared_error: 0.1526 - learning_rate: 3.1250e-05
# Epoch 244/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2416 - mean_squared_error: 0.1139 - val_loss: 0.2815 - val_mean_squared_error: 0.1526 - learning_rate: 3.1250e-05
# Epoch 245/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2417 - mean_squared_error: 0.1138 - val_loss: 0.2814 - val_mean_squared_error: 0.1528 - learning_rate: 1.5625e-05
# Epoch 246/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2415 - mean_squared_error: 0.1139 - val_loss: 0.2814 - val_mean_squared_error: 0.1528 - learning_rate: 1.5625e-05
# Epoch 247/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1137 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 283/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1137 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 284/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1137 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 285/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1137 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 286/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1137 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 287/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 288/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 289/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 290/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 291/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 292/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 293/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 294/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 295/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 296/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 297/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 298/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 299/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 300/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 301/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 302/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 303/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 304/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 305/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 7.8125e-06
# Epoch 306/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2412 - mean_squared_error: 0.1137 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 307/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 308/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 309/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 310/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 311/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 312/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 3.9063e-06
# Epoch 313/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2411 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 314/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 3.9063e-06
# Epoch 315/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 3.9063e-06
# Epoch 316/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 3.9063e-06
# Epoch 317/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 3.9063e-06
# Epoch 318/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 3.9063e-06
# Epoch 319/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 320/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 321/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 322/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 323/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 324/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 325/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 326/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 327/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 328/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 329/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 330/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 3.9063e-06
# Epoch 331/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1527 - learning_rate: 1.9531e-06
# Epoch 332/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 333/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 334/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 335/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1136 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 336/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 337/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 338/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 339/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 340/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 341/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 342/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 343/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 344/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 345/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 346/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 347/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 348/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 349/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 350/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 351/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 352/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 353/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 354/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 355/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 1.9531e-06
# Epoch 356/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 9.7656e-07
# Epoch 357/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2410 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 9.7656e-07
# Epoch 358/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2409 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 9.7656e-07
# Epoch 359/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2409 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 9.7656e-07
# Epoch 360/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2409 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 9.7656e-07
# Epoch 361/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2409 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 9.7656e-07
# Epoch 362/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2409 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 9.7656e-07
# Epoch 363/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2409 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 2.4414e-07
# Epoch 414/1000
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2409 - mean_squared_error: 0.1135 - val_loss: 0.2813 - val_mean_squared_error: 0.1526 - learning_rate: 2.4414e-07

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history['loss'], label='train_mean_absolute_error')
ax.plot(history.history['val_loss'], label='valid_mean_absolute_error')
ax.set_ylabel('MAE (standardized)')
ax.set_xlabel('Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
pred = model.predict(train_ds, steps=train_num_batches)
# Out:
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step

# %%
list(map(lambda x: x[1], train_ds))

# %%
# print(f'Train MAE: {mean_absolute_error(y_train, model.predict(train_dataset))}')
# print(f'Valid MAE: {mean_absolute_error(y_valid, model.predict(valid_dataset))}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5fbb377d9998> in <cell line: 1>()
# ----> 1 print(f'Train MAE: {mean_absolute_error(y_train, model.predict(train_dataset))}')
#       2 print(f'Valid MAE: {mean_absolute_error(y_valid, model.predict(valid_dataset))}')
#
# NameError: name 'y_train' is not defined
